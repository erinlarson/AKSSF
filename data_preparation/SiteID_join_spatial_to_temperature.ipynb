# %% [markdown]
# # Use relational dictionary to update site ids for spatial data so that they match site ids used for temperature data

# %%
import os, arcpy
#Data dictionary to update spatial data siteIDs to link to temperature data SiteIDs
idDict={'akbb-011':('accs_akbb-011'),
'akbb-020':('accs_akbb-020'),
'akbb-028':('accs_akbb-028'),
'akbb-029':('accs_akbb-029'),
'akbb-040':('accs_akbb-040'),
'ilbig01':('accs_ilbig01'),
'iltaz02':('accs_iltaz02'),
'iltnr19':('accs_iltnr19'),
'mubon10':('accs_mubon10'),
'muekm23':('accs_muekm23'),
'musfk01':('accs_musfk01'),
'mussm15':('accs_mussm15'),
'mustu17':('accs_mustu17'),
'mutsk02':('accs_mutsk02'),
'mutsk09':('accs_mutsk09'),
'kdk_ayarv01':('kdk_ayarv01'),
'kdk_busrv01':('kdk_busrv01'),
'kdk_doscr01':('kdk_doscr01'),
'kdk_doscr02':('kdk_doscr02'),
'kdk_karrv01':('kdk_karrv01'),
'kdk_olgcr01a':('kdk_olgcr01a'),
'apu1':('apu1'),
'apu10':('apu10'),
'apu11':('apu11'),
'apu12':('apu12'),
'apu2':('apu2'),
'apu3':('apu3'),
'apu5':('apu5'),
'apu6':('apu6'),
'apu7':('apu7'),
'apu8':('apu8'),
'apu9':('apu9'),
'ar2':('ar2'),
'cik1':('cik1'),
'cik2':('cik2'),
'cik3':('cik3'),
'cik4':('cik4'),
'cik6':('cik6'),
'cik7':('cik7'),
'cik8':('cik8'),
'cott-a':('cott-a'),
'cott-c':('cott-c'),
'cott-w':('cott-w'),
'nanc':('nanc'),
'nanc-44-l':('nanc-44-l'),
'nanc-44-m':('nanc-44-m'),
'nanc-44-u':('nanc-44-u'),
'pj lower':('pj lower'),
'pj mid':('pj mid'),
'sanc':('sanc'),
'sanc-1203-l':('sanc-1203-l'),
'sanc-1203-m':('sanc-1203-m'),
'sanc-1203-u':('sanc-1203-u'),
'star':('star'),
'star-171-m':('star-171-m'),
'star-171-u':('star-171-u'),
'star-69-l':('star-69-l'),
'star-69-m':('star-69-m'),
'star-69-u':('star-69-u'),
'star-a':('star-a'),
'star-w':('star-w'),
'star 171 lower':('star 171 lower'),
'star 171 upper':('star 171 upper'),
'cik_ben courtney creek':('cik_ben courtney creek'),
'cik_big creek':('cik_big creek'),
'big creek_naknek':('cik_big creek_naknek'),
'cik_copper river':('cik_copper river'),
'cik_gibraltar river':('cik_gibraltar river'),
'lost dog creek':('cik_lost dog creek'),
'mcgeary creek':('cik_mcgeary creek'),
'cik_napotoli creek':('cik_napotoli creek'),
'cik_neilson creek':('cik_neilson creek'),
'cik_panaruqak creek':('cik_panaruqak creek'),
'cik_roadhouse creek':('cik_roadhouse creek'),
'cik_silver salmon creek':('cik_silver salmon creek'),
'cik_sivanguq creek':('cik_sivanguq creek'),
'cik_squaw creek':('cik_squaw creek'),
'cik_tunravik creek':('cik_tunravik creek'),
'cik_yellow creek':('cik_yellow creek'),
'cik_0':('cik_0'),
'cik_1':('cik_1'),
'cik_10':('cik_10'),
'cik_11':('cik_11'),
'cik_12':('cik_12'),
'cik_13':('cik_13'),
'cik_14':('cik_14'),
'cik_15':('cik_15'),
'cik_16':('cik_16'),
'cik_17':('cik_17'),
'cik_18':('cik_18'),
'cik_19':('cik_19'),
'cik_2':('cik_2'),
'cik_20':('cik_20'),
'cik_21':('cik_21'),
'cik_22':('cik_22'),
'cik_23':('cik_23'),
'cik_24':('cik_24'),
'cik_25':('cik_25'),
'cik_26':('cik_26'),
'cik_27':('cik_27'),
'cik_28':('cik_28'),
'cik_29':('cik_29'),
'cik_3':('cik_3'),
'cik_30':('cik_30'),
'cik_31':('cik_31'),
'cik_32':('cik_32'),
'cik_33':('cik_33'),
'cik_34':('cik_34'),
'cik_35':('cik_35'),
'cik_36':('cik_36'),
'cik_37':('cik_37'),
'cik_38':('cik_38'),
'cik_39':('cik_39'),
'cik_4':('cik_4'),
'cik_40':('cik_40'),
'cik_41':('cik_41'),
'cik_42':('cik_42'),
'cik_43':('cik_43'),
'cik_44':('cik_44'),
'cik_45':('cik_45'),
'cik_46':('cik_46'),
'cik_47':('cik_47'),
'cik_48':('cik_48'),
'cik_5':('cik_5'),
'cik_6':('cik_6'),
'cik_7':('cik_7'),
'cik_8':('cik_8'),
'cik_9':('cik_9'),
'deshka 1 downstream':('deshka 1 downstream'),
'deshka 1 tributary':('deshka 1 tributary'),
'deshka 1 upstream':('deshka 1 upstream'),
'deshka 2 downstream':('deshka 2 downstream'),
'deshka 2 tributary':('deshka 2 tributary'),
'deshka 2 upstream':('deshka 2 upstream'),
'deshka 3 downstream':('deshka 3 downstream'),
'deshka 3 tributary':('deshka 3 tributary'),
'deshka 3 upstream':('deshka 3 upstream'),
'deshka 4 downstream':('deshka 4 downstream'),
'deshka 4 tributary':('deshka 4 tributary'),
'deshka 4 upstream':('deshka 4 upstream'),
'deshka 5 downstream':('deshka 5 downstream'),
'deshka 5 tributary':('deshka 5 tributary'),
'deshka 6 downstream':('deshka 6 downstream'),
'deshka 6 tributary':('deshka 6 tributary'),
'deshka 6 upstream':('deshka 6 upstream'),
'kroto 1 downstream':('kroto 1 downstream'),
'kroto 1 tributary':('kroto 1 tributary'),
'kroto 1 upstream':('kroto 1 upstream'),
'kroto 2 downstream':('kroto 2 downstream'),
'kroto 2 tributary':('kroto 2 tributary'),
'kroto 2 upstream':('kroto 2 upstream'),
'kroto 3 downstream':('kroto 3 downstream'),
'kroto 3 tributary':('kroto 3 tributary'),
'kroto 3 upstream':('kroto 3 upstream'),
'kroto 4 downstream':('kroto 4 downstream'),
'kroto 4 tributary':('kroto 4 tributary'),
'kroto 4 upstream':('kroto 4 upstream'),
'kroto 5 downstream':('kroto 5 downstream'),
'kroto 6 downstream':('kroto 6 downstream'),
'kroto 6 tributary':('kroto 6 tributary'),
'kroto 6 upstream':('kroto 6 upstream'),
'kroto 7 downstream':('kroto 7 downstream'),
'kroto 7 tributary':('kroto 7 tributary'),
'kroto 7 upstream':('kroto 7 upstream'),
'kroto 8 downstream':('kroto 8 downstream'),
'kroto 8 tributary':('kroto 8 tributary'),
'kroto 8 upstream':('kroto 8 upstream'),
'moose 1 top of study':('moose 1 top of study'),
'moose 2 downstream':('moose 2 downstream'),
'moose 2 tributary':('moose 2 tributary'),
'moose 2 upstream':('moose 2 upstream'),
'moose 3 downstream':('moose 3 downstream'),
'moose 3 tributary':('moose 3 tributary'),
'moose 3 upstream':('moose 3 upstream'),
'moose 4 downstream':('moose 4 downstream'),
'moose 4 tributary':('moose 4 tributary'),
'moose 4 upstream':('moose 4 upstream'),
'moose 5 downstream':('moose 5 downstream'),
'moose 5 tributary':('moose 5 tributary'),
'moose 5 upstream':('moose 5 upstream'),
'moose 6 downstream':('moose 6 downstream'),
'moose 6 tributary':('moose 6 tributary'),
'moose 6 upstream':('moose 6 upstream'),
'moose 7 downstream':('moose 7 downstream'),
'moose 7 tributary':('moose 7 tributary'),
'moose 7 upstream':('moose 7 upstream'),
'moose 8 downstream':('moose 8 downstream'),
'moose 8 tributary':('moose 8 tributary'),
'moose 8 upstream':('moose 8 upstream'),
'occ1':('occ1'),
'occ2':('occ2'),
'occt1':('occt1'),
'omct1':('omct1'),
'omct2':('omct2'),
'omct3':('omct3'),
'omct4':('omct4'),
'omct5':('omct5'),
'owl1':('owl1'),
'pgc1':('pgc1'),
'pgc2':('pgc2'),
'pgct1':('pgct1'),
'pgct2':('pgct2'),
'pkc1':('pkc1'),
'pkct1':('pkct1'),
'pkct2':('pkct2'),
'pmc1':('pmc1'),
'pmc2':('pmc2'),
'pmct1':('pmct1'),
'pnc1':('pnc1'),
'pnct1':('pnct1'),
'pnct2':('pnct2'),
'pnct4':('pnct4'),
'psm1':('psm1'),
'psm2':('psm2'),
'psmt1':('psmt1'),
'ptc1':('ptc1'),
'pwmc1':('pwmc1'),
'580223156504200':('fws_580223156504200'),
'gelo':('fws_gelo'),
'kulr':('fws_kulr'),
'malr':('fws_malr'),
'nclo':('fws_nclo'),
'newhalen river':('fws_newhalen river'),
'oslr':('fws_oslr'),
'oslr2':('fws_oslr2'),
'pulo':('fws_pulo'),
'pulr':('fws_pulr'),
'sllr':('fws_sllr'),
'tolo':('fws_tolo'),
'tolr':('fws_tolr'),
'welr':('fws_welr'),
'welr2':('fws_welr2'),
'571005154134600':('571005154134600'),
'571221154040300':('571221154040300'),
'571343154244900':('571343154244900'),
'572656154082400':('572656154082400'),
'fws_kdk_aforv01':('fws_kdk_aforv01'),
'fws_kdk_busrv01':('fws_kdk_busrv01'),
'fws_long lake creek':('fws_long lake creek'),
'fws_tanada creek':('fws_tanada creek'),
'kdk_akacr01':('kdk_akacr01'),
'kdk_akacr02':('kdk_akacr02'),
'kdk_ayarv03':('kdk_ayarv03'),
'kdk_cancr01':('kdk_cancr01'),
'kdk_cancr02':('kdk_cancr02'),
'kdk_cascr01':('kdk_cascr01'),
'kdk_concr01':('kdk_concr01'),
'kdk_eftrv01':('kdk_eftrv01'),
'kdk_falcr01':('kdk_falcr01'),
'kdk_falcr02':('kdk_falcr02'),
'kdk_meacr01':('kdk_meacr01'),
'kdk_omarv01':('kdk_omarv01'),
'kdk_pincr01':('kdk_pincr01'),
'kdk_pincr02':('kdk_pincr02'),
'kdk_relrv01':('kdk_relrv01'),
'kdk_soucr01':('kdk_soucr01'),
'bm1':('bm1'),
'bm10':('bm10'),
'bm11':('bm11'),
'bm12':('bm12'),
'bm13':('bm13'),
'bm14':('bm14'),
'bm2':('bm2'),
'bm3':('bm3'),
'bm4':('bm4'),
'bm5':('bm5'),
'bm6':('bm6'),
'bm7':('bm7'),
'bm8':('bm8'),
'bm9':('bm9'),
'kwf1':('kwf1'),
'kwf2':('kwf2'),
'kwf3':('kwf3'),
'kdk_bigcr01':('kdk_bigcr01'),
'kdk_karrv02':('kdk_karrv02'),
'lsarc':('lsarc'),
'lscoa':('lscoa'),
'lscoh':('lscoh'),
'lsgov':('lsgov'),
'lslak':('lslak'),
'lslak7':('lslak7'),
'lslil':('lslil10'),
'lsmoo1':('lsmoo1'),
'lsnlt1':('lsnlt10'),
'lspap':('lspap'),
'lsr100':('lsr100'),
'lsr103':('lsr103'),
'lsr112.5':('lsr106'),
'lsr106':('lsr106'),
'lsr112':('lsr112'),
'lsr112.2':('lsr112.2'),
'lsr112.4':('lsr112.4'),
'lsr28':('lsr28'),
'lsr28.3':('lsr28.3'),
'lsr33':('lsr33'),
'lsr33.1':('lsr33.1'),
'lsr33.8':('lsr33.8'),
'lsr47':('lsr47'),
'lsr48.1':('lsr48.1'),
'lsr48.3':('lsr48.3'),
'lsr59':('lsr59'),
'lsr63.1':('lsr63.1'),
'lsr63.4':('lsr63.4'),
'lsr67':('lsr67'),
'lsr73':('lsr73'),
'lsr73.1':('lsr73.1'),
'lsr73.2':('lsr73.2'),
'lsr87':('lsr87'),
'lsr89':('lsr89'),
'lsr93lb':('lsr93'),
'lsswi1':('lsswi1'),
'lstrb33':('lstrb33'),
'lstrb36':('lstrb36'),
'lstrb88':('lstrb88'),
'lstrb97':('lstrb97'),
'katm_idavc_stream_water':('nps_katm_idavc_stream_water'),
'katm_lbrooo_lvl':('nps_katm_lbrooo'),
'katm_margc_stream_water':('nps_katm_margc_stream_water'),
'katm_naknlo_lvl':('nps_katm_naknlo'),
'katm_savor_stream_water':('nps_katm_savor_stream_water'),
'katm_upatc_stream_water':('nps_katm_upatc_stream_water'),
'lacl_kijilo_lvl':('nps_lacl_kijilo'),
'lacl_lclaro_lvl':('nps_lacl_lclaro'),
'lacl_tazir_stream_water':('nps_lacl_tazir_stream_water'),
'lacl_tlikr_stream_water':('nps_lacl_tlikr_stream_water'),
'nps_chulitna_siteb':('nps_chulitna_siteb'),
'nps_hardenburg_bay':('nps_hardenburg_bay'),
'nps_little_kijik_river_dan':('nps_little_kijik_river_dan'),
'nps_newhalen_river':('nps_newhalen_river'),
'nps_six_mile_outlet':('nps_six_mile_outlet'),
'caribou creek':('nps_caribou creek'),
'crystal creek':('nps_crystal creek'),
'gilahina river':('nps_gilahina river'),
'lakina river':('nps_lakina river'),
'long lake creek':('nps_long lake creek'),
'rock creek wrst':('nps_rock creek wrst'),
'rufus creek':('nps_rufus creek'),
'nv_eyak_hartney creek':('nv_eyak_hartney creek'),
'nv_eyak_heney creek':('nv_eyak_heney creek'),
'pwscc_erb':('pwscc_erb'),
'pwscc_gilmour':('pwscc_gilmour'),
'pwscc_hogan':('pwscc_hogan'),
'pwscc_stockdale':('pwscc_stockdale'),
'usfs_18 mile':('usfs_18 mile'),
'usfs_18 mile middle fork':('usfs_18 mile middle fork'),
'usfs_18 mile west fork':('usfs_18 mile west fork'),
'usfs_24.9 mile creek':('usfs_24.9 mile creek'),
'usfs_25 mile':('usfs_25 mile'),
'usfs_bench creek':('usfs_bench creek'),
'usfs_blackhole creek':('usfs_blackhole creek'),
'usfs_cabin lake outlet':('usfs_cabin lake outlet'),
'usfs_center creek':('usfs_center creek'),
'usfs_chickaloon headwaters':('usfs_chickaloon headwaters'),
'usfs_crescent creek':('usfs_crescent creek'),
'usfs_daves creek':('usfs_daves creek'),
'usfs_eagle creek':('usfs_eagle creek'),
'usfs_east fork 18 mile':('usfs_east fork 18 mile'),
'usfs_erb creek':('usfs_erb creek'),
'usfs_eyak lake tributary':('usfs_eyak lake tributary'),
'usfs_hell\'s hole trib':('usfs_hell\'s hole trib'),
'usfs_hook point':('usfs_hook point'),
'usfs_ibeck creek-low':('usfs_ibeck creek-low'),
'usfs_ibeck creek-lower side channel':('usfs_ibeck creek-lower side channel'),
'usfs_jackpot river':('usfs_jackpot river'),
'usfs_juneau creek':('usfs_juneau creek'),
'usfs_koppen creek':('usfs_koppen creek'),
'usfs_little martin river':('usfs_little martin river'),
'usfs_martin lake- inlet':('usfs_martin lake- inlet'),
'usfs_middle arm eyak':('usfs_middle arm eyak'),
'usfs_olsen creek':('usfs_olsen creek'),
'usfs_pigot bay spawn channel':('usfs_pigot bay spawn channel'),
'usfs_power creek':('usfs_power creek'),
'usfs_quartz creek':('usfs_quartz creek'),
'usfs_resurrection creek':('usfs_resurrection creek'),
'usfs_rude river sc':('usfs_rude river sc'),
'usfs_salmon creek':('usfs_salmon creek'),
'usfs_sheep river':('usfs_sheep river'),
'usfs_shelter bay trib':('usfs_shelter bay trib'),
'usfs_solf lake fish pass':('usfs_solf lake fish pass'),
'usfs_solf lake outlet creek':('usfs_solf lake outlet creek'),
'usfs_stump lake outlet':('usfs_stump lake outlet'),
'15200280':('usgs_15200280'),
'15209700':('usgs_15209700'),
'15212000':('usgs_15212000'),
'15215900':('usgs_15215900'),
'15219000':('usgs_15219000'),
'15236900':('usgs_15236900'),
'15237030':('usgs_15237030'),
'15238450':('usgs_15238450'),
'15238984':('usgs_15238984'),
'15238986':('usgs_15238986'),
'15239070':('usgs_15239070'),
'15241600':('usgs_15241600'),
'15258000':('usgs_15258000'),
'15260001':('usgs_15260001'),
'15261000':('usgs_15261000'),
'15266110':('usgs_15266110'),
'15266300':('usgs_15266300'),
'15272380':('usgs_15272380'),
'15274000':('usgs_15274000'),
'15274600':('usgs_15274600'),
'15276000':('usgs_15276000'),
'15280999':('usgs_15280999'),
'15283700':('usgs_15283700'),
'15284000':('usgs_15284000'),
'15285000':('usgs_15285000'),
'15290000':('usgs_15290000'),
'15291000':('usgs_15291000'),
'15291700':('usgs_15291700'),
'15292100':('usgs_15292100'),
'15292400':('usgs_15292400'),
'15292700':('usgs_15292700'),
'15292780':('usgs_15292780'),
'15292800':('usgs_15292800'),
'15293200':('usgs_15293200'),
'15293700':('usgs_15293700'),
'15294005':('usgs_15294005'),
'15294080':('usgs_15294080'),
'15294345':('usgs_15294345'),
'15294350':('usgs_15294350'),
'15295700':('usgs_15295700'),
'15297475':('usgs_15297475'),
'15298040':('usgs_15298040'),
'15300100':('usgs_15300100'),
'15300250':('usgs_15300250'),
'15300270':('usgs_15300270'),
'15300300':('usgs_15300300'),
'15300320':('usgs_15300320'),
'15301500':('usgs_15301500'),
'15302000':('usgs_15302000'),
'15302200':('usgs_15302200'),
'15302250':('usgs_15302250'),
'15302300':('usgs_15302300'),
'15302320':('usgs_15302320'),
'15302812':('usgs_15302812'),
'uw_aleknagik bear creek':('uw_aleknagik bear creek'),
'uw_aleknagik big whitefish creek':('uw_aleknagik big whitefish creek'),
'uw_aleknagik eagle creek':('uw_aleknagik eagle creek'),
'uw_aleknagik hansen creek':('uw_aleknagik hansen creek'),
'uw_aleknagik happy creek':('uw_aleknagik happy creek'),
'uw_aleknagik ice creek':('uw_aleknagik ice creek'),
'uw_aleknagik mission creek':('uw_aleknagik mission creek'),
'uw_aleknagik pfifer creek':('uw_aleknagik pfifer creek'),
'uw_aleknagik silver salmon creek':('uw_aleknagik silver salmon creek'),
'uw_aleknagik yako creek':('uw_aleknagik yako creek'),
'uw_beverley hope creek':('uw_beverley hope creek'),
'uw_beverley moose creek':('uw_beverley moose creek'),
'uw_beverley uno creek':('uw_beverley uno creek'),
'uw_kulik grant river':('uw_kulik grant river'),
'uw_kulik k-3 creek':('uw_kulik k-3 creek'),
'uw_kulik kulik creek':('uw_kulik kulik creek'),
'uw_little togiak c creek':('uw_little togiak c creek'),
'uw_little togiak creek':('uw_little togiak creek'),
'uw_nerka allah creek':('uw_nerka allah creek'),
'uw_nerka bear creek':('uw_nerka bear creek'),
'uw_nerka berm creek':('uw_nerka berm creek'),
'uw_nerka cabin creek':('uw_nerka cabin creek'),
'uw_nerka chamee creek':('uw_nerka chamee creek'),
'uw_nerka cottonwood creek':('uw_nerka cottonwood creek'),
'uw_nerka elva creek':('uw_nerka elva creek'),
'uw_nerka fenno creek':('uw_nerka fenno creek'),
'uw_nerka hidden lake creek':('uw_nerka hidden lake creek'),
'uw_nerka joe creek':('uw_nerka joe creek'),
'uw_nerka kema creek':('uw_nerka kema creek'),
'uw_nerka lynx creek':('uw_nerka lynx creek'),
'uw_nerka lynx creek cold tributary':('uw_nerka lynx creek cold tributary'),
'uw_nerka n4 creek':('uw_nerka n4 creek'),
'uw_nerka pick creek':('uw_nerka pick creek'),
'uw_nerka rainbow creek':('uw_nerka rainbow creek'),
'uw_nerka sam creek':('uw_nerka sam creek'),
'uw_nerka seventh creek':('uw_nerka seventh creek'),
'uw_nerka stovall creek':('uw_nerka stovall creek'),
'uw_nerka teal creek':('uw_nerka teal creek'),
'uw_agulowak river':('uw_agulowak river'),
'uw_agulukpak river':('uw_agulukpak river'),
'uw_aleknagik sunshine creek':('uw_aleknagik sunshine creek'),
'uw_nerka little togiak river':('uw_nerka little togiak river'),
'uw_nerka lynx lake tributary':('uw_nerka lynx lake tributary'),
'uw_nerka beaver creek':('uw_nerka beaver creek'),
'uw_nerka bug creek':('uw_nerka bug creek'),
'nerka pike creek':('uw_nerka pike creek'),
'uw_nerka sixth creek':('uw_nerka sixth creek'),
'uw_beverley silverhorn creek':('uw_beverley silverhorn creek'),
'uw_aleknagik squaw creek':('uw_aleknagik squaw creek'),
'uw_aleknagik youth creek':('uw_aleknagik youth creek')
}
idDict
# Out:
# {'akbb-011': 'accs_akbb-011',
#  'akbb-020': 'accs_akbb-020',
#  'akbb-028': 'accs_akbb-028',
#  'akbb-029': 'accs_akbb-029',
#  'akbb-040': 'accs_akbb-040',
#  'ilbig01': 'accs_ilbig01',
#  'iltaz02': 'accs_iltaz02',
#  'iltnr19': 'accs_iltnr19',
#  'mubon10': 'accs_mubon10',
#  'muekm23': 'accs_muekm23',
#  'musfk01': 'accs_musfk01',
#  'mussm15': 'accs_mussm15',
#  'mustu17': 'accs_mustu17',
#  'mutsk02': 'accs_mutsk02',
#  'mutsk09': 'accs_mutsk09',
#  'kdk_ayarv01': 'kdk_ayarv01',
#  'kdk_busrv01': 'kdk_busrv01',
#  'kdk_doscr01': 'kdk_doscr01',
#  'kdk_doscr02': 'kdk_doscr02',
#  'kdk_karrv01': 'kdk_karrv01',
#  'kdk_olgcr01a': 'kdk_olgcr01a',
#  'apu1': 'apu1',
#  'apu10': 'apu10',
#  'apu11': 'apu11',
#  'apu12': 'apu12',
#  'apu2': 'apu2',
#  'apu3': 'apu3',
#  'apu5': 'apu5',
#  'apu6': 'apu6',
#  'apu7': 'apu7',
#  'apu8': 'apu8',
#  'apu9': 'apu9',
#  'ar2': 'ar2',
#  'cik1': 'cik1',
#  'cik2': 'cik2',
#  'cik3': 'cik3',
#  'cik4': 'cik4',
#  'cik6': 'cik6',
# ...

# %% [markdown]
# ### Check Spatial Data against relational ID list

# %%
# Fields to be queried and updated
fields = ['SiteID']
# Lists to store records that match/missing from idDict
missing = []
matches = []

in_dat = r"D:\\GIS\\AKSSF_land_met\\AKSSF_land_met.gdb\\all_sites_sj_merge"
c=0
b=0
with arcpy.da.SearchCursor(in_dat,fields) as cur:
    for row in cur:
        key = row[0].lower()
        #print(key)
        if key in idDict:
            print(f'{c}. {row[0]} will be changed to {idDict[key]}')
            matches.append(row[0])
            c+=1
        else:
            print(f'{b}. {row[0]} not in idDict and will not be updated')
            missing.append(row[0])
            b+=1
    del(cur)
del(row)

print (f'Total updates = {c}')
print (f'Total unrelated records = {b}')
print(f' Total records of input dataset = {c+b}')
print(f'{missing}')
# Out:
# 0. APU1 will be changed to apu1
# 1. APU10 will be changed to apu10
# 2. APU11 will be changed to apu11
# 3. APU12 will be changed to apu12
# 4. APU2 will be changed to apu2
# 5. APU3 will be changed to apu3
# 6. APU5 will be changed to apu5
# 7. APU6 will be changed to apu6
# 8. APU7 will be changed to apu7
# 9. APU8 will be changed to apu8
# 10. APU9 will be changed to apu9
# 11. AR2 will be changed to ar2
# 12. CIK1 will be changed to cik1
# 13. CIK2 will be changed to cik2
# 14. CIK3 will be changed to cik3
# 15. CIK4 will be changed to cik4
# 16. CIK6 will be changed to cik6
# 17. CIK7 will be changed to cik7
# 18. CIK8 will be changed to cik8
# 19. COTT-A will be changed to cott-a
# 20. COTT-C will be changed to cott-c
# 21. COTT-W will be changed to cott-w
# 22. NANC will be changed to nanc
# 23. NANC-44-L will be changed to nanc-44-l
# 24. NANC-44-M will be changed to nanc-44-m
# 25. NANC-44-U will be changed to nanc-44-u
# 26. PJ Lower will be changed to pj lower
# ...

# %% [markdown]
# ### Populate new site ID field using relational Dictionary

# %%
# Fields to be queried and updated
fields = ['SiteID', 'ts_id_dm','cat_ID_con']
# Lists to store records that match/missing from idDict
missing = []
matches = []

in_dat = r"D:\\GIS\\AKSSF_land_met\\AKSSF_land_met.gdb\\all_sites_sj_merge"
#arcpy.AddField_management(in_dat,'ts_id_dm','TEXT')
c=0
b=0
with arcpy.da.UpdateCursor(in_dat,fields) as cur:
    for row in cur:
        key = row[0].lower()
        if key in idDict:
            matches.append(row[0])
            ts_id = idDict[key]
            row[1] = ts_id
            print(f'{key}({row[2]}) has ts_id = {idDict[key]}')
            c+=1
        else:
            print(f'{key} ({row[2]}) has no ts_id')
            missing.append(row[0])
            b+=1
        cur.updateRow(row)
    del(row)
del(cur)
print (f'Total updates = {c}')
print (f'Total unrelated records = {b}')
print(f'{missing}')
# Out:
# apu1(Cook_Inlet_75004300004192) has ts_id = apu1
# apu10(Cook_Inlet_75004300004192) has ts_id = apu10
# apu11(Cook_Inlet_75004300004304) has ts_id = apu11
# apu12(Cook_Inlet_75004300005245) has ts_id = apu12
# apu2(Cook_Inlet_75004300003171) has ts_id = apu2
# apu3(Cook_Inlet_75004300006312) has ts_id = apu3
# apu5(Cook_Inlet_75004300002142) has ts_id = apu5
# apu6(Cook_Inlet_75004300007324) has ts_id = apu6
# apu7(Cook_Inlet_75004300001288) has ts_id = apu7
# apu8(Cook_Inlet_75004300002332) has ts_id = apu8
# apu9(Cook_Inlet_75004300004254) has ts_id = apu9
# ar2(Cook_Inlet_75004300004341) has ts_id = ar2
# cik1(Cook_Inlet_75004300000100) has ts_id = cik1
# cik2(Cook_Inlet_75004300002142) has ts_id = cik2
# cik3(Cook_Inlet_75004300002289) has ts_id = cik3
# cik4(Cook_Inlet_75004300005303) has ts_id = cik4
# cik6(Cook_Inlet_75004300006376) has ts_id = cik6
# cik7(Cook_Inlet_75004300000311) has ts_id = cik7
# cik8(Cook_Inlet_75004300004452) has ts_id = cik8
# ...

# %%
import arcpy
import pandas as pd
print(in_dat)
sitemerge_df = pd.DataFrame()
fields = [f.name for f in arcpy.ListFields(in_dat)]
print(fields)
# Out:
# D:\\GIS\\AKSSF_land_met\\AKSSF_land_met.gdb\\all_sites_sj_merge
# ['OBJECTID', 'Shape', 'SiteID', 'Agnc_ID', 'SourcNm', 'Wtrbdy_n', 'Verified', 'Comments', 'DM_Notes', 'Region', 'dist_coast_km', 'NHDPlusID', 'SourceFC', 'GridCode', 'AreaSqKm', 'VPUID', 'cat_ID', 'cat_ID_txt', 'cat_ID_con', 'catID', 'MERGE_SRC', 'site_max_acc', 'site_acc_sqKm', 'Area_km2', 'PathLength', 'TerminalPa', 'ArbolateSu', 'StartFlag', 'AreaSqKm_1', 'LINKNO', 'DSContArea', 'USContArea', 'DOUTEND', 'DOUTSTART', 'area_diff', 'str_slope', 'str_ord', 'ds_dist_outlet', 'str_slope_dg', 'lat', 'lon', 'sp_ls', 'AWC_CODE', 'sa_sp_hab', 'sa_sp_count', 'ts_id_dm']

# %%
keepfields = ['SiteID', 'ts_id_dm','cat_ID_con','region', 'area_diff', 'lat', 'lon', 'site_max_acc', 'site_acc_sqKm', 'Area_km2', 'str_slope','str_slope_dg',
          'str_ord','dist_coast_km', 'ds_dist_outlet','sp_ls', 'AWC_CODE']

sitesmerge_arr = arcpy.da.TableToNumPyArray(in_dat, keepfields)
sitemerge_df = pd.DataFrame(sitesmerge_arr)
#sitemerge_df = sitemerge_df.set_index('cat_ID_con')

sitemerge_df
# Out:
#                           SiteID                     ts_id_dm  \
# 0                           APU1                         apu1
# 1                          APU10                        apu10
# 2                          APU11                        apu11
# 3                          APU12                        apu12
# 4                           APU2                         apu2
# ..                           ...                          ...
# 484               USFS_ERB Creek               usfs_erb creek
# 485  USFS_Solf Lake Outlet Creek  usfs_solf lake outlet creek
# 486                     15219000                usgs_15219000
# 487                     15236900                usgs_15236900
# 488                     15237030                usgs_15237030
#
#                      cat_ID_con                region  area_diff        lat  \
# 0     Cook_Inlet_75004300004192            Cook_Inlet   0.368275  59.772331
# ...

# %%
import os
#Export CSV to read into R
outdir = r"C:\Users\dwmerrigan\Documents\GitHub\AKSSF\data_preparation\sensitivity_drivers"
sj_outname = 'AKSSF_sites_sj_maxfac.csv'
arcpy.da.NumPyArrayToTable(sitesmerge_arr,os.path.join(outdir,sj_outname))
print('CSV export complete')
print('----------')
# Out:
# CSV export complete
# ----------
