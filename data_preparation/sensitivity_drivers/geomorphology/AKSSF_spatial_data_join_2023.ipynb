# %% [markdown]
# This script will be for linking the siteIDs to the catchment IDs - which are either NHDPlusIDs,
# gridcodes, or new catIDs made from the gridcodes for BB. This will give us a way to link the
# thermal sensitivity responses by year to the covariates. This script also includes code to
# check the watersheds. The watersheds are individual feature classes to avoid overlapping
# polygons so the best way to check they are correct is to 1) check that every siteID/catID
# has a watershed, and 2) check that the watershed area approximately matches the watershed
# area from the flow accumulation grid. They won't be exact for sites that are not close to
# the catchment outlet and could be quite different for very small watersheds in some cases.
#
# # Watershed Summaries
#
# 1. read in all watersheds feature classes
# 2. create a table with the NHDPlusID/catID of the watershed name, region, and watershed area
# 3. merge original point feature classes (inside and outside bb)
# 4. do a spatial join with merged catchments by region to get catID and region on the points dataset
# 5. clip to the region and save in each regional gdb
# 6. merge all point feature classes with siteIDs and catIDs into one table
# 7. join the watershed area from the watershed fcs to the points table using the catID
# NOT DONE and not sure we need it: 8. join the watershed area from the fac grid to the points table using the catID
# 9. compare the results to ensure that watersheds have been created correctly

# %%
import arcpy, os
arcpy.env.overwriteOutput = True

# Path to create output folder/gdb
temppath = r"D:\\GIS\\sites_outputs_20230523\\" # Output folder
dirname = 'AKSSF_land_met_2023'
tempgdbname = 'AKSSF_land_met_2023.gdb'
temp_dir = os.path.join(temppath, dirname)

# Create temporary working gdb
if not arcpy.Exists(temp_dir):
    os.makedirs(temp_dir)
else:
    print('Working Folder already created...', temp_dir)

outcheck = os.path.join(temp_dir, tempgdbname)

if arcpy.Exists(outcheck):
    print ('Output location already exists', outcheck)
    outgdb = outcheck
if not arcpy.Exists(outcheck):
    print('Creating output GDB')
    tempgdb = arcpy.CreateFileGDB_management(temp_dir,tempgdbname)
    print ('Output geodatabase created at', outcheck)
    outgdb = tempgdb.getOutput(0)
# Out:
# Working Folder already created... D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023
# Output location already exists D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb

# %%
# steps 1 and 2

import arcpy,sys, os, time, datetime
import pandas as pd

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
regions = ["Kodiak", "Copper_River", "Prince_William_Sound", "Cook_Inlet", "Bristol_Bay"]
#regions = ['Copper_River', 'Cook_Inlet']
wtdList = []

for region in regions:
    c=1
    local_gdb = "D:\\GIS\\AKSSF\\" + region + "\\" + region + ".gdb\\Watersheds"
    arcpy.env.workspace = local_gdb
    wtds = arcpy.ListFeatureClasses()
    print(region + ": " + str(len(wtds)) + " watersheds")
    print('----------')
    for wtd in wtds:
        wtdName = wtd[4:]
        #print("Starting wtd: " + wtdName)
        wtdPath = os.path.join(arcpy.env.workspace, wtd)
        field_names = [f.name for f in arcpy.ListFields(wtdPath)]
        #print(field_names)
        if "Area_km2" in field_names:
            print("Area already calculated")
        else:
            arcpy.AddField_management(wtdPath, "Area_km2", "DOUBLE")
            expression1 = "{0}".format("!SHAPE.area@SQUAREKILOMETERS!")
            arcpy.CalculateField_management(wtdPath, "Area_km2", expression1, "PYTHON", )
        if "cat_ID" in field_names:
            print("cat_ID field exists")
        else:
            print('Adding cat_ID field')
            arcpy.AddField_management(wtdPath, "cat_ID", "DOUBLE")
            arcpy.CalculateField_management(wtdPath, "cat_ID", wtdName, "PYTHON")
        wtdArea = [row[0] for row in arcpy.da.SearchCursor(wtdPath, ['Area_km2'])]
        print(f"{c}. {wtdName}: " + str(wtdArea))
        wtdList.append({'Region': region, 'cat_ID': {wtdName}, 'Area_km2': wtdArea})
        c+=1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')
# Out:
# Kodiak: 28 watersheds
# ----------
# Area already calculated
# cat_ID field exists
# 1. 48267: [80.5581]
# Area already calculated
# cat_ID field exists
# 2. 49617: [294.1329]
# Area already calculated
# cat_ID field exists
# 3. 50197: [49.0722]
# Area already calculated
# cat_ID field exists
# 4. 64593: [65.5676]
# Area already calculated
# cat_ID field exists
# 5. 72144: [4.2088]
# Area already calculated
# cat_ID field exists
# 6. 76954: [30.8766]
# Area already calculated
# cat_ID field exists
# 7. 77794: [54.7985]
# Area already calculated
# cat_ID field exists
# 8. 90346: [7.5286]
# Area already calculated
# cat_ID field exists
# 9. 93176: [10.5872]
# Area already calculated
# cat_ID field exists
# 10. 94216: [9.5218]
# Area already calculated
# cat_ID field exists
# 11. 97276: [25.1611]
# Area already calculated
# cat_ID field exists
# 12. 99516: [15.1699]
# Area already calculated
# cat_ID field exists
# 13. 100826: [26.9231]
# Area already calculated
# cat_ID field exists
# 14. 101556: [25.3449]
# Area already calculated
# cat_ID field exists
# 15. 103096: [52.8504]
# Area already calculated
# cat_ID field exists
# 16. 103196: [69.6273]
# Area already calculated
# cat_ID field exists
# 17. 103296: [63.8678]
# Area already calculated
# cat_ID field exists
# 18. 103456: [64.8608]
# Area already calculated
# cat_ID field exists
# 19. 103496: [58.428]
# Area already calculated
# cat_ID field exists
# 20. 106626: [184.9214]
# Area already calculated
# cat_ID field exists
# 21. 106676: [185.1191]
# Area already calculated
# cat_ID field exists
# 22. 107796: [431.4948]
# Area already calculated
# cat_ID field exists
# 23. 107816: [467.6201]
# Area already calculated
# cat_ID field exists
# 24. 108356: [519.8356]
# Area already calculated
# cat_ID field exists
# 25. 128685: [103.3893]
# Area already calculated
# cat_ID field exists
# 26. 129955: [277.461]
# Area already calculated
# cat_ID field exists
# 27. 130295: [430.8143]
# Area already calculated
# cat_ID field exists
# 28. 130735: [605.336]
# Copper_River: 28 watersheds
# ----------
# Area already calculated
# cat_ID field exists
# 1. 75019800000406: [7.35572498100007]
# Area already calculated
# cat_ID field exists
# 2. 75019800010313: [562.020949827]
# Area already calculated
# cat_ID field exists
# 3. 75019800014348: [35.1819750030002]
# Area already calculated
# cat_ID field exists
# 4. 75019800001957: [12.75060003825]
# Area already calculated
# cat_ID field exists
# 5. 75019800019692: [1623.22927529275]
# Area already calculated
# cat_ID field exists
# 6. 75019600118138: [4551.255525077]
# Area already calculated
# cat_ID field exists
# 7. 75019700004190: [370.47150009425]
# Area already calculated
# cat_ID field exists
# 8. 75019700004084: [33.5466249777501]
# Area already calculated
# cat_ID field exists
# 9. 75019700017692: [700.42457513925]
# Area already calculated
# cat_ID field exists
# 10. 75019700001794: [141.764799868]
# Area already calculated
# cat_ID field exists
# 11. 75019700003889: [28.2315499447503]
# Area already calculated
# cat_ID field exists
# 12. 75003900062338: [51100.7862998642]
# Area already calculated
# cat_ID field exists
# 13. 75003900033524: [54.0521499752501]
# Area already calculated
# cat_ID field exists
# 14. 75003900054316: [52.1643999492501]
# Area already calculated
# cat_ID field exists
# 15. 75003900055039: [3.44030003900001]
# Area already calculated
# cat_ID field exists
# 16. 75003900023942: [8.0190249755]
# Area already calculated
# cat_ID field exists
# 17. 75003900058380: [5.2301000194999]
# Area already calculated
# cat_ID field exists
# 18. 75003900028507: [2.12479999075003]
# Area already calculated
# cat_ID field exists
# 19. 75003900027489: [20.9082749335002]
# Area already calculated
# cat_ID field exists
# 20. 75003900044936: [5.18647501100007]
# Area already calculated
# cat_ID field exists
# 21. 75003900023855: [0.764774991000045]
# Area already calculated
# cat_ID field exists
# 22. 75003900044738: [6.04239994075009]
# Area already calculated
# cat_ID field exists
# 23. 75003900055694: [0.210325000999973]
# Area already calculated
# cat_ID field exists
# 24. 75003900023674: [3.88814998624989]
# Area already calculated
# cat_ID field exists
# 25. 75003900062264: [22.1521251559997]
# Area already calculated
# cat_ID field exists
# 26. 75003900055316: [7.33369992075021]
# Area already calculated
# cat_ID field exists
# 27. 75003900039073: [5.76037498350005]
# Area already calculated
# cat_ID field exists
# 28. 75003900027771: [1.61012501325003]
# Prince_William_Sound: 20 watersheds
# ----------
# Area already calculated
# cat_ID field exists
# 1. 18457: [12.6534]
# Area already calculated
# cat_ID field exists
# 2. 26464: [4.5097]
# Area already calculated
# cat_ID field exists
# 3. 28086: [4.2285]
# Area already calculated
# cat_ID field exists
# 4. 29854: [18.2419]
# Area already calculated
# cat_ID field exists
# 5. 30884: [8.4223]
# Area already calculated
# cat_ID field exists
# 6. 31865: [0.8897]
# Area already calculated
# cat_ID field exists
# 7. 36645: [3.5947]
# Area already calculated
# cat_ID field exists
# 8. 37815: [5.2671]
# Area already calculated
# cat_ID field exists
# 9. 38993: [3.1686]
# Area already calculated
# cat_ID field exists
# 10. 40285: [12.3775]
# Area already calculated
# cat_ID field exists
# 11. 41515: [5.3127]
# Area already calculated
# cat_ID field exists
# 12. 42563: [12.2628]
# Area already calculated
# cat_ID field exists
# 13. 43055: [15.2785]
# Area already calculated
# cat_ID field exists
# 14. 43185: [23.9529]
# Area already calculated
# cat_ID field exists
# 15. 43383: [25.5571]
# Area already calculated
# cat_ID field exists
# 16. 43933: [32.3575]
# Area already calculated
# cat_ID field exists
# 17. 43973: [16.6989]
# Area already calculated
# cat_ID field exists
# 18. 44553: [50.2923]
# Area already calculated
# cat_ID field exists
# 19. 46055: [2.7634]
# Area already calculated
# cat_ID field exists
# 20. 46513: [472.5486]
# Cook_Inlet: 240 watersheds
# ----------
# Area already calculated
# cat_ID field exists
# 1. 75004300006312: [154.306524975027]
# Area already calculated
# cat_ID field exists
# 2. 75004300001906: [91.870175120765]
# Area already calculated
# cat_ID field exists
# 3. 75004300000100: [28.961324890473]
# Area already calculated
# cat_ID field exists
# 4. 75004300004983: [15.2613751159444]
# Area already calculated
# cat_ID field exists
# 5. 75004300004332: [330.1240747626]
# Area already calculated
# cat_ID field exists
# 6. 75004300006239: [56.0308501025738]
# Area already calculated
# cat_ID field exists
# 7. 75004300004304: [321.79309986178]
# Area already calculated
# cat_ID field exists
# 8. 75004300002332: [310.727624846888]
# Area already calculated
# cat_ID field exists
# 9. 75004300005437: [9.34964989214677]
# Area already calculated
# cat_ID field exists
# 10. 75004300003464: [39.05965002492]
# Area already calculated
# cat_ID field exists
# 11. 75004300005171: [8.04862502289959]
# Area already calculated
# cat_ID field exists
# 12. 75004300004701: [154.661600009603]
# Area already calculated
# cat_ID field exists
# 13. 75004300005303: [96.2434001069572]
# Area already calculated
# cat_ID field exists
# 14. 75004300006440: [3.55284995515247]
# Area already calculated
# cat_ID field exists
# 15. 75004300004254: [347.268774828552]
# Area already calculated
# cat_ID field exists
# 16. 75004300001207: [14.9358500208013]
# Area already calculated
# cat_ID field exists
# 17. 75004300005245: [177.062124937249]
# Area already calculated
# cat_ID field exists
# 18. 75004300000311: [51.8118499666333]
# Area already calculated
# cat_ID field exists
# 19. 75004300008012: [59.4149499598852]
# Area already calculated
# cat_ID field exists
# 20. 75004300004192: [581.778649740426]
# Area already calculated
# cat_ID field exists
# 21. 75004300007324: [89.0440250295134]
# Area already calculated
# cat_ID field exists
# 22. 75004300001162: [183.04649992364]
# Area already calculated
# cat_ID field exists
# 23. 75004300004217: [131.949049938799]
# Area already calculated
# cat_ID field exists
# 24. 75004300002207: [398.294124805145]
# Area already calculated
# cat_ID field exists
# 25. 75004300003409: [5.98590004553863]
# Area already calculated
# cat_ID field exists
# 26. 75004300002142: [55.3421999378382]
# Area already calculated
# cat_ID field exists
# 27. 75004300002314: [1.06192495338125]
# Area already calculated
# cat_ID field exists
# 28. 75004300003171: [8.91457499826932]
# Area already calculated
# cat_ID field exists
# 29. 75004300000101: [10.2498250040996]
# Area already calculated
# cat_ID field exists
# 30. 75004300005352: [58.9958500208178]
# Area already calculated
# cat_ID field exists
# 31. 75004300000856: [156.919096275364]
# Area already calculated
# cat_ID field exists
# 32. 75004300004341: [268.456549910218]
# Area already calculated
# cat_ID field exists
# 33. 75004300002289: [8.16919998404097]
# Area already calculated
# cat_ID field exists
# 34. 75004300007331: [69.5340248327356]
# Area already calculated
# cat_ID field exists
# 35. 75004300006376: [41.6300998783105]
# Area already calculated
# cat_ID field exists
# 36. 75004300002278: [4.34527498661142]
# Area already calculated
# cat_ID field exists
# 37. 75004300002352: [0.572200021105535]
# Area already calculated
# cat_ID field exists
# 38. 75004300001210: [3.64997506843073]
# Area already calculated
# cat_ID field exists
# 39. 75004300004452: [161.045675049111]
# Area already calculated
# cat_ID field exists
# 40. 75004300000105: [117.520799971326]
# Area already calculated
# cat_ID field exists
# 41. 75004300006071: [213.276349813864]
# Area already calculated
# cat_ID field exists
# 42. 75004300004324: [570.917724990867]
# Area already calculated
# cat_ID field exists
# 43. 75004300001288: [41.7343749989578]
# Area already calculated
# cat_ID field exists
# 44. 75004300006013: [44.808675109818]
# Area already calculated
# cat_ID field exists
# 45. 75004400004829: [125.552424951494]
# Area already calculated
# cat_ID field exists
# 46. 75004400000576: [278.267925423806]
# Area already calculated
# cat_ID field exists
# 47. 75004400006041: [645.732999907538]
# Area already calculated
# cat_ID field exists
# 48. 75004400010402: [47.3331250785339]
# Area already calculated
# cat_ID field exists
# 49. 75004400008856: [87.7250730577964]
# Area already calculated
# cat_ID field exists
# 50. 75004400010754: [163.908949833661]
# Area already calculated
# cat_ID field exists
# 51. 75004400010810: [33.9592499650158]
# Area already calculated
# cat_ID field exists
# 52. 75004400002950: [141.631200096825]
# Area already calculated
# cat_ID field exists
# 53. 75004400009144: [66.6914999458208]
# Area already calculated
# cat_ID field exists
# 54. 75004400006357: [83.1506250499538]
# Area already calculated
# cat_ID field exists
# 55. 75004400007385: [118.993599857851]
# Area already calculated
# cat_ID field exists
# 56. 75004400007948: [131.659275112825]
# Area already calculated
# cat_ID field exists
# 57. 75004400009261: [144.483024942008]
# Area already calculated
# cat_ID field exists
# 58. 75004400001510: [98.8227250647972]
# Area already calculated
# cat_ID field exists
# 59. 75004400007387: [96.0323499495381]
# Area already calculated
# cat_ID field exists
# 60. 75004400010320: [66.4171249875312]
# Area already calculated
# cat_ID field exists
# 61. 75004400001568: [352.446399319792]
# Area already calculated
# cat_ID field exists
# 62. 75004400008917: [126.562850055719]
# Area already calculated
# cat_ID field exists
# 63. 75004400001952: [1673.69265062306]
# Area already calculated
# cat_ID field exists
# 64. 75004400009919: [74.831224923946]
# Area already calculated
# cat_ID field exists
# 65. 75004400001498: [5158.83382470789]
# Area already calculated
# cat_ID field exists
# 66. 75004400011711: [360.566400535551]
# Area already calculated
# cat_ID field exists
# 67. 75004400003452: [15.3436497833864]
# Area already calculated
# cat_ID field exists
# 68. 75004400007388: [43.5565999900558]
# Area already calculated
# cat_ID field exists
# 69. 75004400000627: [410.589224966524]
# Area already calculated
# cat_ID field exists
# 70. 75004400003042: [682.138525136464]
# Area already calculated
# cat_ID field exists
# 71. 75004400002041: [83.9883502931417]
# Area already calculated
# cat_ID field exists
# 72. 75004400011322: [55.5205501032957]
# Area already calculated
# cat_ID field exists
# 73. 75004400001872: [101.07972507388]
# Area already calculated
# cat_ID field exists
# 74. 75004400009331: [124.138425040732]
# Area already calculated
# cat_ID field exists
# 75. 75004400009308: [67.6002000223301]
# Area already calculated
# cat_ID field exists
# 76. 75004400006846: [78.9342001912424]
# Area already calculated
# cat_ID field exists
# 77. 75004400003154: [3205.93695067461]
# Area already calculated
# cat_ID field exists
# 78. 75004400002951: [37.3352500025437]
# Area already calculated
# cat_ID field exists
# 79. 75004400009260: [143.811824939184]
# Area already calculated
# cat_ID field exists
# 80. 75000100000981: [109.983349958]
# Area already calculated
# cat_ID field exists
# 81. 75000100003094: [234.57054993775]
# Area already calculated
# cat_ID field exists
# 82. 75000100003947: [79.0551749225006]
# Area already calculated
# cat_ID field exists
# 83. 75000100002463: [319.489400008]
# Area already calculated
# cat_ID field exists
# 84. 75000100001919: [72.9444250159999]
# Area already calculated
# cat_ID field exists
# 85. 75000100004336: [80.870575001]
# Area already calculated
# cat_ID field exists
# 86. 75000100000004: [171.531024892]
# Area already calculated
# cat_ID field exists
# 87. 75000100000652: [323.050200045]
# Area already calculated
# cat_ID field exists
# 88. 75000100004200: [57.4192750037499]
# Area already calculated
# cat_ID field exists
# 89. 75000100002523: [182.2452501505]
# Area already calculated
# cat_ID field exists
# 90. 75000100000059: [35.9268251207499]
# Area already calculated
# cat_ID field exists
# 91. 75000400000173: [77.7938499320003]
# Area already calculated
# cat_ID field exists
# 92. 75000400009620: [5326.81112514375]
# Area already calculated
# cat_ID field exists
# 93. 75000400014405: [16.13084996975]
# Area already calculated
# cat_ID field exists
# 94. 75000400014403: [130.46237492]
# Area already calculated
# cat_ID field exists
# 95. 75000700036166: [16286.9933501912]
# Area already calculated
# cat_ID field exists
# 96. 75000700030756: [13362.7330504702]
# Area already calculated
# cat_ID field exists
# 97. 75000700032122: [2381.775150233]
# Area already calculated
# cat_ID field exists
# 98. 75000500009621: [407.1570000505]
# Area already calculated
# cat_ID field exists
# 99. 75000500011984: [99.8046998795003]
# Area already calculated
# cat_ID field exists
# 100. 75000500009975: [126.10624999525]
# Area already calculated
# cat_ID field exists
# 101. 75000500010609: [6528.89145008825]
# Area already calculated
# cat_ID field exists
# 102. 75000300025361: [5212.2290001505]
# Area already calculated
# cat_ID field exists
# 103. 75000600010189: [15794.3653997276]
# Area already calculated
# cat_ID field exists
# 104. 75000600030148: [169.87782500175]
# Area already calculated
# cat_ID field exists
# 105. 75000200008033: [359.15514994375]
# Area already calculated
# cat_ID field exists
# 106. 75000200002920: [375.46257499]
# Area already calculated
# cat_ID field exists
# 107. 75000200000411: [308.3031249575]
# Area already calculated
# cat_ID field exists
# 108. 75000200008551: [399.677524938]
# Area already calculated
# cat_ID field exists
# 109. 75000200007305: [62.550675013]
# Area already calculated
# cat_ID field exists
# 110. 75000200015657: [51.2484999730002]
# Area already calculated
# cat_ID field exists
# 111. 75000200003107: [413.550975164]
# Area already calculated
# cat_ID field exists
# 112. 75000200008009: [32.26387496725]
# Area already calculated
# cat_ID field exists
# 113. 75000200013536: [28668.7653250127]
# Area already calculated
# cat_ID field exists
# 114. 75000200015867: [395.61577508275]
# Area already calculated
# cat_ID field exists
# 115. 75000200010712: [17.9079750887497]
# Area already calculated
# cat_ID field exists
# 116. 75000200003070: [17.9918499105003]
# Area already calculated
# cat_ID field exists
# 117. 75000200006065: [381.50114999075]
# Area already calculated
# cat_ID field exists
# 118. 75000200010532: [304.51692498875]
# Area already calculated
# cat_ID field exists
# 119. 75000200005573: [376.6677001775]
# Area already calculated
# cat_ID field exists
# 120. 75000200005575: [394.67542509125]
# Area already calculated
# cat_ID field exists
# 121. 75000200018331: [1643.75800021975]
# Area already calculated
# cat_ID field exists
# 122. 75000200005504: [1189.41742503]
# Area already calculated
# cat_ID field exists
# 123. 75000200003013: [909.8220249955]
# Area already calculated
# cat_ID field exists
# 124. 75000200015680: [350.77669997725]
# Area already calculated
# cat_ID field exists
# 125. 75000200000416: [249.903524947001]
# Area already calculated
# cat_ID field exists
# 126. 75000200005413: [60.77080005775]
# Area already calculated
# cat_ID field exists
# 127. 75000200002930: [234.77997507375]
# Area already calculated
# cat_ID field exists
# 128. 75000200010359: [3.47834998424999]
# Area already calculated
# cat_ID field exists
# 129. 75000200010144: [49.4989500267498]
# Area already calculated
# cat_ID field exists
# 130. 75000200018266: [158.24125010125]
# Area already calculated
# cat_ID field exists
# 131. 75000200002753: [79.8248748232504]
# Area already calculated
# cat_ID field exists
# 132. 75000200015505: [59.4859748385005]
# Area already calculated
# cat_ID field exists
# 133. 75000200015584: [30.1823750190001]
# Area already calculated
# cat_ID field exists
# 134. 75000200002806: [1.60382500125002]
# Area already calculated
# cat_ID field exists
# 135. 75000200007853: [63.3565998197505]
# Area already calculated
# cat_ID field exists
# 136. 75000200018577: [85.9000749330003]
# Area already calculated
# cat_ID field exists
# 137. 75000200015695: [43.7374750602498]
# Area already calculated
# cat_ID field exists
# 138. 75000200013033: [1.9217500264999]
# Area already calculated
# cat_ID field exists
# 139. 75000200005075: [7.443249995]
# Area already calculated
# cat_ID field exists
# 140. 75000200007839: [159.187424854]
# Area already calculated
# cat_ID field exists
# 141. 75000200007958: [3.45362500474992]
# Area already calculated
# cat_ID field exists
# 142. 75000200013189: [95.2182750095002]
# Area already calculated
# cat_ID field exists
# 143. 75000200002934: [230.960400077]
# Area already calculated
# cat_ID field exists
# 144. 75000200018235: [2.86357498724999]
# Area already calculated
# cat_ID field exists
# 145. 75000200013258: [1.8278249932501]
# Area already calculated
# cat_ID field exists
# 146. 75000200018069: [5.73922495300004]
# Area already calculated
# cat_ID field exists
# 147. 75000200013187: [140.209200057]
# Area already calculated
# cat_ID field exists
# 148. 75000200007646: [10.0682000424999]
# Area already calculated
# cat_ID field exists
# 149. 75000200000010: [8.52552499399986]
# Area already calculated
# cat_ID field exists
# 150. 75000200013185: [140.052125074]
# Area already calculated
# cat_ID field exists
# 151. 75000200010344: [19.4881999770001]
# Area already calculated
# cat_ID field exists
# 152. 75000200010538: [179.7024500995]
# Area already calculated
# cat_ID field exists
# 153. 75000200010547: [140.33665006175]
# Area already calculated
# cat_ID field exists
# 154. 75000200005606: [8.33517499099995]
# Area already calculated
# cat_ID field exists
# 155. 75000200002554: [2.35274999724991]
# Area already calculated
# cat_ID field exists
# 156. 75000200017518: [44.7527249537502]
# Area already calculated
# cat_ID field exists
# 157. 75000200018332: [1567.7373502445]
# Area already calculated
# cat_ID field exists
# 158. 75000200015469: [43.576099995]
# Area already calculated
# cat_ID field exists
# 159. 75000200010540: [174.2213250835]
# Area already calculated
# cat_ID field exists
# 160. 75000200018806: [912.3345499465]
# Area already calculated
# cat_ID field exists
# 161. 75000200003094: [864.5141501375]
# Area already calculated
# cat_ID field exists
# 162. 75000200014914: [116.1069749895]
# Area already calculated
# cat_ID field exists
# 163. 75000200007639: [114.3665998495]
# Area already calculated
# cat_ID field exists
# 164. 75000200013266: [909.7959250045]
# Area already calculated
# cat_ID field exists
# 165. 75000200010391: [13.2891000005001]
# Area already calculated
# cat_ID field exists
# 166. 75000200015860: [42.6489498927501]
# Area already calculated
# cat_ID field exists
# 167. 75000200005503: [72.7732250432502]
# Area already calculated
# cat_ID field exists
# 168. 75000200000213: [69.9096248025005]
# Area already calculated
# cat_ID field exists
# 169. 75000200015782: [30.6506749537502]
# Area already calculated
# cat_ID field exists
# 170. 75000200011141: [165.465349959]
# Area already calculated
# cat_ID field exists
# 171. 75000200008051: [3.196350003]
# Area already calculated
# cat_ID field exists
# 172. 75000200013319: [363.563275237749]
# Area already calculated
# cat_ID field exists
# 173. 75000200007852: [72.8471498307505]
# Area already calculated
# cat_ID field exists
# 174. 75000200000465: [233.3975499965]
# Area already calculated
# cat_ID field exists
# 175. 75000200013237: [954.5713000085]
# Area already calculated
# cat_ID field exists
# 176. 75000200007870: [3.95524997025001]
# Area already calculated
# cat_ID field exists
# 177. 75000200000011: [6.29164998675002]
# Area already calculated
# cat_ID field exists
# 178. 75000200013953: [412.71709998875]
# Area already calculated
# cat_ID field exists
# 179. 75000200004615: [160.66304995925]
# Area already calculated
# cat_ID field exists
# 180. 75000200010148: [15.2259000322499]
# Area already calculated
# cat_ID field exists
# 181. 75000200013892: [85.6818249087504]
# Area already calculated
# cat_ID field exists
# 182. 75000200013179: [15.941324992]
# Area already calculated
# cat_ID field exists
# 183. 75000200002984: [942.15707498625]
# Area already calculated
# cat_ID field exists
# 184. 75000200007660: [453.9741500215]
# Area already calculated
# cat_ID field exists
# 185. 75000200005448: [236.65315002275]
# Area already calculated
# cat_ID field exists
# 186. 75000200018581: [803.402799845]
# Area already calculated
# cat_ID field exists
# 187. 75000200011336: [430.2868750425]
# Area already calculated
# cat_ID field exists
# 188. 75000200012999: [860.24374987975]
# Area already calculated
# cat_ID field exists
# 189. 75000200003732: [432.14192503]
# Area already calculated
# cat_ID field exists
# 190. 75000200008734: [20.1270249037503]
# Area already calculated
# cat_ID field exists
# 191. 75000200000021: [782.14647484125]
# Area already calculated
# cat_ID field exists
# 192. 75000200005532: [1203.4901249995]
# Area already calculated
# cat_ID field exists
# 193. 75000200018882: [550.02869988675]
# Area already calculated
# cat_ID field exists
# 194. 75000200005404: [42.30899999875]
# Area already calculated
# cat_ID field exists
# 195. 75000200015587: [24.7833999975001]
# Area already calculated
# cat_ID field exists
# 196. 75000200015319: [57.5390999147504]
# Area already calculated
# cat_ID field exists
# 197. 75000200015900: [1773.59767521775]
# Area already calculated
# cat_ID field exists
# 198. 75000200005077: [22.4859249792501]
# Area already calculated
# cat_ID field exists
# 199. 75000200008950: [345.21459982325]
# Area already calculated
# cat_ID field exists
# 200. 75000200015320: [546.64872494925]
# Area already calculated
# cat_ID field exists
# 201. 75000200012046: [16.8856250054998]
# Area already calculated
# cat_ID field exists
# 202. 75000200002162: [107.954649947]
# Area already calculated
# cat_ID field exists
# 203. 75000200011392: [17.7257250779997]
# Area already calculated
# cat_ID field exists
# 204. 75000200000278: [232.3140499125]
# Area already calculated
# cat_ID field exists
# 205. 75000200018259: [68.9904750749999]
# Area already calculated
# cat_ID field exists
# 206. 75000200005444: [304.1866749645]
# Area already calculated
# cat_ID field exists
# 207. 75000200018203: [28.326525091]
# Area already calculated
# cat_ID field exists
# 208. 75000200008110: [311.622500131]
# Area already calculated
# cat_ID field exists
# 209. 75000200018317: [59.9661000157497]
# Area already calculated
# cat_ID field exists
# 210. 75000200000949: [388.32754999175]
# Area already calculated
# cat_ID field exists
# 211. 75000200013249: [373.93840013575]
# Area already calculated
# cat_ID field exists
# 212. 75000200013010: [53.2871250202497]
# Area already calculated
# cat_ID field exists
# 213. 75000200000418: [305.90245010425]
# Area already calculated
# cat_ID field exists
# 214. 75000200002552: [3.57724996000007]
# Area already calculated
# cat_ID field exists
# 215. 75000200008508: [587.875574851]
# Area already calculated
# cat_ID field exists
# 216. 75000200007670: [3.96435001525006]
# Area already calculated
# cat_ID field exists
# 217. 75000200008676: [14.81074997225]
# Area already calculated
# cat_ID field exists
# 218. 75000200018667: [645.99639993125]
# Area already calculated
# cat_ID field exists
# 219. 75000200011572: [12.1452500882498]
# Area already calculated
# cat_ID field exists
# 220. 75000200011623: [12.7518749602502]
# Area already calculated
# cat_ID field exists
# 221. 75000200019765: [165.89392498525]
# Area already calculated
# cat_ID field exists
# 222. 75000200016095: [21.1075499407501]
# Area already calculated
# cat_ID field exists
# 223. 75000200014508: [209.836800004]
# Area already calculated
# cat_ID field exists
# 224. 75000200015883: [1745.84072519675]
# Area already calculated
# cat_ID field exists
# 225. 75000200014057: [9.68937496700011]
# Area already calculated
# cat_ID field exists
# 226. 75000200019263: [4.92087494900005]
# Area already calculated
# cat_ID field exists
# 227. 75000200003896: [305.410149972]
# Area already calculated
# cat_ID field exists
# 228. 75000200005619: [69.6610249480002]
# Area already calculated
# cat_ID field exists
# 229. 75000200003312: [658.739774982]
# Area already calculated
# cat_ID field exists
# 230. 75000200014207: [260.93259995525]
# Area already calculated
# cat_ID field exists
# 231. 75000200007927: [50138.586775259]
# Area already calculated
# cat_ID field exists
# 232. 75000200011034: [56.0562500654999]
# Area already calculated
# cat_ID field exists
# 233. 75000200015882: [1675.89852526975]
# Area already calculated
# cat_ID field exists
# 234. 75000200016094: [707.52427485075]
# Area already calculated
# cat_ID field exists
# 235. 75000200008452: [69.79484998675]
# Area already calculated
# cat_ID field exists
# 236. 75005300022831: [350.518224904666]
# Area already calculated
# cat_ID field exists
# 237. 75005300011378: [302.201700289278]
# Area already calculated
# cat_ID field exists
# 238. 75005400001203: [282.44622527767]
# Area already calculated
# cat_ID field exists
# 239. 75005400029139: [29.47359998857]
# Area already calculated
# cat_ID field exists
# 240. 75005400013272: [10.8415499649418]
# Bristol_Bay: 114 watersheds
# ----------
# Area already calculated
# cat_ID field exists
# 1. 1023044: [3265.2693]
# Area already calculated
# cat_ID field exists
# 2. 2041471: [1188.83394165891]
# Area already calculated
# cat_ID field exists
# 3. 2065755: [305.9274]
# Area already calculated
# cat_ID field exists
# 4. 2065914: [12.9698]
# Area already calculated
# cat_ID field exists
# 5. 2066924: [29.7025]
# Area already calculated
# cat_ID field exists
# 6. 2066955: [315.312]
# Area already calculated
# cat_ID field exists
# 7. 2067494: [62.7302]
# Area already calculated
# cat_ID field exists
# 8. 2068072: [5.1499]
# Area already calculated
# cat_ID field exists
# 9. 2068584: [93.536922261]
# Area already calculated
# cat_ID field exists
# 10. 2070402: [17.8413]
# Area already calculated
# cat_ID field exists
# 11. 2071934: [155.076111114]
# Area already calculated
# cat_ID field exists
# 12. 2072993: [16.4381]
# Area already calculated
# cat_ID field exists
# 13. 2073464: [331.712]
# Area already calculated
# cat_ID field exists
# 14. 2074424: [221.1778]
# Area already calculated
# cat_ID field exists
# 15. 2078232: [110.151911114]
# Area already calculated
# cat_ID field exists
# 16. 2078282: [112.105411114]
# Area already calculated
# cat_ID field exists
# 17. 2082373: [843.839377772]
# Area already calculated
# cat_ID field exists
# 18. 2082393: [844.595977772]
# Area already calculated
# cat_ID field exists
# 19. 2084713: [53.4479]
# Area already calculated
# cat_ID field exists
# 20. 2085642: [2665.491811147]
# Area already calculated
# cat_ID field exists
# 21. 2085962: [2864.098311147]
# Area already calculated
# cat_ID field exists
# 22. 2087913: [7592.46903735782]
# Area already calculated
# cat_ID field exists
# 23. 2088163: [8605.62943535774]
# Area already calculated
# cat_ID field exists
# 24. 2088253: [8669.17433535774]
# Area already calculated
# cat_ID field exists
# 25. 2088326: [492.0395]
# Area already calculated
# cat_ID field exists
# 26. 2088586: [269.6706]
# Area already calculated
# cat_ID field exists
# 27. 3023044: [148.7091]
# Area already calculated
# cat_ID field exists
# 28. 3024343: [6754.2341]
# Area already calculated
# cat_ID field exists
# 29. 3030955: [781.4748]
# Area already calculated
# cat_ID field exists
# 30. 3033666: [83.1925]
# Area already calculated
# cat_ID field exists
# 31. 3033956: [273.1076]
# Area already calculated
# cat_ID field exists
# 32. 3034126: [79.2503]
# Area already calculated
# cat_ID field exists
# 33. 4046617: [5.9778]
# Area already calculated
# cat_ID field exists
# 34. 4048046: [2.2256]
# Area already calculated
# cat_ID field exists
# 35. 4051055: [3.0883]
# Area already calculated
# cat_ID field exists
# 36. 4051056: [3.314]
# Area already calculated
# cat_ID field exists
# 37. 4051616: [3.2994]
# Area already calculated
# cat_ID field exists
# 38. 4052076: [5.3765]
# Area already calculated
# cat_ID field exists
# 39. 4054120: [25.8769]
# Area already calculated
# cat_ID field exists
# 40. 4054200: [176.4666]
# Area already calculated
# cat_ID field exists
# 41. 4055337: [9.0458]
# Area already calculated
# cat_ID field exists
# 42. 4059016: [7.0866]
# Area already calculated
# cat_ID field exists
# 43. 4059736: [11.9662]
# Area already calculated
# cat_ID field exists
# 44. 4060036: [9.1895]
# Area already calculated
# cat_ID field exists
# 45. 4061136: [9.1353]
# Area already calculated
# cat_ID field exists
# 46. 4063606: [17.4968]
# Area already calculated
# cat_ID field exists
# 47. 4063775: [6.779]
# Area already calculated
# cat_ID field exists
# 48. 4064055: [2.4938]
# Area already calculated
# cat_ID field exists
# 49. 4064845: [8.6642]
# Area already calculated
# cat_ID field exists
# 50. 4068584: [1.8667]
# Area already calculated
# cat_ID field exists
# 51. 4069455: [9.3439]
# Area already calculated
# cat_ID field exists
# 52. 4069495: [10.9117]
# Area already calculated
# cat_ID field exists
# 53. 4069586: [16.7362]
# Area already calculated
# cat_ID field exists
# 54. 4071036: [105.6871]
# Area already calculated
# cat_ID field exists
# 55. 4071256: [138.1613]
# Area already calculated
# cat_ID field exists
# 56. 4071625: [10.2876]
# Area already calculated
# cat_ID field exists
# 57. 4073375: [15.8738]
# Area already calculated
# cat_ID field exists
# 58. 4074184: [3.1412]
# Area already calculated
# cat_ID field exists
# 59. 4074505: [22.3844]
# Area already calculated
# cat_ID field exists
# 60. 4074726: [94.8666]
# Area already calculated
# cat_ID field exists
# 61. 4075225: [25.9738]
# Area already calculated
# cat_ID field exists
# 62. 4075474: [9.5446]
# Area already calculated
# cat_ID field exists
# 63. 4075715: [23.3416]
# Area already calculated
# cat_ID field exists
# 64. 4076505: [38.0412]
# Area already calculated
# cat_ID field exists
# 65. 4076575: [52.4802]
# Area already calculated
# cat_ID field exists
# 66. 4076675: [22.3564]
# Area already calculated
# cat_ID field exists
# 67. 4078235: [30.6554]
# Area already calculated
# cat_ID field exists
# 68. 4079234: [3.3111]
# Area already calculated
# cat_ID field exists
# 69. 4080045: [80.3923]
# Area already calculated
# cat_ID field exists
# 70. 4080875: [164.2842]
# Area already calculated
# cat_ID field exists
# 71. 4082225: [2.2765]
# Area already calculated
# cat_ID field exists
# 72. 4084145: [164.6464]
# Area already calculated
# cat_ID field exists
# 73. 4084351: [73.2784]
# Area already calculated
# cat_ID field exists
# 74. 4084915: [80.8575]
# Area already calculated
# cat_ID field exists
# 75. 4086815: [1528.3775]
# Area already calculated
# cat_ID field exists
# 76. 4087015: [1174.8091]
# Area already calculated
# cat_ID field exists
# 77. 4087224: [10.3069]
# Area already calculated
# cat_ID field exists
# 78. 4088675: [2216.1895]
# Area already calculated
# cat_ID field exists
# 79. 4088904: [13.5213]
# Area already calculated
# cat_ID field exists
# 80. 4089074: [20.2415]
# Area already calculated
# cat_ID field exists
# 81. 4089384: [10.8875]
# Area already calculated
# cat_ID field exists
# 82. 4089394: [10.9771]
# Area already calculated
# cat_ID field exists
# 83. 4089574: [15.4036]
# Area already calculated
# cat_ID field exists
# 84. 4091164: [35.998]
# Area already calculated
# cat_ID field exists
# 85. 4091424: [25.6329]
# Area already calculated
# cat_ID field exists
# 86. 4092244: [22.1608]
# Area already calculated
# cat_ID field exists
# 87. 4093084: [41.3073]
# Area already calculated
# cat_ID field exists
# 88. 4095301: [186.5479]
# Area already calculated
# cat_ID field exists
# 89. 4095374: [35.5411]
# Area already calculated
# cat_ID field exists
# 90. 4096064: [30.2231]
# Area already calculated
# cat_ID field exists
# 91. 4096454: [63.3384]
# Area already calculated
# cat_ID field exists
# 92. 4098114: [97.0252]
# Area already calculated
# cat_ID field exists
# 93. 4098704: [177.7584]
# Area already calculated
# cat_ID field exists
# 94. 4099594: [296.4068]
# Area already calculated
# cat_ID field exists
# 95. 4099694: [273.2782]
# Area already calculated
# cat_ID field exists
# 96. 4101123: [3929.443]
# Area already calculated
# cat_ID field exists
# 97. 4101274: [19.5802]
# Area already calculated
# cat_ID field exists
# 98. 4102124: [125.2901]
# Area already calculated
# cat_ID field exists
# 99. 4104574: [420.1106]
# Area already calculated
# cat_ID field exists
# 100. 4105204: [692.7912]
# Area already calculated
# cat_ID field exists
# 101. 4105594: [109.4471]
# Area already calculated
# cat_ID field exists
# 102. 4105844: [268.5621]
# Area already calculated
# cat_ID field exists
# 103. 4106904: [175.4414]
# Area already calculated
# cat_ID field exists
# 104. 4107464: [9400.3065]
# Area already calculated
# cat_ID field exists
# 105. 4115672: [906.4683]
# Area already calculated
# cat_ID field exists
# 106. 5008707: [162.345]
# Area already calculated
# cat_ID field exists
# 107. 5020796: [345.2735]
# Area already calculated
# cat_ID field exists
# 108. 5021476: [394.0384]
# Area already calculated
# cat_ID field exists
# 109. 5030363: [73.6221]
# Area already calculated
# cat_ID field exists
# 110. 5030704: [44.4566]
# Area already calculated
# cat_ID field exists
# 111. 5032474: [74.8338]
# Area already calculated
# cat_ID field exists
# 112. 5033094: [247.9377]
# Area already calculated
# cat_ID field exists
# 113. 5034893: [1332.0373]
# Area already calculated
# cat_ID field exists
# 114. 5038375: [452.8228]
# Process completed at 2023-05-23 15:32 (Elapsed time: 0:02:32)
# ----------

# %%
wtdDf = pd.DataFrame(wtdList)
print(wtdDf)
# Out:
#           Region     cat_ID     Area_km2
# 0         Kodiak    {48267}    [80.5581]
# 1         Kodiak    {49617}   [294.1329]
# 2         Kodiak    {50197}    [49.0722]
# 3         Kodiak    {64593}    [65.5676]
# 4         Kodiak    {72144}     [4.2088]
# ..           ...        ...          ...
# 425  Bristol_Bay  {5030704}    [44.4566]
# 426  Bristol_Bay  {5032474}    [74.8338]
# 427  Bristol_Bay  {5033094}   [247.9377]
# 428  Bristol_Bay  {5034893}  [1332.0373]
# 429  Bristol_Bay  {5038375}   [452.8228]
#
# [430 rows x 3 columns]

# %%
#merge watersheds into one feature class for each region

import arcpy
arcpy.env.overwriteOutput = True
regions = ["Kodiak", "Copper_River", "Prince_William_Sound", "Cook_Inlet", "Bristol_Bay"]
c=1
for region in regions:
    local_gdb = "D:\\GIS\\AKSSF\\" + region + "\\" + region + ".gdb"
    arcpy.env.workspace = local_gdb + "\\Watersheds"
    wtds = arcpy.ListFeatureClasses()
    print(region + ": " + str(len(wtds)) + " watersheds")
    arcpy.env.workspace = local_gdb
    wtdMerge = [local_gdb + "\\Watersheds\\" + s for s in wtds]
    wtd_output = "wtds_merge"
    wtd_merge = arcpy.Merge_management(wtdMerge, wtd_output)
    #add region field
    arcpy.AddField_management(wtd_merge,'region','TEXT')
    calc ="'"+region+"'"
    arcpy.CalculateField_management(wtd_merge,'region',calc)
    c+=1
print('Process complete')
# Out:
# Kodiak: 28 watersheds
# Copper_River: 28 watersheds
# Prince_William_Sound: 20 watersheds
# Cook_Inlet: 240 watersheds
# Bristol_Bay: 114 watersheds
# Process complete

# %%
print(len(wtdDf))
print(len(wtdList))
# Out:
# 430
# 430

# %% [markdown]
# Also want to intersect sites with maximum flow accumulation in small (30 meters) buffer.  Buffers need to be generated
# iteratively and clipped to their respective catchment to ensure they don't pull values from an adjacent catchment.
# Need to join stream order, stream slope, and upstream downstream km info from vaa/streams merge datasets.

# %%
# steps 4-6
import arcpy
import os
arcpy.env.overwriteOutput = True
regions_dict = {"Kodiak": '!gridcode!', "Copper_River": '!NHDPlusID!', "Prince_William_Sound": '!gridcode!',
                "Cook_Inlet": '!NHDPlusID!', "Bristol_Bay": '!catID!'}

points = r"C:\\Users\\dwmerrigan\\Documents\\GitHub\\AKSSF\\hydrography\\AKSSF_Hydrography.gdb\\AKSSF_Sites_Shifted_2021202"
sites_lst = []
cats_lst = []

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
c=1
for key, value in regions_dict.items():
    arcpy.env.workspace = "D:\\GIS\\AKSSF\\" + key + "\\" + key + ".gdb"
    cats = os.path.join(arcpy.env.workspace, "cats_merge")
    pointlayer = arcpy.MakeFeatureLayer_management(points,'pointlayer')
    pointselect = arcpy.SelectLayerByLocation_management(pointlayer,'INTERSECT',cats)
    arcpy.SpatialJoin_analysis(pointselect, cats, "sites_sj")
    # #note that catID is in the BB cats_merge, but only a LONG, need a DOUBLE to account for NHDPlusIDs
    print('Adding cat_ID field..')
    arcpy.AddField_management("sites_sj", "cat_ID", "DOUBLE")
    arcpy.CalculateField_management("sites_sj", "cat_ID", value)
    sites_fc = os.path.join(arcpy.env.workspace, "sites_sj")
    count = arcpy.GetCount_management(sites_fc)
    print('{}. {} has {} records'.format(c,sites_fc, count[0]))
    sites_lst.append(sites_fc)
    cats_lst.append(cats)
    c+=1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')
# Out:
# Adding cat_ID field..
# 1. D:\GIS\AKSSF\Kodiak\Kodiak.gdb\sites_sj has 33 records
# Adding cat_ID field..
# 2. D:\GIS\AKSSF\Copper_River\Copper_River.gdb\sites_sj has 31 records
# Adding cat_ID field..
# 3. D:\GIS\AKSSF\Prince_William_Sound\Prince_William_Sound.gdb\sites_sj has 22 records
# Adding cat_ID field..
# 4. D:\GIS\AKSSF\Cook_Inlet\Cook_Inlet.gdb\sites_sj has 276 records
# Adding cat_ID field..
# 5. D:\GIS\AKSSF\Bristol_Bay\Bristol_Bay.gdb\sites_sj has 127 records
# Process completed at 2023-05-23 15:34 (Elapsed time: 0:00:36)
# ----------

# %%
import arcpy
import pandas as pd
import os

# Setting outgdb to location created in Covariate notebook but any temp gdb will work
#outgdb = r"D:\\GIS\\AKSSF_land_met\\AKSSF_land_met_2023.gdb"
# Set data dir = to folder with regional subfolders and gdbs
data_dir = r"D:\\GIS\\AKSSF"
arcpy.env.workspace = data_dir
arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr
regions = arcpy.ListWorkspaces(workspace_type="Folder")

# Create lists to store paths to data copies to be merged
site_lst = []
cats_lst = []
vaas_lst = []
streams_lst = []
wtds_lst = []

# Walk through gdbs and select sites_sj, streams and vaas to merge into single fcs
# Separate data by
nhdplus_dat = ['Cook_Inlet', 'Copper_River']
tauDem_dat = ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound']
# Loop through all processing areas
rois = nhdplus_dat + tauDem_dat
for roi in rois:
    # Loop through regional folders
    for region in regions:
        if roi in str(region):
            if roi in nhdplus_dat:
                cat_cur_fields = ['cat_ID_txt', 'NHDPlusID', "cat_ID_con"]
                sj_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
                wtd_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
                str_cur_fields = ['cat_ID_txt', 'NHDPlusID', "cat_ID_con"]
                print(
                    f'{roi} in {nhdplus_dat} AKSSF list, using cat_fields {cat_cur_fields} and watershed fields {sj_cur_fields}')
                print('----------')
            # Set data and variables unique to regions with TauDEM Data
            elif roi in tauDem_dat:
                if roi == 'Bristol_Bay':
                    # Fields for update cursor
                    cat_cur_fields = ['cat_ID_txt', 'catID', "cat_ID_con"]
                    sj_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
                    wtd_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
                    str_cur_fields = ['cat_ID_txt', 'catID', "cat_ID_con"]
                else:
                    cat_cur_fields = ['cat_ID_txt', 'gridcode', "cat_ID_con"]
                    wtd_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
                    sj_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
                    str_cur_fields = ['cat_ID_txt', 'LINKNO', "cat_ID_con"]

                print(
                    f'{roi} in {tauDem_dat} TauDEM list, using cat_fields {cat_cur_fields} and watershed fields {sj_cur_fields}')
                print('----------')
            print(f'{roi} using data from {region} folder')
            arcpy.env.workspace = region
            gdb = arcpy.ListWorkspaces(workspace_type='FileGDB')
            walk = arcpy.da.Walk(region, datatype=['FeatureClass', 'Table'])
            for dirpath, dirnames, filenames in walk:
                for filename in filenames:
                    # Grab sites
                    if filename == 'sites_sj':
                        print(f'{dirpath},{filename}')
                        sitesource = os.path.join(dirpath, filename)
                        sitename = roi + '_' + filename
                        sitepath = os.path.join(outgdb, sitename)
                        # Make local copy projected in AKAlbers
                        if not arcpy.Exists(sitepath):
                            print(f'Copying {sitename}...')
                            print('----------')
                            sitecopy = arcpy.FeatureClassToFeatureClass_conversion(sitesource, outgdb, sitename)
                        else:
                            print(f'{sitepath} already created')
                            sitecopy = sitepath
                            print('----------')
                        site_lst.append(sitecopy)
                        sitefieldnames = []
                        sitelstFields = arcpy.ListFields(sitecopy)
                        for field in sitelstFields:
                            sitefieldnames.append(field.name)
                        if str(sj_cur_fields[0]) in sitefieldnames:
                            print(f'{sj_cur_fields[0]} field already in dataset')
                            print('----------')
                        else:
                            print(f'Adding {sj_cur_fields[0]} field to watershed dataset {sitecopy}')
                            print('----------')
                            # add cat_ID_txt field and concat cat_ID + region
                            arcpy.AddField_management(sitecopy, str(sj_cur_fields[0]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(sitecopy, sj_cur_fields[0:2]) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[0] = strval.replace('.0', '')
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                        if str(sj_cur_fields[2]) in sitefieldnames:
                            print(f'{sj_cur_fields[2]} field already in dataset {sitecopy}')
                            print('----------')
                        else:
                            print(f'Adding {sj_cur_fields[2]} field to watershed dataset {sitecopy}')
                            print('----------')
                            # add cat_ID_con field and concat cat_ID + region
                            arcpy.AddField_management(sitecopy, str(sj_cur_fields[2]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(sitecopy, sj_cur_fields) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[2] = str(roi) + '_' + strval.replace('.0', '')
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                    # Set merged streams dataset
                    elif 'streams_merge' == filename:
                        strsource = os.path.join(dirpath, filename)
                        strname = roi + '_' + filename
                        strpath = os.path.join(outgdb, strname)

                        if not arcpy.Exists(strpath):
                            print(f'Copying {strname}...')
                            print('----------')
                            # Make local copy projected in AKAlbers
                            str_merge = arcpy.FeatureClassToFeatureClass_conversion(strsource, outgdb, strname)
                        else:
                            print(f'Merged streams dataset {strpath} already created...')
                            print('----------')
                            str_merge = strpath
                        streams_lst.append(str_merge)
                        strfieldnames = []
                        strlstFields = arcpy.ListFields(str_merge)
                        for field in strlstFields:
                            strfieldnames.append(field.name)
                        if str(str_cur_fields[0]) in strfieldnames:
                            print(f'{str_cur_fields[0]} field already in dataset')
                            print('----------')
                        else:
                            print(f'Adding {str_cur_fields[0]} field to streams dataset {str_merge}')
                            print('----------')
                            # add cat_ID_txt field and concat cat_ID + region
                            arcpy.AddField_management(str_merge, str(str_cur_fields[0]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(str_merge, str_cur_fields[0:2]) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[0] = strval.replace('.0', '')
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                        if str(str_cur_fields[2]) in strfieldnames:
                            print(f'{str_cur_fields[2]} field already in dataset {str_merge}')
                            print('----------')
                        else:
                            print(f'Adding {str_cur_fields[2]} field to streams dataset {str_merge}')
                            print('----------')
                            # add cat_ID_con field and concat cat_ID + region
                            arcpy.AddField_management(str_merge, str(str_cur_fields[2]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(str_merge, str_cur_fields) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[2] = str(roi) + '_' + strval.replace(".0", "")
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)

                    # Set merged VAA Table dataset
                    elif 'vaa_merge' == filename:
                        vaasource = os.path.join(dirpath, filename)
                        vaaname = roi + '_' + filename
                        vaa_path = os.path.join(outgdb, vaaname)
                        if not arcpy.Exists(vaa_path):
                            print(f'Copying {vaaname}...')
                            print('----------')
                            # Make local copy projected in AKAlbers
                            vaa_merge = arcpy.TableToTable_conversion(vaasource, outgdb, vaaname)
                        else:
                            print(f'Merged VAA Table dataset {vaa_path} already created...')
                            print('----------')
                            vaa_merge = vaa_path
                        vaas_lst.append(vaa_merge)
                        vaafieldnames = []
                        vaalstFields = arcpy.ListFields(vaa_merge)
                        for field in vaalstFields:
                            vaafieldnames.append(field.name)
                        if str(str_cur_fields[0]) in vaafieldnames:
                            print(f'{str_cur_fields[0]} field already in dataset')
                            print('----------')
                        else:
                            print(f'Adding {str_cur_fields[0]} field to VAA Table dataset {vaa_merge}')
                            print('----------')
                            # add cat_ID_txt field and concat cat_ID + region
                            arcpy.AddField_management(vaa_merge, str(str_cur_fields[0]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(vaa_merge, str_cur_fields[0:2]) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[0] = strval.replace('.0', '')
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                        if str(str_cur_fields[2]) in vaafieldnames:
                            print(f'{str_cur_fields[2]} field already in dataset {vaa_merge}')
                            print('----------')
                        else:
                            print(f'Adding {str_cur_fields[2]} field to VAA Table dataset {vaa_merge}')
                            print('----------')
                            # add cat_ID_con field and concat cat_ID + region
                            arcpy.AddField_management(vaa_merge, str(str_cur_fields[2]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(vaa_merge, str_cur_fields) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[2] = str(roi) + '_' + strval.replace(".0", "")
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                    # Set merged watersheds dataset
                    elif 'wtds_merge' == filename:
                        wtdsource = os.path.join(dirpath, filename)
                        wtdname = roi + '_' + filename
                        wtdpath = os.path.join(outgdb, wtdname)

                        if not arcpy.Exists(wtdpath):
                            print(f'Copying {wtdname}...')
                            print('----------')
                            # Make local copy projected in AKAlbers
                            wtd_merge = arcpy.FeatureClassToFeatureClass_conversion(wtdsource, outgdb, wtdname)
                        else:
                            print(f'Merged watershed dataset {wtdpath} already created...')
                            print('----------')
                            wtd_merge = wtdpath
                        wtds_lst.append(wtd_merge)
                        wtdfieldnames = []
                        wtdlstFields = arcpy.ListFields(wtd_merge)
                        for field in wtdlstFields:
                            wtdfieldnames.append(field.name)
                        if str(wtd_cur_fields[0]) in wtdfieldnames:
                            print(f'{wtd_cur_fields[0]} field already in dataset')
                            print('----------')
                        else:
                            print(f'Adding {wtd_cur_fields[0]} field to watershed dataset {wtd_merge}')
                            print('----------')
                            # add cat_ID_txt field and concat cat_ID + region
                            arcpy.AddField_management(wtd_merge, str(wtd_cur_fields[0]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(wtd_merge, wtd_cur_fields[0:2]) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[0] = strval.replace('.0', '')
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                        if str(wtd_cur_fields[2]) in wtdfieldnames:
                            print(f'{wtd_cur_fields[2]} field already in dataset {wtd_merge}')
                            print('----------')
                        else:
                            print(f'Adding {wtd_cur_fields[2]} field to watershed dataset {wtd_merge}')
                            print('----------')
                            # add cat_ID_con field and concat cat_ID + region
                            arcpy.AddField_management(wtd_merge, str(wtd_cur_fields[2]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(wtd_merge, wtd_cur_fields) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[2] = str(roi) + '_' + strval.replace(".0", "")
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)

                    # Select catch_int fc (catchments of interest for region) and make a copy
                    elif 'cats_intersect' == filename:
                        # Make local copy projected in AKAlbers
                        catssource = os.path.join(dirpath, filename)
                        catsname = roi + "_" + filename
                        catspath = os.path.join(outgdb, catsname)
                        if not arcpy.Exists(catspath):
                            print(f'Copying {catsname}...')
                            print('----------')
                            cats = arcpy.FeatureClassToFeatureClass_conversion(catssource, outgdb, catsname)
                        else:
                            print(f'{catspath} already created')
                            print('----------')
                            cats = catspath
                        cats_lst.append(cats)
                        catlstfields = arcpy.ListFields(cats)
                        catfieldnames = []
                        for field in catlstfields:
                            catfieldnames.append(field.name)
                        if str(cat_cur_fields[0]) in catfieldnames:
                            print(f'{cat_cur_fields[0]} field already in dataset {cats}')
                            print('----------')
                        else:
                            print(f'Adding {cat_cur_fields[0]} field to catchment dataset {cats}')
                            print('----------')
                            # add cat_ID_txt field
                            arcpy.AddField_management(cats, str(cat_cur_fields[0]), field_type='TEXT')
                            # populate cat_ID_txt
                            with arcpy.da.UpdateCursor(cats, cat_cur_fields[0:2]) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[0] = strval.replace('.0', '')
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
                        if str(cat_cur_fields[2]) in catfieldnames:
                            print(f'{cat_cur_fields[2]} field already in dataset {cats}')
                            print('----------')
                        else:
                            print(f'Adding {cat_cur_fields[2]} field to catchment dataset {cats}')
                            print('----------')
                            # add cat_ID_txt field & cat_ID + region concat field
                            arcpy.AddField_management(cats, str(cat_cur_fields[2]), field_type='TEXT')
                            # populate cat_ID_con
                            with arcpy.da.UpdateCursor(cats, cat_cur_fields) as cur:
                                for row in cur:
                                    strval = str(row[1])
                                    row[2] = str(roi) + '_' + strval.replace(".0", "")
                                    # Update rows
                                    cur.updateRow(row)
                                del (row)
                            del (cur)
print(cats_lst)
print(site_lst)
print(vaas_lst)
print(streams_lst)
print(wtds_lst)
# Out:
# Cook_Inlet in ['Cook_Inlet', 'Copper_River'] AKSSF list, using cat_fields ['cat_ID_txt', 'NHDPlusID', 'cat_ID_con'] and watershed fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Cook_Inlet using data from D:\\GIS\\AKSSF\Cook_Inlet folder
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_cats_intersect already created
# ----------
# cat_ID_txt field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_cats_intersect
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_cats_intersect
# ----------
# Merged watershed dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_wtds_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_wtds_merge
# ----------
# D:\GIS\AKSSF\Cook_Inlet\Cook_Inlet.gdb,sites_sj
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_sites_sj already created
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_sites_sj
# ----------
# Merged VAA Table dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_vaa_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Cook_Inlet_vaa_merge
# ----------
# Copper_River in ['Cook_Inlet', 'Copper_River'] AKSSF list, using cat_fields ['cat_ID_txt', 'NHDPlusID', 'cat_ID_con'] and watershed fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Copper_River using data from D:\\GIS\\AKSSF\Copper_River folder
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_cats_intersect already created
# ----------
# cat_ID_txt field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_cats_intersect
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_cats_intersect
# ----------
# Merged watershed dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_wtds_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_wtds_merge
# ----------
# D:\GIS\AKSSF\Copper_River\Copper_River.gdb,sites_sj
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_sites_sj already created
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_sites_sj
# ----------
# Merged VAA Table dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_vaa_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Copper_River_vaa_merge
# ----------
# Bristol_Bay in ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound'] TauDEM list, using cat_fields ['cat_ID_txt', 'catID', 'cat_ID_con'] and watershed fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Bristol_Bay using data from D:\\GIS\\AKSSF\Bristol_Bay folder
# Merged streams dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_streams_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_streams_merge
# ----------
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_cats_intersect already created
# ----------
# cat_ID_txt field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_cats_intersect
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_cats_intersect
# ----------
# Merged watershed dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_wtds_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_wtds_merge
# ----------
# D:\GIS\AKSSF\Bristol_Bay\Bristol_Bay.gdb,sites_sj
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_sites_sj already created
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Bristol_Bay_sites_sj
# ----------
# Kodiak in ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound'] TauDEM list, using cat_fields ['cat_ID_txt', 'gridcode', 'cat_ID_con'] and watershed fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Kodiak using data from D:\\GIS\\AKSSF\Kodiak folder
# Merged streams dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_streams_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_streams_merge
# ----------
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_cats_intersect already created
# ----------
# cat_ID_txt field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_cats_intersect
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_cats_intersect
# ----------
# Merged watershed dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_wtds_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_wtds_merge
# ----------
# D:\GIS\AKSSF\Kodiak\Kodiak.gdb,sites_sj
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_sites_sj already created
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Kodiak_sites_sj
# ----------
# Prince_William_Sound in ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound'] TauDEM list, using cat_fields ['cat_ID_txt', 'gridcode', 'cat_ID_con'] and watershed fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Prince_William_Sound using data from D:\\GIS\\AKSSF\Prince_William_Sound folder
# Merged streams dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_streams_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_streams_merge
# ----------
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_cats_intersect already created
# ----------
# cat_ID_txt field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_cats_intersect
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_cats_intersect
# ----------
# Merged watershed dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_wtds_merge already created...
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_wtds_merge
# ----------
# D:\GIS\AKSSF\Prince_William_Sound\Prince_William_Sound.gdb,sites_sj
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_sites_sj already created
# ----------
# cat_ID_txt field already in dataset
# ----------
# cat_ID_con field already in dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\Prince_William_Sound_sites_sj
# ----------
# ['D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Cook_Inlet_cats_intersect', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Copper_River_cats_intersect', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Bristol_Bay_cats_intersect', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Kodiak_cats_intersect', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Prince_William_Sound_cats_intersect']
# ['D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Cook_Inlet_sites_sj', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Copper_River_sites_sj', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Bristol_Bay_sites_sj', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Kodiak_sites_sj', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Prince_William_Sound_sites_sj']
# ['D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Cook_Inlet_vaa_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Copper_River_vaa_merge']
# ['D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Bristol_Bay_streams_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Kodiak_streams_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Prince_William_Sound_streams_merge']
# ['D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Cook_Inlet_wtds_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Copper_River_wtds_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Bristol_Bay_wtds_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Kodiak_wtds_merge', 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\Prince_William_Sound_wtds_merge']

# %% [markdown]
# ## Merge collected datasets

# %%
import time
import datetime

arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()

outcats = os.path.join(outgdb, "all_cats_int_merge")
outsites = os.path.join(outgdb, "all_sites_sj_merge")
outvaa = os.path.join(outgdb, "all_vaas_merge")
outwtd = os.path.join(outgdb, "all_wtds_merge")
outwtd1 = os.path.join(r'memory/', "all_wtds_merge")
outstreams = os.path.join(outgdb, "all_taustreams_merge")
print(f"Merging dataset {outsites}...\n '----------' ")
sitesmerge = arcpy.Merge_management(site_lst, outsites, "", "ADD_SOURCE_INFO")
print(f"Merging dataset {outcats}...\n '----------' ")
catsmerge = arcpy.Merge_management(cats_lst, outcats, "", "ADD_SOURCE_INFO")
print(f"Merging dataset {outvaa}...\n '----------' ")
vaasmerge = arcpy.Merge_management(vaas_lst, outvaa, "", "ADD_SOURCE_INFO")
print(f"Merging dataset {outstreams}...\n '----------' ")
streamsmerge = arcpy.Merge_management(streams_lst, outstreams, "", "ADD_SOURCE_INFO")
print(f"Merging dataset {outwtd}...\n '----------' ")
wtdsmerge1 = arcpy.Merge_management(wtds_lst, outwtd1, "", "ADD_SOURCE_INFO")
wtdsmerge = arcpy.EliminatePolygonPart_management(wtdsmerge1,outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')
# Out:
# Merging dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\all_sites_sj_merge...
#  '----------'
# Merging dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\all_cats_int_merge...
#  '----------'
# Merging dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\all_vaas_merge...
#  '----------'
# Merging dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\all_taustreams_merge...
#  '----------'
# Merging dataset D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\all_wtds_merge...
#  '----------'
# Process completed at 2023-05-23 15:35 (Elapsed time: 0:00:40)
# ----------

# %% [markdown]
# ## Buffer and clip sites
# Buffer sites by 30 meters and loop through each site and clip to its respective catchment.  Merge all clips together
# when complete

# %%
import arcpy
import os
from arcpy.sa import *
import time
import datetime

# Setting outgdb to location created in Covariate notebook but any temp gdb will work
#outgdb = r"D:\\GIS\\AKSSF_land_met\\AKSSF_land_met_2023.gdb"
# Set data dir = to folder with regional subfolders and gdbs
data_dir = r"D:\GIS\AKSSF"
arcpy.env.workspace = data_dir
arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr
regions = arcpy.ListWorkspaces(workspace_type="Folder")
#buffer value of 30 meters
buffval = 30
bufpath = os.path.join(outgdb, "sites_buffer")
buffer = arcpy.Buffer_analysis(sitesmerge, bufpath, "30 meters")
# this makes sure the buffer does not extend outside of the catchment - cannot use memory/ object as input for zonal stats
# must write to gdb
clips = []
# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
buflyr = arcpy.MakeFeatureLayer_management(bufpath, "buflyr")
catlayer = arcpy.MakeFeatureLayer_management(catsmerge, 'catlayer')
fieldlist = []
fields = arcpy.ListFields(bufpath)
for field in fields:
    fieldlist.append(field.name)
row_count = len(list(i for i in arcpy.da.SearchCursor(bufpath, fieldlist)))
print(row_count)

c = 1
with arcpy.da.SearchCursor(bufpath, ['SiteID', 'cat_ID_con', 'OBJECTID']) as cur:
    for row in cur:
        fieldValue = str(row[0])
        if fieldValue.find("'") != -1:
            newVal = fieldValue.replace("'", "''")
            print(f'Apostrophe found in {fieldValue}, replacing with {newVal}')
        else:
            print(f'Site ID: {fieldValue} OK')
            newVal = fieldValue

        clause = """ "cat_ID_con" = '%s'""" % row[1]
        clause1 = """ "SiteID" = '%s'""" % newVal
        print(f' {c} of {row_count} -  Clipping {row[0]} to {row[1]}...')
        print('----------')
        bufselect = arcpy.SelectLayerByAttribute_management(buflyr, 'NEW_SELECTION', where_clause=clause1)
        catselect = arcpy.SelectLayerByAttribute_management(catlayer, 'NEW_SELECTION', where_clause=clause)
        clipname = 'clip_' + str(c)
        clipout = os.path.join(outgdb, clipname)
        clip = arcpy.Clip_analysis(bufselect, catselect, clipout)
        clips.append(clipout)
        c += 1
    del (row)
del (cur)

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')
# Out:
# 489
# Site ID: APU1 OK
#  1 of 489 -  Clipping APU1 to Cook_Inlet_75004300004192...
# ----------
# Site ID: APU10 OK
#  2 of 489 -  Clipping APU10 to Cook_Inlet_75004300004192...
# ----------
# Site ID: APU11 OK
#  3 of 489 -  Clipping APU11 to Cook_Inlet_75004300004304...
# ----------
# Site ID: APU12 OK
#  4 of 489 -  Clipping APU12 to Cook_Inlet_75004300005245...
# ----------
# Site ID: APU2 OK
#  5 of 489 -  Clipping APU2 to Cook_Inlet_75004300003171...
# ----------
# Site ID: APU3 OK
#  6 of 489 -  Clipping APU3 to Cook_Inlet_75004300006312...
# ----------
# Site ID: APU5 OK
#  7 of 489 -  Clipping APU5 to Cook_Inlet_75004300002142...
# ----------
# Site ID: APU6 OK
#  8 of 489 -  Clipping APU6 to Cook_Inlet_75004300007324...
# ----------
# Site ID: APU7 OK
#  9 of 489 -  Clipping APU7 to Cook_Inlet_75004300001288...
# ----------
# Site ID: KATM_margc_stream_water OK
#  347 of 489 -  Clipping KATM_margc_stream_water to Bristol_Bay_3033956...
# ----------
# Site ID: KATM_naknlo_continuous_wq OK
#  348 of 489 -  Clipping KATM_naknlo_continuous_wq to Bristol_Bay_3024343...
# ----------
# Site ID: KATM_naknlo_lvl OK
#  349 of 489 -  Clipping KATM_naknlo_lvl to Bristol_Bay_3024343...
# ----------
# Site ID: KATM_naknlo_temp OK
#  350 of 489 -  Clipping KATM_naknlo_temp to Bristol_Bay_3024343...
# ----------
# Site ID: KATM_savor_stream_water OK
#  351 of 489 -  Clipping KATM_savor_stream_water to Bristol_Bay_3034126...
# ----------
# Site ID: KATM_upatc_stream_water OK
#  352 of 489 -  Clipping KATM_upatc_stream_water to Bristol_Bay_3033666...
# ----------
# Site ID: KULR OK
#  353 of 489 -  Clipping KULR to Bristol_Bay_5038375...
# ----------
# Site ID: LACL_kijilo_lvl OK
#  354 of 489 -  Clipping LACL_kijilo_lvl to Bristol_Bay_2078282...
# ----------
# Site ID: LACL_kijilo_temp OK
#  355 of 489 -  Clipping LACL_kijilo_temp to Bristol_Bay_2078282...
# ----------
# Site ID: LACL_lclaro_continuous_wq OK
#  356 of 489 -  Clipping LACL_lclaro_continuous_wq to Bristol_Bay_2087913...
# ----------
# Site ID: LACL_lclaro_lvl OK
#  357 of 489 -  Clipping LACL_lclaro_lvl to Bristol_Bay_2087913...
# ----------
# Site ID: LACL_lclaro_temp OK
#  358 of 489 -  Clipping LACL_lclaro_temp to Bristol_Bay_2087913...
# ----------
# Site ID: LACL_lkijr_stream_water OK
#  359 of 489 -  Clipping LACL_lkijr_stream_water to Bristol_Bay_2078282...
# ----------
# Site ID: LACL_tazir_stream_water OK
#  360 of 489 -  Clipping LACL_tazir_stream_water to Bristol_Bay_2082373...
# ----------
# Site ID: LACL_tlikr_stream_water OK
#  361 of 489 -  Clipping LACL_tlikr_stream_water to Bristol_Bay_2041471...
# ----------
# Site ID: MALR OK
#  362 of 489 -  Clipping MALR to Bristol_Bay_5020796...
# ----------
# Site ID: mubon10 OK
#  363 of 489 -  Clipping mubon10 to Bristol_Bay_4054200...
# ----------
# Site ID: muekm23 OK
#  364 of 489 -  Clipping muekm23 to Bristol_Bay_4092244...
# ----------
# Site ID: musfk01 OK
#  365 of 489 -  Clipping musfk01 to Bristol_Bay_4099694...
# ----------
# Site ID: mussm15 OK
#  366 of 489 -  Clipping mussm15 to Bristol_Bay_4091424...
# ----------
# Site ID: mustu17 OK
#  367 of 489 -  Clipping mustu17 to Bristol_Bay_4104574...
# ----------
# Site ID: mutsk02 OK
#  368 of 489 -  Clipping mutsk02 to Bristol_Bay_4089074...
# ----------
# Site ID: mutsk09 OK
#  369 of 489 -  Clipping mutsk09 to Bristol_Bay_4088904...
# ----------
# Site ID: NCLO OK
#  370 of 489 -  Clipping NCLO to Bristol_Bay_5030704...
# ----------
# Site ID: Newhalen River OK
#  371 of 489 -  Clipping Newhalen River to Bristol_Bay_2088253...
#  439 of 489 -  Clipping kdk_olgcr01a to Kodiak_48267...
# ----------
# Site ID: kdk_olgcr01b OK
#  440 of 489 -  Clipping kdk_olgcr01b to Kodiak_48267...
# ----------
# Site ID: kdk_ayarv01 OK
#  441 of 489 -  Clipping kdk_ayarv01 to Kodiak_108356...
# ----------
# Site ID: kdk_akacr01 OK
#  442 of 489 -  Clipping kdk_akacr01 to Kodiak_50197...
# ----------
# Site ID: kdk_ayarv03 OK
#  443 of 489 -  Clipping kdk_ayarv03 to Kodiak_107796...
# ----------
# Site ID: kdk_cancr01 OK
#  444 of 489 -  Clipping kdk_cancr01 to Kodiak_101556...
# ----------
# Site ID: kdk_concr01 OK
#  445 of 489 -  Clipping kdk_concr01 to Kodiak_97276...
# ----------
# Site ID: kdk_pincr01 OK
#  446 of 489 -  Clipping kdk_pincr01 to Kodiak_103296...
# ----------
# Site ID: kdk_relrv01 OK
#  447 of 489 -  Clipping kdk_relrv01 to Kodiak_103196...
# ----------
# Site ID: kdk_cascr01 OK
#  448 of 489 -  Clipping kdk_cascr01 to Kodiak_94216...
# ----------
# Site ID: kdk_eftrv01 OK
#  449 of 489 -  Clipping kdk_eftrv01 to Kodiak_103096...
# ----------
# Site ID: kdk_falcr01 OK
#  450 of 489 -  Clipping kdk_falcr01 to Kodiak_99516...
# ----------
# Site ID: kdk_meacr01 OK
#  451 of 489 -  Clipping kdk_meacr01 to Kodiak_93176...
# ----------
# Site ID: kdk_omarv01 OK
#  452 of 489 -  Clipping kdk_omarv01 to Kodiak_100826...
# ----------
# Site ID: kdk_soucr01 OK
#  453 of 489 -  Clipping kdk_soucr01 to Kodiak_90346...
# ----------
# Site ID: kdk_akacr02 OK
#  454 of 489 -  Clipping kdk_akacr02 to Kodiak_50197...
# ----------
# Site ID: kdk_cancr02 OK
#  455 of 489 -  Clipping kdk_cancr02 to Kodiak_101556...
# ----------
# Site ID: kdk_falcr02 OK
#  456 of 489 -  Clipping kdk_falcr02 to Kodiak_99516...
# ----------
# Site ID: kdk_pincr02 OK
#  457 of 489 -  Clipping kdk_pincr02 to Kodiak_103456...
# ----------
# Site ID: fws_kdk_aforv01 OK
#  458 of 489 -  Clipping fws_kdk_aforv01 to Kodiak_64593...
# ----------
# Site ID: fws_kdk_busrv01 OK
#  459 of 489 -  Clipping fws_kdk_busrv01 to Kodiak_77794...
# ----------
# Site ID: 571005154134600 OK
#  460 of 489 -  Clipping 571005154134600 to Kodiak_50197...
# ----------
# Site ID: 571221154040300 OK
#  461 of 489 -  Clipping 571221154040300 to Kodiak_106626...
# ----------
# Site ID: 571343154244900 OK
#  462 of 489 -  Clipping 571343154244900 to Kodiak_107816...
# ----------
# Site ID: 572656154082400 OK
#  463 of 489 -  Clipping 572656154082400 to Kodiak_129955...
# ----------
# Site ID: kdk_bigcr01 OK
#  464 of 489 -  Clipping kdk_bigcr01 to Kodiak_103496...
# ----------
# Site ID: kdk_karrv02 OK
#  465 of 489 -  Clipping kdk_karrv02 to Kodiak_130295...
# ----------
# Site ID: 15295700 OK
Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()

# Merge Clips and delete individual clipped buffers
clip_path = os.path.join(outgdb, 'all_buffsites_clip')
clip_outfile = arcpy.Merge_management(clips, clip_path)

delete = clips
for d in delete:
    arcpy.DeleteFeatures_management(d)
print('Complete...')
print('----------')

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')
# Out:
# Complete...
# ----------
# Process completed at 2023-05-23 15:49 (Elapsed time: 0:03:09)
# ----------

# %%
# zonal stats on buffer intersection with flow accumulation grids (need to loop through regions for this)
# to get maximum flow accumulation bc some points may not exactly fall on stream grid
tbl_lst = []
# Seperate data by
nhdplus_dat = ['Cook_Inlet', 'Copper_River']
tauDem_dat = ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound']

# Loop through all processing areas
rois = nhdplus_dat + tauDem_dat

for roi in rois:
    # Loop through regional folders
    # Grab stream order from VAA/Streams and join to sites_sj
    for region in regions:
        arcpy.env.workspace = region
        raslist = arcpy.ListRasters()
        if roi in str(region):
            if roi in nhdplus_dat:
                cat_cur_fields = ['cat_ID_txt', 'NHDPlusID', "cat_ID_con"]
                cf = 25
                # grab stream order from vaa - upstream and downstream lengths - and stream gradient
                vaa = 'vaa_merge'
                print(f'{roi} in {nhdplus_dat} AKSSF list, using cat_fields {cat_cur_fields} and spatial join fields '
                      f'{sj_cur_fields}')
                print('----------')
            # Set data and variables unique to regions with TauDEM Data
            elif roi in tauDem_dat:
                # grab stream order from tauDEM - upstream and downstream lengths - and stream gradient
                streams = "streams_merge"
                # Fields for update cursor
                if roi == 'Bristol_Bay':
                    # Fields for update cursor
                    cat_cur_fields = ['cat_ID_txt', 'catID', "cat_ID_con"]
                else:
                    cat_cur_fields = ['cat_ID_txt', 'gridcode', "cat_ID_con"]
                cf = 100
                print(f'{roi} in {tauDem_dat} TauDEM list, using cat_fields {cat_cur_fields} and spatial join fields '
                      f'{sj_cur_fields}')
                print('----------')
            print(f'{roi} using data from {region} folder')
            print('--------')
            fac = os.path.join(region, 'fac.tif')
            if arcpy.Exists(fac):
                print(f'Flow accumulation grid {fac} selected for {roi}')
            else:
                print(f'No flow accumulation raster for {region}')
            outtable = os.path.join(outgdb, (roi + "_maxfac"))
            print(f'Calculating {roi} catchment Max flow accumulation stats...')
            arcpy.env.snapRaster = fac
            arcpy.env.cellSize = fac
            try:
                field = 'cat_ID_con'
                operator = 'LIKE'
                value = roi
                sba = """"{}" {} '{}%'""".format(field, operator, value)
                clip_select = arcpy.SelectLayerByAttribute_management(clip_outfile, 'NEW_SELECTION', sba)
                zon_start = time.time()
                cat_facMax_table = ZonalStatisticsAsTable(in_zone_data=clip_select,
                                                          zone_field=cat_cur_fields[2],
                                                          in_value_raster=fac,
                                                          out_table=outtable,
                                                          statistics_type='MAXIMUM'
                                                          )
                # Add region identifier field for catchment table
                arcpy.AddField_management(cat_facMax_table, 'region', field_type='TEXT')
                # Add cat_ID_Con field
                arcpy.AddField_management(cat_facMax_table, 'cat_ID_txt', field_type='TEXT')
                # Update fields
                # Add upstream area as calculated from Max flow acc zonal stats for catchment table
                arcpy.AddField_management(cat_facMax_table, 'site_acc_sqKm', field_type='DOUBLE')

                with arcpy.da.UpdateCursor(cat_facMax_table,
                                           ['region', 'cat_ID_txt', 'cat_ID_con', 'MAX', 'site_acc_sqKm']) as cur:
                    for row in cur:
                        strval = str(row[1])
                        row[0] = roi
                        row[1] = strval.replace('.0', '')
                        row[4] = (cf * row[3]) / 1000000
                        # Update
                        cur.updateRow(row)
                    del (row)
                del (cur)
                # rename MAX field
                arcpy.AlterField_management(cat_facMax_table, "MAX", 'site_max_acc', 'site_max_acc')
                zon_stop = time.time()
                zon_time = int(zon_stop - zon_start)
                print(f'Max Flow zonal stats for {roi} Elapsed time: ({datetime.timedelta(seconds=zon_time)})')
                print('----------')

                tbl_lst.append(outtable)
            except:
                e = sys.exc_info()[1]
                print(e.args[0])
                arcpy.AddError(e.args[0])
# Out:
# Cook_Inlet in ['Cook_Inlet', 'Copper_River'] AKSSF list, using cat_fields ['cat_ID_txt', 'NHDPlusID', 'cat_ID_con'] and spatial join fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Cook_Inlet using data from D:\GIS\AKSSF\Cook_Inlet folder
# --------
# Flow accumulation grid D:\GIS\AKSSF\Cook_Inlet\fac.tif selected for Cook_Inlet
# Calculating Cook_Inlet catchment Max flow accumulation stats...
# Max Flow zonal stats for Cook_Inlet Elapsed time: (0:04:26)
# ----------
# Copper_River in ['Cook_Inlet', 'Copper_River'] AKSSF list, using cat_fields ['cat_ID_txt', 'NHDPlusID', 'cat_ID_con'] and spatial join fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Copper_River using data from D:\GIS\AKSSF\Copper_River folder
# --------
# Flow accumulation grid D:\GIS\AKSSF\Copper_River\fac.tif selected for Copper_River
# Calculating Copper_River catchment Max flow accumulation stats...
# Max Flow zonal stats for Copper_River Elapsed time: (0:01:03)
# ----------
# Bristol_Bay in ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound'] TauDEM list, using cat_fields ['cat_ID_txt', 'catID', 'cat_ID_con'] and spatial join fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Bristol_Bay using data from D:\GIS\AKSSF\Bristol_Bay folder
# --------
# Flow accumulation grid D:\GIS\AKSSF\Bristol_Bay\fac.tif selected for Bristol_Bay
# Calculating Bristol_Bay catchment Max flow accumulation stats...
# Max Flow zonal stats for Bristol_Bay Elapsed time: (0:00:26)
# ----------
# Kodiak in ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound'] TauDEM list, using cat_fields ['cat_ID_txt', 'gridcode', 'cat_ID_con'] and spatial join fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Kodiak using data from D:\GIS\AKSSF\Kodiak folder
# --------
# Flow accumulation grid D:\GIS\AKSSF\Kodiak\fac.tif selected for Kodiak
# Calculating Kodiak catchment Max flow accumulation stats...
# Max Flow zonal stats for Kodiak Elapsed time: (0:00:09)
# ----------
# Prince_William_Sound in ['Bristol_Bay', 'Kodiak', 'Prince_William_Sound'] TauDEM list, using cat_fields ['cat_ID_txt', 'gridcode', 'cat_ID_con'] and spatial join fields ['cat_ID_txt', 'cat_ID', 'cat_ID_con']
# ----------
# Prince_William_Sound using data from D:\GIS\AKSSF\Prince_William_Sound folder
# --------
# Flow accumulation grid D:\GIS\AKSSF\Prince_William_Sound\fac.tif selected for Prince_William_Sound
# Calculating Prince_William_Sound catchment Max flow accumulation stats...
# Max Flow zonal stats for Prince_William_Sound Elapsed time: (0:00:10)
# ----------

# %%
# Merge flow accumulation outtables
out_table_merge = os.path.join(outgdb, "AKSSF_site_sj_maxfac")
flowmerge = arcpy.Merge_management(tbl_lst, out_table_merge, "", "ADD_SOURCE_INFO")
print("Merge all maxfac tables completed")
# Recalculate area_km2 to join back to sites sj - Not all sites had these fields joined
arcpy.env.workspace = outgdb
for fc in arcpy.ListFeatureClasses('*wtds_merge'):
    print(fc)
    arcpy.CalculateField_management(fc, "Area_km2", expression="!SHAPE.area@SQUAREKILOMETERS!")
    fieldlist = arcpy.ListFields(fc)
# Out:
# Merge all maxfac tables completed
# Cook_Inlet_wtds_merge
# Copper_River_wtds_merge
# Bristol_Bay_wtds_merge
# Kodiak_wtds_merge
# Prince_William_Sound_wtds_merge
# all_wtds_merge

# %% [markdown]
# ## Add stream metrics from VAA table and streams merge
# ### VAA ATTRIBUTES
# * ARBOLATESU takes advantage of the LengthKM field in NHDFlowline, which measures the length of the flowline in kilometers. ARBOLATESU is determined by accumulating the length of all the upstream flowlines from the bottom of the current flowline and so provides the total length of the upstream drainage network from the bottom of the current flowline.
# * ARBOLATESU is the total length of the upstream drainage network from the bottom of the current flowline
#
# * The PATHLENGTH is the distance from the bottom of a flowline to the bottom of the terminal flowline along the main path as identified in the TERMINALPA field. There may be many pathways between a flowline and the terminal flowline because of divergences in the network so PATHLENGTH is computed by following the main path at each divergence.
#    * PATHLENGTH is the distance from the bottom of a flowline to the end of the network and is calculated on the main network path in km
#    * PATHLENGTH at the terminal Flowline (Isolated, Sinks, Oceans) is equal to zero.
#
# * This is what you need to know about STARTFLAG AND TERMINALFL:
#   * STARTFLAG identifies headwater flowlines
#   * TERMINALFL identifies network end flowlines
#   * Values of 0 indicate the feature is not headwater (STARTFLAG) or network end (TERMINALFL)
#   * values of 1 indicate the feature is a headwater (STARTFLAG) or network end (TERMINALFL)
#
# * TotalDrainageAreaSqKm
#   * Total cumulative area, in square kilometers
# * AreaSqKm - Catchment area, in square kilometers
# * Slope - Slope of the flowline from smoothed elevation (unitless)
# ### tauDEM Attributes
# * DSContArea - Drainage area at the downstream end of the link. Generally this is one grid cell upstream of the downstream end because the drainage area at the downstream end grid cell includes the area of the stream being joined.
# * USContArea - Drainage area at the upstream end of the link
# * Slope - Average slope of the link (computed as drop/length)
# * DOUT_END - Distance to the outlet from the downstream end of the link in meters
# * DOUT_START - Distance to the outlet from the upstream end of the link in meters

# %%
import os,arcpy
from math import *
wtds_merge = os.path.join(outgdb,'all_wtds_merge')
#Join fields from flow acc zonal stats and wtds merge to compare watershed area
delete_fields = ['StreamOrde', 'strmOrder', 'Slope', 'Slope_1', 'HUC8_ID', 'HUC8', 'Join_Count', 'TARGET_FID',
                 'proc_reg']
sj_cur_fields = ['cat_ID_txt', 'cat_ID', "cat_ID_con"]
str_cur_fields = ['cat_ID_txt', 'catID', "cat_ID_con"]
flow_join_fields = ['site_max_acc', 'site_acc_sqKm']
wtds_join_fields = ['Area_km2']
vaa_join_fields = ['StreamOrde', 'Slope', 'AreaSqKm', 'ArbolateSu', 'PathLength', 'StartFlag', 'TerminalPa',
                   'TotalDrainageAreaSqKm']
streams_join_fields = ['strmOrder', 'Slope', 'USContArea', 'DSContArea', 'LINKNO', 'DOUTEND', 'DOUTSTART']
#join flow acc
arcpy.JoinField_management(sitesmerge, sj_cur_fields[2], out_table_merge, sj_cur_fields[2], flow_join_fields)
#join wtds merge
arcpy.JoinField_management(sitesmerge, sj_cur_fields[2], wtds_merge, sj_cur_fields[2], wtds_join_fields)
#join NHDPlus vaa table data
arcpy.JoinField_management(sitesmerge, sj_cur_fields[2], vaasmerge, str_cur_fields[2], vaa_join_fields)
# join TauDEM streams merge data
arcpy.JoinField_management(sitesmerge, sj_cur_fields[2], streamsmerge, str_cur_fields[2], streams_join_fields)
# Add fields as necessary
arcpy.AddField_management(sitesmerge, "area_diff", field_type="DOUBLE")
arcpy.AddField_management(sitesmerge, "str_slope", field_type="DOUBLE")
arcpy.AddField_management(sitesmerge, "str_ord", field_type="SHORT")
arcpy.AddField_management(sitesmerge, "ds_dist_outlet", field_type="DOUBLE")
arcpy.AddField_management(sitesmerge, "str_slope_dg", field_type="DOUBLE")

# Make list of fields to keep
str_fields = []
for field in arcpy.ListFields(sitesmerge):
    str_fields.append(field.name)
keep_fields = [item for item in str_fields if item not in delete_fields]
print(str_fields)
with arcpy.da.UpdateCursor(sitesmerge,
                           ["area_diff", 'Area_km2', 'site_acc_sqKm', 'str_slope', 'Slope', 'Slope_1', 'str_ord',
                            'StreamOrde', 'strmOrder','ds_dist_outlet','PathLength','DOUTEND','str_slope_dg','cat_ID_con']) as cur:
    for row in cur:
        # Set conditions for na values in vaa/tau slope
        if row[4] != None:
            slope = row[4]
        else:
            slope = row[5]
        # Set conditions for na values in vaa/tau slope_dg
        if row[4] != None:
            slope_dg = degrees(atan(row[4]))
        else:
            slope_dg = degrees(atan(row[5]))
        # Set conditions for na values in vaa/tau strOrder
        if row[7] != None:
            ord = row[7]
        else:
            ord = row[8]
        # Set conditions for na values in vaa/tau ds distance to outlet
        if row[10] != None:
            ds_dist = row[10]
        else:
            ds_dist = row[11] * 0.001 # convert to km
        print(f'{row[13]} has a slope of {slope} ({slope_dg} deg), stream order of {ord}, and ds dist to outlet of {ds_dist}\n area diff of {row[1]-row[2]}')
        row[3] = slope
        row[6] = ord
        # Calculate difference in area as watershed polygon area in sqKm minus area calculated from max flow accumulation in sqKm
        row[0] = row[1] - row[2]
        row[9] = ds_dist
        row[12] = slope_dg
        cur.updateRow(row)
    del (row)
del (cur)
print('Join Fields Complete')
print('----------')
# Calculate lat/lon in Nad83
arcpy.management.CalculateGeometryAttributes("all_sites_sj_merge", "lat POINT_Y;lon POINT_X", '', '','GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]', "DD")
arcpy.DeleteField_management("all_sites_sj_merge",delete_fields)
# Out:
# ['OBJECTID', 'Shape', 'Join_Count', 'TARGET_FID', 'SiteID', 'Agnc_ID', 'SourcNm', 'Wtrbdy_n', 'Verified', 'Comments', 'DM_Notes', 'Region', 'NEAR_FID', 'NEAR_DIST', 'NHDPlusID', 'SourceFC', 'GridCode', 'AreaSqKm', 'VPUID', 'cat_ID', 'cat_ID_txt', 'cat_ID_con', 'catID', 'MERGE_SRC', 'site_max_acc', 'site_acc_sqKm', 'Area_km2', 'StreamOrde', 'Slope', 'AreaSqKm_1', 'ArbolateSu', 'PathLength', 'StartFlag', 'TerminalPa', 'strmOrder', 'Slope_1', 'USContArea', 'DSContArea', 'LINKNO', 'DOUTEND', 'DOUTSTART', 'area_diff', 'str_slope', 'str_ord', 'ds_dist_outlet', 'str_slope_dg']
# Cook_Inlet_75004300004192 has a slope of 0.00223118 (0.12783698520311323 deg), stream order of 6, and ds dist to outlet of 1.75012969
#  area diff of 0.368274740425818
# Cook_Inlet_75004300004192 has a slope of 0.00223118 (0.12783698520311323 deg), stream order of 6, and ds dist to outlet of 1.75012969
#  area diff of 0.368274740425818
# Cook_Inlet_75004300004304 has a slope of 0.00577096 (0.3306479811402406 deg), stream order of 6, and ds dist to outlet of 16.92847388
#  area diff of 0.5492248617798055
# Cook_Inlet_75004300005245 has a slope of 0.00320175 (0.18344613520986391 deg), stream order of 5, and ds dist to outlet of 3.6214280199999997
#  area diff of 0.03904993724876249
# Cook_Inlet_75004300003171 has a slope of 0.0030561200000000003 (0.1751022325428812 deg), stream order of 1, and ds dist to outlet of 35.16401682
#  area diff of 0.028374998269315554
# Cook_Inlet_75004300006312 has a slope of 0.0047260900000000005 (0.2707829945479531 deg), stream order of 5, and ds dist to outlet of 12.33081329
#  area diff of 0.5508499750269777
# Cook_Inlet_75004300002142 has a slope of 0.00888109 (0.5088355968316952 deg), stream order of 4, and ds dist to outlet of 14.21820732
#  area diff of 0.2766249378382284
# Cook_Inlet_75004300007324 has a slope of 0.00148898 (0.0853122067319586 deg), stream order of 4, and ds dist to outlet of 20.61451336
#  area diff of 0.00030002951341145945
# Cook_Inlet_75004300001288 has a slope of 0.01148158 (0.6578171712068109 deg), stream order of 4, and ds dist to outlet of 23.68594172
#  area diff of 0.058149998957794935
# Cook_Inlet_75004300002332 has a slope of 0.0049174 (0.28174399525840327 deg), stream order of 6, and ds dist to outlet of 21.79652239
#  area diff of 0.6313248468878783
# Cook_Inlet_75004300004254 has a slope of 0.00750803 (0.4301703486044865 deg), stream order of 6, and ds dist to outlet of 9.76669077
#  area diff of 3.9364748285523206
# Cook_Inlet_75004300004341 has a slope of 0.00643801 (0.36886570527411083 deg), stream order of 6, and ds dist to outlet of 22.55912069
#  area diff of 0.014924910217871457
# Cook_Inlet_75004300000100 has a slope of 0.00990767 (0.5676491024517124 deg), stream order of 3, and ds dist to outlet of 7.59494702
#  area diff of 0.02709989047301775
# Cook_Inlet_75004300002142 has a slope of 0.00888109 (0.5088355968316952 deg), stream order of 4, and ds dist to outlet of 14.21820732
#  area diff of 0.2766249378382284
# Cook_Inlet_75004300002289 has a slope of 0.00611858 (0.3505644359607523 deg), stream order of 3, and ds dist to outlet of 16.92847388
#  area diff of 0.42072498404097214
# Cook_Inlet_75004300005303 has a slope of 0.00086123 (0.04934483199008553 deg), stream order of 4, and ds dist to outlet of 15.969979649999999
#  area diff of 1.762175106957173
# Cook_Inlet_75004300006376 has a slope of 0.01043677 (0.5979611621733518 deg), stream order of 4, and ds dist to outlet of 22.55912069
#  area diff of 0.035899878310466704
# Cook_Inlet_75004300000311 has a slope of 0.00759467 (0.4351341718868624 deg), stream order of 5, and ds dist to outlet of 37.38393442
#  area diff of 0.050199966633293513
# Cook_Inlet_75004300004452 has a slope of 0.00698696 (0.4003168055416232 deg), stream order of 5, and ds dist to outlet of 37.38393442
#  area diff of 0.005825049111166436
# Cook_Inlet_75004300003409 has a slope of 0.029445330000000002 (1.686605803504926 deg), stream order of 3, and ds dist to outlet of 45.03039831
#  area diff of -0.4655249544613751
# Cook_Inlet_75004300005352 has a slope of 0.00288768 (0.16545141670234997 deg), stream order of 4, and ds dist to outlet of 31.77733682
#  area diff of 0.08967502081785739
# Cook_Inlet_75004300003171 has a slope of 0.0030561200000000003 (0.1751022325428812 deg), stream order of 1, and ds dist to outlet of 35.16401682
#  area diff of 0.028374998269315554
# Cook_Inlet_75004300001162 has a slope of 0.008030240000000001 (0.4600889710724129 deg), stream order of 5, and ds dist to outlet of 2.25658771
#  area diff of 0.9131999236399793
# Cook_Inlet_75004300003171 has a slope of 0.0030561200000000003 (0.1751022325428812 deg), stream order of 1, and ds dist to outlet of 35.16401682
#  area diff of 0.028374998269315554
# Cook_Inlet_75004300003171 has a slope of 0.0030561200000000003 (0.1751022325428812 deg), stream order of 1, and ds dist to outlet of 35.16401682
#  area diff of 0.028374998269315554
# Cook_Inlet_75004300003171 has a slope of 0.0030561200000000003 (0.1751022325428812 deg), stream order of 1, and ds dist to outlet of 35.16401682
#  area diff of 0.028374998269315554
# Cook_Inlet_75004300001207 has a slope of 0.016190160000000002 (0.9275468000538383 deg), stream order of 3, and ds dist to outlet of 9.73961019
#  area diff of 0.49495002080127115
# Cook_Inlet_75004300002278 has a slope of 0.0112425 (0.6441206644696192 deg), stream order of 3, and ds dist to outlet of 13.34395498
#  area diff of 0.2665499866114249
# Cook_Inlet_75004300002207 has a slope of 0.00637575 (0.36529861646503703 deg), stream order of 6, and ds dist to outlet of 2.25658771
#  area diff of 0.06967480514452973
# Cook_Inlet_75004300005437 has a slope of 0.01640347 (0.9397653176660858 deg), stream order of 3, and ds dist to outlet of 34.01118718
#  area diff of 0.06182489214677034
# Cook_Inlet_75004300006440 has a slope of 0.04530245 (2.593865682831215 deg), stream order of 1, and ds dist to outlet of 37.42294636
#  area diff of 0.0001999551524725085
# Cook_Inlet_75004300006440 has a slope of 0.04530245 (2.593865682831215 deg), stream order of 1, and ds dist to outlet of 37.42294636
#  area diff of 0.0001999551524725085
# Cook_Inlet_75004300004217 has a slope of 0.00615773 (0.3528074812173062 deg), stream order of 4, and ds dist to outlet of 3.21333374
#  area diff of 2.102599938799159
# Cook_Inlet_75004300000101 has a slope of 0.01103163 (0.6320402018791539 deg), stream order of 2, and ds dist to outlet of 7.12093049
#  area diff of 0.15935000409962186
# Cook_Inlet_75004300001210 has a slope of 0.0037431400000000003 (0.21446512249979224 deg), stream order of 2, and ds dist to outlet of 9.59040247
#  area diff of 0.2945250684307341
# Cook_Inlet_75004300005171 has a slope of 0.01088186 (0.6234600430478173 deg), stream order of 2, and ds dist to outlet of 18.65759691
#  area diff of 0.024400022899595086
# Cook_Inlet_75004300005171 has a slope of 0.01088186 (0.6234600430478173 deg), stream order of 2, and ds dist to outlet of 18.65759691
#  area diff of 0.024400022899595086
# Cook_Inlet_75004300002314 has a slope of 0.02302141 (1.3187966833981475 deg), stream order of 1, and ds dist to outlet of 22.94363071
#  area diff of 0.025799953381245633
# Cook_Inlet_75004300003464 has a slope of 0.00986751 (0.5653483288806067 deg), stream order of 4, and ds dist to outlet of 49.47929749
#  area diff of 0.07492502492002018
# Cook_Inlet_75004300002352 has a slope of 0.01319037 (0.7557087057060136 deg), stream order of 1, and ds dist to outlet of 34.94664974
#  area diff of 0.00017502110553513361
# Cook_Inlet_75004300000101 has a slope of 0.01103163 (0.6320402018791539 deg), stream order of 2, and ds dist to outlet of 7.12093049
#  area diff of 0.15935000409962186
# Cook_Inlet_75004300000101 has a slope of 0.01103163 (0.6320402018791539 deg), stream order of 2, and ds dist to outlet of 7.12093049
#  area diff of 0.15935000409962186
# Cook_Inlet_75000400014405 has a slope of 0.00299803 (0.17177395120955324 deg), stream order of 1, and ds dist to outlet of 13.77345892
#  area diff of 0.10274996974995787
# Cook_Inlet_75000100002463 has a slope of 0.00620661 (0.3556079918859983 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 21.086400007999828
# Cook_Inlet_75004400008917 has a slope of 0.0018139200000000001 (0.10392984638747935 deg), stream order of 3, and ds dist to outlet of 6.28357775
#  area diff of 0.002825055719313241
# Cook_Inlet_75004400007385 has a slope of 0.00263804 (0.1511482075610339 deg), stream order of 3, and ds dist to outlet of 21.97225325
#  area diff of 1.0511498578508167
# Cook_Inlet_75004400010320 has a slope of 0.0034693700000000003 (0.19877946103366642 deg), stream order of 3, and ds dist to outlet of 16.84076231
#  area diff of 0.012599987531203283
# Cook_Inlet_75004400007387 has a slope of 0.0011007200000000001 (0.06306658495548223 deg), stream order of 3, and ds dist to outlet of 0.46237892
#  area diff of 2.1493249495380695
# Cook_Inlet_75004300004192 has a slope of 0.00223118 (0.12783698520311323 deg), stream order of 6, and ds dist to outlet of 1.75012969
#  area diff of 0.368274740425818
# Cook_Inlet_75004300004324 has a slope of 0.00382122 (0.21893871296770143 deg), stream order of 5, and ds dist to outlet of 1.8502868399999999
#  area diff of 0.04312499086654498
# Cook_Inlet_75004400000627 has a slope of 0.00770806 (0.44163055999833273 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.3390999665236336
# Cook_Inlet_75004400009144 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 2, and ds dist to outlet of 90.27662083
#  area diff of 0.01024994582074612
# Cook_Inlet_75004300006239 has a slope of 0.0055439700000000005 (0.31764282845915354 deg), stream order of 3, and ds dist to outlet of 0.80616615
#  area diff of 0.42785010257384215
# Cook_Inlet_75004300007331 has a slope of 0.012789710000000001 (0.7327564519825762 deg), stream order of 3, and ds dist to outlet of 0.0
#  area diff of 0.510999832735564
# Cook_Inlet_75000100000059 has a slope of 0.02835564 (1.6242232759392183 deg), stream order of 4, and ds dist to outlet of 0.9711735300000001
#  area diff of 0.6680501207499105
# Cook_Inlet_75004300000856 has a slope of 0.00729931 (0.41821222902422495 deg), stream order of 3, and ds dist to outlet of 51.19819046
#  area diff of 4.548871275364348
# Cook_Inlet_75004300006013 has a slope of 0.00024197000000000002 (0.01386385949820661 deg), stream order of 3, and ds dist to outlet of 43.02629164
#  area diff of 0.188900109817979
# Cook_Inlet_75004400000576 has a slope of 0.00391263 (0.2241760418549962 deg), stream order of 5, and ds dist to outlet of 126.13151634
#  area diff of 1.1928254238063687
# Cook_Inlet_75004400001568 has a slope of 0.00625725 (0.35850933748050257 deg), stream order of 4, and ds dist to outlet of 35.78780031
#  area diff of -0.11237568020789013
# Cook_Inlet_75004300001906 has a slope of 0.01286969 (0.7373382142620127 deg), stream order of 4, and ds dist to outlet of 0.64096662
#  area diff of 0.041500120765036286
# Cook_Inlet_75000200002930 has a slope of 0.00095177 (0.05453238760082265 deg), stream order of 5, and ds dist to outlet of 165.69840549
#  area diff of 1.3628500737499394
# Cook_Inlet_75000200010144 has a slope of 0.00305871 (0.17525062722465817 deg), stream order of 2, and ds dist to outlet of 140.23014882
#  area diff of 0.4686250267497556
# Cook_Inlet_75000100002523 has a slope of 0.00023476 (0.013450756951390683 deg), stream order of 4, and ds dist to outlet of 33.58765116
#  area diff of -0.07957484950040339
# Cook_Inlet_75000200015900 has a slope of 0.0003565 (0.02042594453108746 deg), stream order of 6, and ds dist to outlet of 69.83269571
#  area diff of 84.30267521774977
# Cook_Inlet_75000200018577 has a slope of 0.00131937 (0.07559428875293235 deg), stream order of 3, and ds dist to outlet of 145.51227885
#  area diff of 19.545299933000337
# Cook_Inlet_75000100004336 has a slope of 0.00505491 (0.2896225420124396 deg), stream order of 4, and ds dist to outlet of 1.36330182
#  area diff of 0.4057250009999933
# Cook_Inlet_75000200008551 has a slope of 0.00205194 (0.11756733681015741 deg), stream order of 5, and ds dist to outlet of 91.88539088
#  area diff of 0.00037493799999310795
# Cook_Inlet_75000100003947 has a slope of 0.01884513 (1.0796186206113747 deg), stream order of 3, and ds dist to outlet of 9.98230856
#  area diff of -0.020700077499355984
# Cook_Inlet_75000400000173 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 5, and ds dist to outlet of 18.92433619
#  area diff of 0.12119993200032297
# Cook_Inlet_75000200006065 has a slope of 0.0063028500000000005 (0.361121921988053 deg), stream order of 5, and ds dist to outlet of 128.30186774
#  area diff of 1.309524990750333
# Cook_Inlet_75000200003312 has a slope of 0.00094418 (0.054097513025123355 deg), stream order of 6, and ds dist to outlet of 81.43307841
#  area diff of 0.020199982000008276
# Cook_Inlet_75000100000981 has a slope of 0.0075239999999999994 (0.431085310516652 deg), stream order of 5, and ds dist to outlet of 14.96438699
#  area diff of 1.6701499579998256
# Cook_Inlet_75000200011141 has a slope of 0.00339523 (0.19453160198519429 deg), stream order of 4, and ds dist to outlet of 91.0169139
#  area diff of 0.1752249590001611
# Cook_Inlet_75000400014403 has a slope of 0.02026859 (1.1611456754563254 deg), stream order of 4, and ds dist to outlet of 36.75267603
#  area diff of -0.13412507999970558
# Cook_Inlet_75000100000652 has a slope of 0.00643582 (0.36874023271579154 deg), stream order of 4, and ds dist to outlet of 0.0
#  area diff of 0.4067750449997334
# Cook_Inlet_75000500011984 has a slope of 0.01409761 (0.8076800502437574 deg), stream order of 3, and ds dist to outlet of 194.78665631
#  area diff of 0.6512498795003268
# Cook_Inlet_75000100000004 has a slope of 0.00299637 (0.17167884106995568 deg), stream order of 5, and ds dist to outlet of 3.70331352
#  area diff of 0.029249892000166255
# Cook_Inlet_75000500009975 has a slope of 0.00405332 (0.23223685718389783 deg), stream order of 4, and ds dist to outlet of 204.31001819
#  area diff of 6.970924995250385
# Cook_Inlet_75000500009621 has a slope of 0.00807466 (0.4626338845808087 deg), stream order of 6, and ds dist to outlet of 286.32957183
#  area diff of 4.28097505050016
# Cook_Inlet_75000200012999 has a slope of 0.00027388 (0.015692167700685163 deg), stream order of 6, and ds dist to outlet of 19.33420978
#  area diff of 2.947324879749999
# Cook_Inlet_75000600030148 has a slope of 0.01295542 (0.7422493625808834 deg), stream order of 4, and ds dist to outlet of 185.78369141
#  area diff of 0.6348750017501175
# Cook_Inlet_75005300011378 has a slope of 0.0019955 (0.11433357625897826 deg), stream order of 6, and ds dist to outlet of 11.11695839
#  area diff of -0.1259497107223524
# Cook_Inlet_75005300022831 has a slope of 0.0026388600000000003 (0.15119518977317178 deg), stream order of 6, and ds dist to outlet of 4.7895335
#  area diff of 0.7885249046661329
# Cook_Inlet_75005400029139 has a slope of 0.00623461 (0.35721221163539035 deg), stream order of 4, and ds dist to outlet of 0.0
#  area diff of 0.14117498856998978
# Cook_Inlet_75005400013272 has a slope of 1e-05 (0.0005729577951117247 deg), stream order of 3, and ds dist to outlet of 2.86223972
#  area diff of 0.1557999649417603
# Cook_Inlet_75005400001203 has a slope of 0.02196502 (1.2583006081627834 deg), stream order of 6, and ds dist to outlet of 1.07007857
#  area diff of 0.004275277670501509
# Cook_Inlet_75004400006041 has a slope of 0.00069487 (0.039813111902411394 deg), stream order of 5, and ds dist to outlet of 47.50961999
#  area diff of 0.015674907538254956
# Cook_Inlet_75004300004332 has a slope of 0.00600703 (0.34417332668456113 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.19484976259985842
# Cook_Inlet_75004400003042 has a slope of 0.00339911 (0.19475390704413453 deg), stream order of 4, and ds dist to outlet of 1.15504841
#  area diff of 0.4414001364643809
# Cook_Inlet_75004300000105 has a slope of 0.00670645 (0.3842455199153629 deg), stream order of 4, and ds dist to outlet of 7.12093049
#  area diff of 0.011299971325740898
# Cook_Inlet_75004300004701 has a slope of 0.00238251 (0.1365075093597937 deg), stream order of 4, and ds dist to outlet of 10.75223137
#  area diff of 1.981950009603139
# Cook_Inlet_75000200013266 has a slope of 0.00064694 (0.037066926426970306 deg), stream order of 6, and ds dist to outlet of 100.91676429
#  area diff of 2.267825004500196
# Cook_Inlet_75000200015860 has a slope of 0.00848424 (0.4860994810757928 deg), stream order of 2, and ds dist to outlet of 103.02957036
#  area diff of 9.989275005040099e-05
# Cook_Inlet_75000200003094 has a slope of 0.00085635 (0.04906522879227526 deg), stream order of 6, and ds dist to outlet of 103.0189605
#  area diff of -0.28624986249974427
# Cook_Inlet_75000200002984 has a slope of 0.0015056800000000001 (0.08626904410457821 deg), stream order of 6, and ds dist to outlet of 98.22673247
#  area diff of 0.15617498625056214
# Cook_Inlet_75000200015782 has a slope of 0.00392055 (0.22462981746796598 deg), stream order of 3, and ds dist to outlet of 100.62792525
#  area diff of 0.0012499537502144165
# Cook_Inlet_75000200003013 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 6, and ds dist to outlet of 100.6809098
#  area diff of 909.7975999955003
# Cook_Inlet_75000200005504 has a slope of 0.00075967 (0.043525876449798405 deg), stream order of 6, and ds dist to outlet of 93.48598622
#  area diff of 0.7282000299999254
# Cook_Inlet_75000200000465 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 4, and ds dist to outlet of 95.2276344
#  area diff of -0.10257500350022042
# Cook_Inlet_75000200013237 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 6, and ds dist to outlet of 95.21042438
#  area diff of -0.28437499149981704
# Cook_Inlet_75000200018332 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 6, and ds dist to outlet of 88.33220876
#  area diff of 81.88577524449988
# Cook_Inlet_75000200013319 has a slope of 0.00065477 (0.037515552190512086 deg), stream order of 4, and ds dist to outlet of 89.06953632
#  area diff of 82.18450023774943
# Cook_Inlet_75000200005532 has a slope of 0.00018857 (0.01080426501472026 deg), stream order of 6, and ds dist to outlet of 89.05226815
#  area diff of -0.3856750004999867
# Cook_Inlet_75000200018331 has a slope of 0.00024793 (0.014205342323614426 deg), stream order of 6, and ds dist to outlet of 85.71048913999999
#  area diff of 84.44532521974998
# Cook_Inlet_75000200005503 has a slope of 0.00344269 (0.1972508278945614 deg), stream order of 3, and ds dist to outlet of 88.3759915
#  area diff of 2.504325017582687e-05
# Cook_Inlet_75000200015883 has a slope of 0.00081519 (0.04670693615514425 deg), stream order of 6, and ds dist to outlet of 73.98557283
#  area diff of 81.84610019675006
# Cook_Inlet_75000200005619 has a slope of 0.0041978300000000005 (0.24051652934384954 deg), stream order of 3, and ds dist to outlet of 75.32383592
#  area diff of 0.0005249480001623397
# Cook_Inlet_75000200015882 has a slope of 0.00111059 (0.0636320936079527 deg), stream order of 6, and ds dist to outlet of 75.21228254
#  area diff of 81.87167526974986
# Cook_Inlet_75000200000213 has a slope of 0.00390589 (0.2237898742026147 deg), stream order of 3, and ds dist to outlet of 190.31707949
#  area diff of 0.09182480250048286
# Cook_Inlet_75000200000011 has a slope of 0.01016681 (0.5824952349804439 deg), stream order of 1, and ds dist to outlet of 191.00066207
#  area diff of 2.4986750022826243e-05
# Cook_Inlet_75000200007853 has a slope of 0.00445219 (0.25509001113488294 deg), stream order of 3, and ds dist to outlet of 191.00066207
#  area diff of -0.11020018024952094
# Cook_Inlet_75000200002753 has a slope of 0.00544483 (0.3119626963571564 deg), stream order of 3, and ds dist to outlet of 186.06983573
#  area diff of -0.110750176749562
# Cook_Inlet_75000200018069 has a slope of 0.0260861 (1.4942845495590475 deg), stream order of 2, and ds dist to outlet of 188.33987863
#  area diff of 0.00017495300004011227
# Cook_Inlet_75000200007852 has a slope of 0.00343415 (0.1967615277223875 deg), stream order of 3, and ds dist to outlet of 188.33987863
#  area diff of -0.11062516924951638
# Cook_Inlet_75000200007639 has a slope of 0.00394432 (0.22599171708645083 deg), stream order of 3, and ds dist to outlet of 179.58456352
#  area diff of -0.11055015049963401
# Cook_Inlet_75000200010344 has a slope of 0.00792901 (0.45428928860864387 deg), stream order of 2, and ds dist to outlet of 186.06983573
#  area diff of 4.997700009568007e-05
# Cook_Inlet_75000200002753 has a slope of 0.00544483 (0.3119626963571564 deg), stream order of 3, and ds dist to outlet of 186.06983573
#  area diff of -0.110750176749562
# Cook_Inlet_75000200007839 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 4, and ds dist to outlet of 178.29430582
#  area diff of 1.0195998540003757
# Cook_Inlet_75000200015469 has a slope of 0.00911151 (0.5220366218846895 deg), stream order of 3, and ds dist to outlet of 179.58456352
#  area diff of -0.07697500499999421
# Cook_Inlet_75000200007639 has a slope of 0.00394432 (0.22599171708645083 deg), stream order of 3, and ds dist to outlet of 179.58456352
#  area diff of -0.11055015049963401
# Cook_Inlet_75000200000278 has a slope of 0.00281056 (0.16103280205652806 deg), stream order of 4, and ds dist to outlet of 150.70117757
#  area diff of -0.09692508749952822
# Cook_Inlet_75000200010532 has a slope of 0.00079008 (0.045268240058487376 deg), stream order of 5, and ds dist to outlet of 135.20132201
#  area diff of -0.01347501124956807
# Cook_Inlet_75000200005444 has a slope of 0.00052647 (0.030164506253347278 deg), stream order of 4, and ds dist to outlet of 136.31513729
#  area diff of 249.8317249645004
# Cook_Inlet_75000200000416 has a slope of 0.00107629 (0.06166685072051273 deg), stream order of 4, and ds dist to outlet of 136.31513729
#  area diff of -0.21495005299939862
# Cook_Inlet_75000200015680 has a slope of 0.0006323 (0.036228116558082404 deg), stream order of 5, and ds dist to outlet of 129.58531469
#  area diff of -0.21530002274960225
# Cook_Inlet_75000200005404 has a slope of 0.00041292 (0.02365857193192343 deg), stream order of 4, and ds dist to outlet of 129.93912925
#  area diff of 0.0001749987499835015
# Cook_Inlet_75000200000411 has a slope of 0.00075013 (0.042979275024741685 deg), stream order of 5, and ds dist to outlet of 129.92941748
#  area diff of -42.52492504249955
# Cook_Inlet_75000200002920 has a slope of 0.00171583 (0.09830972088502296 deg), stream order of 5, and ds dist to outlet of 122.62842405
#  area diff of 0.027399990000276375
# Cook_Inlet_75000200010148 has a slope of 0.00103968 (0.059569254580680096 deg), stream order of 2, and ds dist to outlet of 123.52808975
#  area diff of 7.503224987459589e-05
# Cook_Inlet_75000200008033 has a slope of 0.00101817 (0.058336823668159385 deg), stream order of 5, and ds dist to outlet of 123.51952535
#  area diff of -15.44182505624957
# Cook_Inlet_75000200013185 has a slope of 0.00339127 (0.194304713310752 deg), stream order of 5, and ds dist to outlet of 182.89570891
#  area diff of 0.3979250739999429
# Cook_Inlet_75000200010547 has a slope of 0.00347364 (0.19902411106382448 deg), stream order of 5, and ds dist to outlet of 181.53076304
#  area diff of -0.025449938250062587
# Cook_Inlet_75000200018235 has a slope of 0.008361180000000001 (0.47904916262180797 deg), stream order of 2, and ds dist to outlet of 181.00724645
#  area diff of 0.1409749872499919
# Cook_Inlet_75000200013187 has a slope of 0.00490374 (0.28096135378264675 deg), stream order of 5, and ds dist to outlet of 182.15532315
#  area diff of -0.06997494300003382
# Cook_Inlet_75000200010540 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 5, and ds dist to outlet of 172.13441239
#  area diff of -0.06824991650020706
# Cook_Inlet_75000200013179 has a slope of 0.00429724 (0.24621220002180713 deg), stream order of 3, and ds dist to outlet of 172.22801654
#  area diff of 2.4991999993062564e-05
# Cook_Inlet_75000200018266 has a slope of 0.00154815 (0.0887023901868611 deg), stream order of 5, and ds dist to outlet of 172.30017794
#  area diff of -0.01964989875017409
# Cook_Inlet_75000200002934 has a slope of 0.00049217 (0.028199261526039195 deg), stream order of 5, and ds dist to outlet of 167.36067069
#  area diff of 1.2732750769998802
# Cook_Inlet_75000200015657 has a slope of 0.0047633300000000005 (0.2729166413435346 deg), stream order of 3, and ds dist to outlet of 167.48257912
#  area diff of 1.338349973000227
# Cook_Inlet_75000200010538 has a slope of 0.0035083700000000002 (0.20101396923548165 deg), stream order of 5, and ds dist to outlet of 167.48257912
#  area diff of -49.97984990050031
# Cook_Inlet_75000200000418 has a slope of 0.00040864 (0.02341334603698728 deg), stream order of 5, and ds dist to outlet of 161.41235399
#  area diff of 1.507575104249952
# Cook_Inlet_75000200018259 has a slope of 0.00258157 (0.14791273692984613 deg), stream order of 3, and ds dist to outlet of 162.14163344
#  area diff of 0.00022507499988932977
# Cook_Inlet_75000200005448 has a slope of 0.00068342 (0.03915707553855911 deg), stream order of 5, and ds dist to outlet of 162.09755117
#  area diff of 1.2682250227500447
# Cook_Inlet_75000200013249 has a slope of 0.00076959 (0.04409425025025864 deg), stream order of 5, and ds dist to outlet of 156.09154791
#  area diff of 61.22262513574975
# Cook_Inlet_75000200018317 has a slope of 0.00491426 (0.2815640908581914 deg), stream order of 4, and ds dist to outlet of 156.44028433
#  area diff of 2.501574970636966e-05
# Cook_Inlet_75000200008110 has a slope of 0.00106866 (0.061229684425659854 deg), stream order of 5, and ds dist to outlet of 156.54212614
#  area diff of 1.2670501309999622
# Cook_Inlet_75000200005575 has a slope of 0.00119234 (0.0683160173702569 deg), stream order of 5, and ds dist to outlet of 151.80434236
#  area diff of 1.2690250912498868
# Cook_Inlet_75000200003070 has a slope of 0.00067427 (0.038632819397611304 deg), stream order of 2, and ds dist to outlet of 151.95530661
#  area diff of 0.0014249105003329987
# Cook_Inlet_75000200005573 has a slope of 0.0011914200000000001 (0.06826330532798645 deg), stream order of 5, and ds dist to outlet of 151.95530661
#  area diff of 1.2678251774995601
# Cook_Inlet_75000200003107 has a slope of 0.00125465 (0.0718861120463444 deg), stream order of 5, and ds dist to outlet of 150.34390331
#  area diff of 0.5230501639996987
# Cook_Inlet_75000200010712 has a slope of 0.00306611 (0.17567461201677315 deg), stream order of 2, and ds dist to outlet of 150.66294279
#  area diff of 7.508874974249125e-05
# Cook_Inlet_75000200015867 has a slope of 0.00289745 (0.16601119178458815 deg), stream order of 5, and ds dist to outlet of 150.67938925
#  area diff of 1.2672750827499044
# Cook_Inlet_75000200010144 has a slope of 0.00305871 (0.17525062722465817 deg), stream order of 2, and ds dist to outlet of 140.23014882
#  area diff of 0.4686250267497556
# Cook_Inlet_75000200013010 has a slope of 0.00390653 (0.22382654294199397 deg), stream order of 3, and ds dist to outlet of 139.10127096
#  area diff of 0.27342502024971793
# Cook_Inlet_75000200010359 has a slope of 0.00069533 (0.039839467948253125 deg), stream order of 2, and ds dist to outlet of 140.23014882
#  area diff of 0.06557498424998665
# Cook_Inlet_75000200008051 has a slope of 0.00327145 (0.1874396092063545 deg), stream order of 2, and ds dist to outlet of 167.59685655
#  area diff of 0.15335000300000434
# Cook_Inlet_75000200002552 has a slope of 0.010581430000000001 (0.6062486543428306 deg), stream order of 1, and ds dist to outlet of 163.56206434
#  area diff of 0.19737496000006782
# Cook_Inlet_75000200018203 has a slope of 0.00723739 (0.4146646617720253 deg), stream order of 2, and ds dist to outlet of 164.3739914
#  area diff of 0.023775090999958337
# Cook_Inlet_75000200005413 has a slope of 0.00191414 (0.10967200945370949 deg), stream order of 3, and ds dist to outlet of 163.45451656
#  area diff of 0.1689500577500027
# Cook_Inlet_75000200005077 has a slope of 0.00731174 (0.41892437755570094 deg), stream order of 3, and ds dist to outlet of 167.86535702
#  area diff of 0.1299249792500632
# Cook_Inlet_75000200008009 has a slope of 0.00205328 (0.1176441128312316 deg), stream order of 3, and ds dist to outlet of 164.3739914
#  area diff of 0.0001249672500307497
# Cook_Inlet_75000200015587 has a slope of 0.00780328 (0.4470859359763067 deg), stream order of 3, and ds dist to outlet of 184.82964713
#  area diff of 1.3461999975001007
# Cook_Inlet_75000200015584 has a slope of 0.00571714 (0.3275644240268145 deg), stream order of 3, and ds dist to outlet of 182.57152535
#  area diff of 2.7447250190000645
# Cook_Inlet_75000200007958 has a slope of 0.00955663 (0.5475378970455496 deg), stream order of 2, and ds dist to outlet of 184.82964713
#  area diff of 0.006000004749922017
# Cook_Inlet_75000200002806 has a slope of 0.012950950000000001 (0.7419932934110264 deg), stream order of 2, and ds dist to outlet of 182.57152535
#  area diff of 0.8750250012500179
# Cook_Inlet_75000200015505 has a slope of 0.00338237 (0.1937947867222272 deg), stream order of 3, and ds dist to outlet of 195.26162852
#  area diff of 0.08232483850045469
# Cook_Inlet_75000200007870 has a slope of 0.00346866 (0.19873878151975205 deg), stream order of 1, and ds dist to outlet of 190.15770518
#  area diff of 2.4808999702500056
# Cook_Inlet_75000200000011 has a slope of 0.01016681 (0.5824952349804439 deg), stream order of 1, and ds dist to outlet of 191.00066207
#  area diff of 2.4986750022826243e-05
# Cook_Inlet_75000200013189 has a slope of 0.00279349 (0.1600547707791236 deg), stream order of 4, and ds dist to outlet of 184.70623965
#  area diff of 0.056550009500199394
# Cook_Inlet_75000200013185 has a slope of 0.00339127 (0.194304713310752 deg), stream order of 5, and ds dist to outlet of 182.89570891
#  area diff of 0.3979250739999429
# Cook_Inlet_75000200018235 has a slope of 0.008361180000000001 (0.47904916262180797 deg), stream order of 2, and ds dist to outlet of 181.00724645
#  area diff of 0.1409749872499919
# Cook_Inlet_75000200007646 has a slope of 0.0027892 (0.1598089738001663 deg), stream order of 2, and ds dist to outlet of 175.80996734000001
#  area diff of 0.9316750424999061
# Cook_Inlet_75000200005606 has a slope of 0.00442997 (0.2538169240234956 deg), stream order of 2, and ds dist to outlet of 177.28662065
#  area diff of 0.048274990999946255
# Cook_Inlet_75000200002554 has a slope of 0.00511307 (0.2929547784198191 deg), stream order of 2, and ds dist to outlet of 177.28662065
#  area diff of 0.047674997249909534
# Cook_Inlet_75000200013258 has a slope of 0.00566163 (0.3243840382530903 deg), stream order of 1, and ds dist to outlet of 173.9881135
#  area diff of 0.6702999932500966
# Cook_Inlet_75000200005075 has a slope of 0.00720037 (0.4125436825436473 deg), stream order of 2, and ds dist to outlet of 193.58938509
#  area diff of 0.25067499500000423
# Cook_Inlet_75000200010391 has a slope of 0.00482477 (0.27643681313190066 deg), stream order of 2, and ds dist to outlet of 191.23481499
#  area diff of 1.9249000005000543
# Cook_Inlet_75000200013033 has a slope of 0.00875117 (0.5013923076911301 deg), stream order of 1, and ds dist to outlet of 193.58938509
#  area diff of 0.06615002649990509
# Cook_Inlet_75000200000010 has a slope of 0.01282192 (0.7346016464491263 deg), stream order of 2, and ds dist to outlet of 192.33304248
#  area diff of 2.9329999939998643
# Cook_Inlet_75000200015695 has a slope of 0.00638067 (0.3655805002327686 deg), stream order of 4, and ds dist to outlet of 184.70623965
#  area diff of 0.3075750602497891
# Cook_Inlet_75004400008917 has a slope of 0.0018139200000000001 (0.10392984638747935 deg), stream order of 3, and ds dist to outlet of 6.28357775
#  area diff of 0.002825055719313241
# Cook_Inlet_75004400009260 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 4, and ds dist to outlet of 111.14922122
#  area diff of 1.7822749391840205
# Cook_Inlet_75004400004829 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 4, and ds dist to outlet of 114.25348578
#  area diff of 0.003124951493830963
# Cook_Inlet_75004400001872 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 3, and ds dist to outlet of 121.78821488
#  area diff of 0.08857507387963892
# Cook_Inlet_75004400009308 has a slope of 0.00460022 (0.26357133160787755 deg), stream order of 3, and ds dist to outlet of 130.08427267
#  area diff of 1.8737000223300697
# Cook_Inlet_75004400010810 has a slope of 0.00031949 (0.018305427973799457 deg), stream order of 3, and ds dist to outlet of 135.8762201
#  area diff of 0.16624996501579403
# Cook_Inlet_75004400008917 has a slope of 0.0018139200000000001 (0.10392984638747935 deg), stream order of 3, and ds dist to outlet of 6.28357775
#  area diff of 0.002825055719313241
# Cook_Inlet_75004400001510 has a slope of 0.00046049000000000003 (0.026384131643051867 deg), stream order of 3, and ds dist to outlet of 19.02131239
#  area diff of 0.3507250647971887
# Cook_Inlet_75004400010402 has a slope of 0.00042156 (0.02415360738073305 deg), stream order of 2, and ds dist to outlet of 22.78125726
#  area diff of 5.679725078533863
# Cook_Inlet_75004400007388 has a slope of 0.00186732 (0.10698943064724051 deg), stream order of 3, and ds dist to outlet of 22.78125726
#  area diff of 12.210749990055767
# Cook_Inlet_75004400008856 has a slope of 0.01666718 (0.9548706575377357 deg), stream order of 4, and ds dist to outlet of 150.58876258
#  area diff of 0.7220980577964298
# Cook_Inlet_75004400008856 has a slope of 0.01666718 (0.9548706575377357 deg), stream order of 4, and ds dist to outlet of 150.58876258
#  area diff of 0.7220980577964298
# Cook_Inlet_75004400006846 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 4, and ds dist to outlet of 156.0010618
#  area diff of 0.012025191242386768
# Cook_Inlet_75004400010754 has a slope of 0.00518777 (0.2972346596157918 deg), stream order of 4, and ds dist to outlet of 105.52418172
#  area diff of 0.05222483366139841
# Cook_Inlet_75004400008917 has a slope of 0.0018139200000000001 (0.10392984638747935 deg), stream order of 3, and ds dist to outlet of 6.28357775
#  area diff of 0.002825055719313241
# Cook_Inlet_75004400008856 has a slope of 0.01666718 (0.9548706575377357 deg), stream order of 4, and ds dist to outlet of 150.58876258
#  area diff of 0.7220980577964298
# Cook_Inlet_75004400009261 has a slope of 0.01914164 (1.0966012656038966 deg), stream order of 4, and ds dist to outlet of 110.12852922
#  area diff of 0.33604994200780425
# Cook_Inlet_75000200017518 has a slope of 0.04983357 (2.8528931905494934 deg), stream order of 5, and ds dist to outlet of 180.88267139
#  area diff of 0.004699953750161967
# Cook_Inlet_75000200011392 has a slope of 0.00658264 (0.3771520426397753 deg), stream order of 3, and ds dist to outlet of 117.82471789
#  area diff of 0.008750077999735595
# Cook_Inlet_75000200013892 has a slope of 0.00557505 (0.3194235262481998 deg), stream order of 3, and ds dist to outlet of 101.99043292
#  area diff of 0.025324908750363306
# Cook_Inlet_75000200008676 has a slope of 0.007841270000000001 (0.4492624694620462 deg), stream order of 2, and ds dist to outlet of 118.11670411
#  area diff of 0.2736499722499879
# Cook_Inlet_75000200011034 has a slope of 0.00098097 (0.05620542280008677 deg), stream order of 2, and ds dist to outlet of 77.65309245
#  area diff of 0.02637506549994839
# Cook_Inlet_75000200007305 has a slope of 0.02471472 (1.415760937654118 deg), stream order of 5, and ds dist to outlet of 180.88267139
#  area diff of 0.17285001299999436
# Cook_Inlet_75000200008452 has a slope of 0.0034040200000000002 (0.19503522606650084 deg), stream order of 3, and ds dist to outlet of 53.24061148
#  area diff of 0.0312999867500281
# Cook_Inlet_75000200019263 has a slope of 0.03903951 (2.235663839158778 deg), stream order of 3, and ds dist to outlet of 150.12066131
#  area diff of -2.0422750509999528
# Cook_Inlet_75000200012046 has a slope of 0.011801250000000001 (0.6761304310283462 deg), stream order of 4, and ds dist to outlet of 161.30305104
#  area diff of 2.1426750054997967
# Cook_Inlet_75000200015319 has a slope of 5.443e-05 (0.0031186092758173144 deg), stream order of 3, and ds dist to outlet of 108.99049115
#  area diff of 6.277974914750438
# Cook_Inlet_75000200011623 has a slope of 0.021079070000000002 (1.2075629172340436 deg), stream order of 4, and ds dist to outlet of 147.99415206
#  area diff of 0.5951249602502404
# Cook_Inlet_75000200008734 has a slope of 0.016196330000000002 (0.9279002223386231 deg), stream order of 2, and ds dist to outlet of 115.75083957
#  area diff of 0.06262490375030794
# Cook_Inlet_75000200014508 has a slope of 0.00427472 (0.24492192276913574 deg), stream order of 6, and ds dist to outlet of 160.06659898
#  area diff of 2.7919000039999275
# Cook_Inlet_75000200019765 has a slope of 0.00526118 (0.30144062798546717 deg), stream order of 6, and ds dist to outlet of 165.92529862
#  area diff of 0.016274985250191776
# Cook_Inlet_75000200014914 has a slope of 0.0160787 (0.9211622744945303 deg), stream order of 6, and ds dist to outlet of 179.55345958
#  area diff of -0.11185001049975085
# Cook_Inlet_75000200002162 has a slope of 0.0225862 (1.2938739477483763 deg), stream order of 6, and ds dist to outlet of 180.06172103
#  area diff of 0.22869994700018026
# Cook_Inlet_75000200004615 has a slope of 0.02825176 (1.6182761546042637 deg), stream order of 6, and ds dist to outlet of 171.15249268
#  area diff of -0.050300040749817754
# Cook_Inlet_75000200018581 has a slope of 0.00059256 (0.03395118313454274 deg), stream order of 6, and ds dist to outlet of 44.71211928
#  area diff of 2.0007748450001372
# Cook_Inlet_75000200018581 has a slope of 0.00059256 (0.03395118313454274 deg), stream order of 6, and ds dist to outlet of 44.71211928
#  area diff of 2.0007748450001372
# Cook_Inlet_75000200000021 has a slope of 0.00071545 (0.04099225845841765 deg), stream order of 6, and ds dist to outlet of 47.80816116
#  area diff of 2.8408748412502973
# Cook_Inlet_75000200016094 has a slope of 0.00097517 (0.055873107596811494 deg), stream order of 6, and ds dist to outlet of 53.18940049
#  area diff of -0.0003501492496980063
# Cook_Inlet_75000200000021 has a slope of 0.00071545 (0.04099225845841765 deg), stream order of 6, and ds dist to outlet of 47.80816116
#  area diff of 2.8408748412502973
# Cook_Inlet_75000200018667 has a slope of 0.00048397 (0.027729436245952727 deg), stream order of 6, and ds dist to outlet of 74.70435841
#  area diff of 0.30909993125033
# Cook_Inlet_75000200018667 has a slope of 0.00048397 (0.027729436245952727 deg), stream order of 6, and ds dist to outlet of 74.70435841
#  area diff of 0.30909993125033
# Cook_Inlet_75000200008508 has a slope of 0.00032873 (0.018834840920883174 deg), stream order of 6, and ds dist to outlet of 77.63842601
#  area diff of 0.006049851000511808
# Cook_Inlet_75000200018882 has a slope of 0.00111385 (0.06381887761810714 deg), stream order of 6, and ds dist to outlet of 94.6750483
#  area diff of 0.7454998867503946
# Cook_Inlet_75000200015320 has a slope of 0.00075485 (0.04324971095091097 deg), stream order of 6, and ds dist to outlet of 97.00930228
#  area diff of 6.700799949250154
# Cook_Inlet_75000200007660 has a slope of 0.00090821 (0.052036585604200145 deg), stream order of 6, and ds dist to outlet of 101.99043292
#  area diff of 0.004850021500033108
# Cook_Inlet_75000200007660 has a slope of 0.00090821 (0.052036585604200145 deg), stream order of 6, and ds dist to outlet of 101.99043292
#  area diff of 0.004850021500033108
# Cook_Inlet_75000200003732 has a slope of 0.0008136700000000001 (0.04661984662805054 deg), stream order of 6, and ds dist to outlet of 115.80708276
#  area diff of 1.4813500299998736
# Cook_Inlet_75000200013953 has a slope of 0.00057693 (0.033055650406978054 deg), stream order of 6, and ds dist to outlet of 117.52292256
#  area diff of 0.006349988750059765
# Cook_Inlet_75000200013953 has a slope of 0.00057693 (0.033055650406978054 deg), stream order of 6, and ds dist to outlet of 117.52292256
#  area diff of 0.006349988750059765
# Cook_Inlet_75000200008950 has a slope of 0.00137463 (0.07876044778331213 deg), stream order of 6, and ds dist to outlet of 139.24362997
#  area diff of -0.0009751767495913555
# Cook_Inlet_75000200003896 has a slope of 0.00300869 (0.17238471870992944 deg), stream order of 6, and ds dist to outlet of 142.91283687
#  area diff of 304.1074249720003
# Cook_Inlet_75000200014207 has a slope of 0.00348808 (0.19985145209559546 deg), stream order of 6, and ds dist to outlet of 150.1063115
#  area diff of 0.06862495525024315
# Cook_Inlet_75000200014207 has a slope of 0.00348808 (0.19985145209559546 deg), stream order of 6, and ds dist to outlet of 150.1063115
#  area diff of 0.06862495525024315
# Cook_Inlet_75000200011572 has a slope of 0.024035980000000002 (1.3768950941956268 deg), stream order of 4, and ds dist to outlet of 146.54316244
#  area diff of 0.051325088249795314
# Cook_Inlet_75000200016095 has a slope of 0.00283458 (0.16240903571604828 deg), stream order of 2, and ds dist to outlet of 57.40991132
#  area diff of 0.252624940750124
# Cook_Inlet_75000200014057 has a slope of 0.02176134 (1.2466361794128828 deg), stream order of 3, and ds dist to outlet of 142.09546279
#  area diff of 0.30362496700011654
# Cook_Inlet_75000200007670 has a slope of 0.03259462 (1.8668732202376652 deg), stream order of 4, and ds dist to outlet of 157.15529661
#  area diff of 0.01700001525005934
# Cook_Inlet_75004400009919 has a slope of 0.00266432 (0.1526539300631959 deg), stream order of 4, and ds dist to outlet of 35.8380878
#  area diff of 0.0024249239460090166
# Cook_Inlet_75004400011322 has a slope of 0.00698105 (0.39997820400044093 deg), stream order of 4, and ds dist to outlet of 29.27739239
#  area diff of 0.038200103295693566
# Cook_Inlet_75004400003452 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 2, and ds dist to outlet of 80.11514293
#  area diff of -5.357000216613619
# Cook_Inlet_75004400002041 has a slope of 0.03550915 (2.0336699650030368 deg), stream order of 4, and ds dist to outlet of 129.38884982
#  area diff of 0.02930029314173055
# Cook_Inlet_75004400002951 has a slope of 0.00224683 (0.12873365965731703 deg), stream order of 3, and ds dist to outlet of 131.77487568
#  area diff of 0.46352500254370455
# Cook_Inlet_75004400002950 has a slope of 0.05478862 (3.136021303745562 deg), stream order of 4, and ds dist to outlet of 114.68450344
#  area diff of 0.14760009682461828
# Cook_Inlet_75004400007948 has a slope of 0.00050533 (0.02895327379685875 deg), stream order of 5, and ds dist to outlet of 131.77487568
#  area diff of 0.011350112825397218
# Cook_Inlet_75004400000627 has a slope of 0.00770806 (0.44163055999833273 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.3390999665236336
# Cook_Inlet_75000200004615 has a slope of 0.02825176 (1.6182761546042637 deg), stream order of 6, and ds dist to outlet of 171.15249268
#  area diff of -0.050300040749817754
# Cook_Inlet_75000200013536 has a slope of 0.00025124 (0.014394991341988812 deg), stream order of 8, and ds dist to outlet of 133.33847851
#  area diff of 28189.09592501275
# Cook_Inlet_75000200000949 has a slope of 0.00420836 (0.2411198432439688 deg), stream order of 5, and ds dist to outlet of 123.64627074
#  area diff of -0.055925008249744224
# Cook_Inlet_75000200018806 has a slope of 0.00191332 (0.10962502708657523 deg), stream order of 6, and ds dist to outlet of 99.70490643
#  area diff of -0.08240005350012325
# Cook_Inlet_75000200008551 has a slope of 0.00205194 (0.11756733681015741 deg), stream order of 5, and ds dist to outlet of 91.88539088
#  area diff of 0.00037493799999310795
# Cook_Inlet_75000200011336 has a slope of 0.010184180000000001 (0.5834903596346595 deg), stream order of 6, and ds dist to outlet of 101.05933544
#  area diff of 0.2408250424998073
# Cook_Inlet_75000200000278 has a slope of 0.00281056 (0.16103280205652806 deg), stream order of 4, and ds dist to outlet of 150.70117757
#  area diff of -0.09692508749952822
# Cook_Inlet_75000200007927 has a slope of 0.00012716 (0.0072857312836142685 deg), stream order of 9, and ds dist to outlet of 39.66819973
#  area diff of 43955.983000259
# Cook_Inlet_75000100001919 has a slope of 0.0151977 (0.8706970374446256 deg), stream order of 4, and ds dist to outlet of 21.72436075
#  area diff of 0.7763250159998876
# Cook_Inlet_75000100000004 has a slope of 0.00299637 (0.17167884106995568 deg), stream order of 5, and ds dist to outlet of 3.70331352
#  area diff of 0.029249892000166255
# Cook_Inlet_75000100003094 has a slope of 0.02151531 (1.2325462959747056 deg), stream order of 5, and ds dist to outlet of 15.64003596
#  area diff of 3.7926749377500926
# Cook_Inlet_75000100004200 has a slope of 0.0078788 (0.4514126472286145 deg), stream order of 5, and ds dist to outlet of 34.85764007
#  area diff of 1.6560000037499023
# Cook_Inlet_75004400001952 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 6, and ds dist to outlet of 117.83679766
#  area diff of 6.8547256230604034
# Cook_Inlet_75004400006357 has a slope of 0.057665390000000004 (3.3003285181593798 deg), stream order of 5, and ds dist to outlet of 121.01374563
#  area diff of 2.369825049953832
# Cook_Inlet_75004400009331 has a slope of 0.02712412 (1.5537166413587225 deg), stream order of 5, and ds dist to outlet of 114.56395854
#  area diff of 0.30535004073185235
# Cook_Inlet_75004400003154 has a slope of 0.00117799 (0.06749382408912419 deg), stream order of 6, and ds dist to outlet of 60.41352348
#  area diff of 0.11105067460857754
# Cook_Inlet_75004400001498 has a slope of 0.00115931 (0.0664235403895832 deg), stream order of 6, and ds dist to outlet of 16.764383
#  area diff of 3.601674707893835
# Cook_Inlet_75004400011711 has a slope of 9.999999999999999e-06 (0.0005729577951117246 deg), stream order of 5, and ds dist to outlet of 7.60640323
#  area diff of 6.80565053555091
# Cook_Inlet_75000400014405 has a slope of 0.00299803 (0.17177395120955324 deg), stream order of 1, and ds dist to outlet of 13.77345892
#  area diff of 0.10274996974995787
# Cook_Inlet_75000400014403 has a slope of 0.02026859 (1.1611456754563254 deg), stream order of 4, and ds dist to outlet of 36.75267603
#  area diff of -0.13412507999970558
# Cook_Inlet_75000400009620 has a slope of 0.00287868 (0.1649357589732576 deg), stream order of 8, and ds dist to outlet of 23.51079247
#  area diff of 3.2196251437499086
# Cook_Inlet_75000300025361 has a slope of 0.00124468 (0.07131487401668478 deg), stream order of 8, and ds dist to outlet of 161.90740059
#  area diff of -0.7873248495006919
# Cook_Inlet_75000600010189 has a slope of 0.00086372 (0.049487498374948764 deg), stream order of 8, and ds dist to outlet of 60.82319073
#  area diff of -0.11570027237576141
# Cook_Inlet_75000500010609 has a slope of 0.00099549 (0.05703735670613667 deg), stream order of 7, and ds dist to outlet of 185.54204397
#  area diff of 0.41780008825026016
# Cook_Inlet_75000700032122 has a slope of 0.00037964 (0.0217517686893443 deg), stream order of 7, and ds dist to outlet of 459.93225566
#  area diff of 2.087125232999824
# Cook_Inlet_75000700030756 has a slope of 0.00223239 (0.12790631275101294 deg), stream order of 7, and ds dist to outlet of 289.12393297
#  area diff of -0.03147452975099441
# Cook_Inlet_75000700036166 has a slope of 0.00122163 (0.06999420830726509 deg), stream order of 7, and ds dist to outlet of 163.65840557
#  area diff of -0.9924998087499262
# Cook_Inlet_75004300004983 has a slope of 0.06700259 (3.833236231928123 deg), stream order of 2, and ds dist to outlet of 2.98567347
#  area diff of 0.0011001159443626563
# Cook_Inlet_75004300008012 has a slope of 0.00419574 (0.24039678327375524 deg), stream order of 3, and ds dist to outlet of 0.0
#  area diff of 1.6701999598852169
# Cook_Inlet_75004300006071 has a slope of 0.00523912 (0.30017671792797146 deg), stream order of 4, and ds dist to outlet of 3.15121446
#  area diff of 0.7599498138639547
# Cook_Inlet_75004300004332 has a slope of 0.00600703 (0.34417332668456113 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.19484976259985842
# Copper_River_75019700003889 has a slope of 0.0059723599999999995 (0.3421869532730603 deg), stream order of 3, and ds dist to outlet of 242.93652927
#  area diff of 5.503749944750325
# ...
# Bristol_Bay_4051616 has a slope of 0.029432662805 (1.685880655146261 deg), stream order of 2, and ds dist to outlet of 46.0702
#  area diff of 0.0044999999999997264
# Bristol_Bay_4060036 has a slope of 0.011896080487 (0.681563055007751 deg), stream order of 2, and ds dist to outlet of 39.716800000000006
#  area diff of 0.8839000000000006
# Bristol_Bay_4059736 has a slope of 0.008961813817 (0.513460362753695 deg), stream order of 3, and ds dist to outlet of 44.2416
#  area diff of 1.1018000000000008
# Bristol_Bay_4046617 has a slope of 0.005460887051 (0.31288267025666616 deg), stream order of 2, and ds dist to outlet of 7.7058
#  area diff of 0.7256
# Bristol_Bay_4084145 has a slope of 0.001507798999 (0.08639045352843917 deg), stream order of 5, and ds dist to outlet of 82.90360000000001
#  area diff of 0.08420000000000982
# Bristol_Bay_4061136 has a slope of 0.015126943845 (0.8666439401811147 deg), stream order of 3, and ds dist to outlet of 52.5715
#  area diff of 0.1899000000000015
# Bristol_Bay_4080045 has a slope of 0.000383556443 (0.021976164311271706 deg), stream order of 4, and ds dist to outlet of 78.0394
#  area diff of 0.07270000000001176
# Bristol_Bay_4095374 has a slope of 0.001365801706 (0.07825462474649321 deg), stream order of 3, and ds dist to outlet of 156.1139
#  area diff of 1.4284000000000034
# Bristol_Bay_4098114 has a slope of 0.000887879153 (0.05087171481666379 deg), stream order of 4, and ds dist to outlet of 153.91629999999998
#  area diff of 1.0472999999999928
# Bristol_Bay_4091164 has a slope of 0.0 (0.0 deg), stream order of 4, and ds dist to outlet of 178.6684
#  area diff of 0.0038999999999944635
# Bristol_Bay_4089574 has a slope of 0.009025427658 (0.5171048725734262 deg), stream order of 3, and ds dist to outlet of 168.8954
#  area diff of 0.05540000000000056
# Bristol_Bay_4102124 has a slope of 0.0 (0.0 deg), stream order of 5, and ds dist to outlet of 199.3117
#  area diff of 0.6735999999999933
# Bristol_Bay_4101274 has a slope of 0.008388824593 (0.480632970037661 deg), stream order of 3, and ds dist to outlet of 186.1397
#  area diff of 1.046400000000002
# Bristol_Bay_4105594 has a slope of 0.0 (0.0 deg), stream order of 5, and ds dist to outlet of 189.7244
#  area diff of 0.1518000000000086
# Bristol_Bay_4068584 has a slope of 0.022311355572 (1.2781344539806574 deg), stream order of 2, and ds dist to outlet of 124.19760000000001
#  area diff of 0.04279999999999995
# Bristol_Bay_4093084 has a slope of 0.005607741333 (0.3212965430981426 deg), stream order of 4, and ds dist to outlet of 130.51
#  area diff of 0.055499999999995
# Bristol_Bay_4069455 has a slope of 0.003968040009 (0.22735075222135098 deg), stream order of 3, and ds dist to outlet of 90.3798
#  area diff of 0.10769999999999946
# Bristol_Bay_4069495 has a slope of 0.001183630797 (0.06781701749968055 deg), stream order of 2, and ds dist to outlet of 90.9172
#  area diff of 0.036999999999999034
# Bristol_Bay_4075715 has a slope of 0.002143478515 (0.12281208429998654 deg), stream order of 3, and ds dist to outlet of 141.7752
#  area diff of 0.14199999999999946
# Bristol_Bay_4074184 has a slope of 0.027190138381 (1.5574964283295145 deg), stream order of 2, and ds dist to outlet of 128.32510000000002
#  area diff of 0.000300000000000189
# Bristol_Bay_4063775 has a slope of 0.003757553745 (0.21529095763980052 deg), stream order of 3, and ds dist to outlet of 100.8547
#  area diff of 0.6493000000000002
# Bristol_Bay_4087224 has a slope of 0.021349193085 (1.2230328677727966 deg), stream order of 3, and ds dist to outlet of 126.662
#  area diff of 0.009100000000000108
# Bristol_Bay_4051055 has a slope of 0.002591218463 (0.14846554944052653 deg), stream order of 2, and ds dist to outlet of 132.6258
#  area diff of 0.8335999999999997
# Bristol_Bay_4075474 has a slope of 0.031782663479 (1.8203996926032044 deg), stream order of 3, and ds dist to outlet of 126.49000000000001
#  area diff of 0.15350000000000108
# Bristol_Bay_4096064 has a slope of 0.011421487458 (0.6543745736251037 deg), stream order of 3, and ds dist to outlet of 119.0361
#  area diff of 0.10179999999999723
# Bristol_Bay_4076505 has a slope of 0.0 (0.0 deg), stream order of 4, and ds dist to outlet of 82.41730000000001
#  area diff of 0.009500000000002728
# Bristol_Bay_4064845 has a slope of 0.008627484035 (0.4943061589560953 deg), stream order of 3, and ds dist to outlet of 132.3485
#  area diff of 0.19510000000000005
# Bristol_Bay_4089394 has a slope of 0.0 (0.0 deg), stream order of 3, and ds dist to outlet of 126.7351
#  area diff of 0.2215000000000007
# Bristol_Bay_4076675 has a slope of 0.001085136218 (0.06217370108459085 deg), stream order of 3, and ds dist to outlet of 138.9926
#  area diff of 0.3536999999999999
# Bristol_Bay_4084915 has a slope of 0.0 (0.0 deg), stream order of 4, and ds dist to outlet of 118.35360000000001
#  area diff of 0.15720000000000312
# Bristol_Bay_4073375 has a slope of 0.001248241565 (0.0715189363426017 deg), stream order of 4, and ds dist to outlet of 106.5975
#  area diff of 0.00849999999999973
# Bristol_Bay_4075225 has a slope of 0.003747722319 (0.21472766635584234 deg), stream order of 4, and ds dist to outlet of 103.136
#  area diff of 0.028100000000002012
# Bristol_Bay_4073375 has a slope of 0.001248241565 (0.0715189363426017 deg), stream order of 4, and ds dist to outlet of 106.5975
#  area diff of 0.00849999999999973
# Bristol_Bay_4064055 has a slope of 0.009036346134 (0.5177304041505071 deg), stream order of 2, and ds dist to outlet of 104.5064
#  area diff of 0.08149999999999968
# Bristol_Bay_4074505 has a slope of 0.002136612695 (0.12241870359269465 deg), stream order of 4, and ds dist to outlet of 116.18260000000001
#  area diff of 0.35889999999999844
# Bristol_Bay_4096454 has a slope of 0.002751442326 (0.1576456350389238 deg), stream order of 4, and ds dist to outlet of 132.6304
#  area diff of 0.11209999999999809
# Bristol_Bay_4089384 has a slope of 0.005488304691 (0.3144535382319787 deg), stream order of 3, and ds dist to outlet of 126.92880000000001
#  area diff of 0.016299999999999315
# Bristol_Bay_4079234 has a slope of 0.010042777822 (0.5753894402167256 deg), stream order of 2, and ds dist to outlet of 120.9644
#  area diff of 0.11940000000000017
# Bristol_Bay_4082225 has a slope of 0.016018862051 (0.9177346953819683 deg), stream order of 2, and ds dist to outlet of 121.0027
#  area diff of 0.013199999999999878
# Bristol_Bay_4078235 has a slope of 0.001232871778 (0.07063831377076525 deg), stream order of 3, and ds dist to outlet of 92.9478
#  area diff of 1.504100000000001
# Bristol_Bay_4071625 has a slope of 0.002510385227 (0.14383417631030965 deg), stream order of 3, and ds dist to outlet of 93.8202
#  area diff of 0.22589999999999932
# Bristol_Bay_4071256 has a slope of 0.000962355647 (0.055138899941785655 deg), stream order of 5, and ds dist to outlet of 61.194300000000005
#  area diff of 0.08020000000001914
# Bristol_Bay_4071256 has a slope of 0.000962355647 (0.055138899941785655 deg), stream order of 5, and ds dist to outlet of 61.194300000000005
#  area diff of 0.08020000000001914
# Kodiak_76954 has a slope of 0.016769761203360992 (0.9607464852060594 deg), stream order of 4, and ds dist to outlet of 4.9914
#  area diff of 0.2339999999999982
# Kodiak_49617 has a slope of 0.0091129153408481 (0.5221171352988394 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.048499999999989996
# Kodiak_130735 has a slope of 0.015608283895005582 (0.8942161814666558 deg), stream order of 6, and ds dist to outlet of 5.573600000000001
#  area diff of 0.0
# Kodiak_106676 has a slope of 0.022088801455618774 (1.2653893238056373 deg), stream order of 5, and ds dist to outlet of 12.844100000000001
#  area diff of 0.0075999999999964984
# Kodiak_48267 has a slope of 0.00626999986816652 (0.35923982245666736 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.00539999999999452
# Kodiak_48267 has a slope of 0.00626999986816652 (0.35923982245666736 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.00539999999999452
# Kodiak_108356 has a slope of 0.007863756782466282 (0.45055078775189933 deg), stream order of 5, and ds dist to outlet of 0.2373
#  area diff of 0.035799999999994725
# Kodiak_50197 has a slope of 0.005507561972239533 (0.31555686582128434 deg), stream order of 4, and ds dist to outlet of 0.1431
#  area diff of 0.010899999999999466
# Kodiak_107796 has a slope of 0.0033254555716356 (0.19053386686563784 deg), stream order of 5, and ds dist to outlet of 17.048000000000002
#  area diff of 0.07290000000000418
# Kodiak_101556 has a slope of 0.008349755982868771 (0.478394660348431 deg), stream order of 3, and ds dist to outlet of 64.2086
#  area diff of 0.13179999999999836
# Kodiak_97276 has a slope of 0.013922891702474046 (0.7976713937876901 deg), stream order of 3, and ds dist to outlet of 29.2985
#  area diff of 0.032500000000002416
# Kodiak_103296 has a slope of 0.006809539255776431 (0.3901518294352092 deg), stream order of 5, and ds dist to outlet of 30.8992
#  area diff of 0.02459999999999951
# Kodiak_103196 has a slope of 0.0034195710022876307 (0.19592622249325342 deg), stream order of 4, and ds dist to outlet of 21.2568
#  area diff of 0.7454000000000036
# Kodiak_94216 has a slope of 0.057812324708863536 (3.3087192838958623 deg), stream order of 3, and ds dist to outlet of 63.684000000000005
#  area diff of 0.09020000000000117
# Kodiak_103096 has a slope of 0.013533471183513439 (0.7753634460991349 deg), stream order of 5, and ds dist to outlet of 57.4249
#  area diff of 0.0257000000000005
# Kodiak_99516 has a slope of 0.019830438159168254 (1.1360515120190648 deg), stream order of 3, and ds dist to outlet of 65.3664
#  area diff of 0.0
# Kodiak_93176 has a slope of 0.029289321881345247 (1.6776748991219672 deg), stream order of 3, and ds dist to outlet of 61.0341
#  area diff of 0.0
# Kodiak_100826 has a slope of 0.00229213661685848 (0.13132952421673832 deg), stream order of 4, and ds dist to outlet of 64.2086
#  area diff of 0.07870000000000132
# Kodiak_90346 has a slope of 0.00793174906671882 (0.45444621570214766 deg), stream order of 3, and ds dist to outlet of 32.922900000000006
#  area diff of 0.5662000000000003
# Kodiak_50197 has a slope of 0.005507561972239533 (0.31555686582128434 deg), stream order of 4, and ds dist to outlet of 0.1431
#  area diff of 0.010899999999999466
# Kodiak_101556 has a slope of 0.008349755982868771 (0.478394660348431 deg), stream order of 3, and ds dist to outlet of 64.2086
#  area diff of 0.13179999999999836
# Kodiak_99516 has a slope of 0.019830438159168254 (1.1360515120190648 deg), stream order of 3, and ds dist to outlet of 65.3664
#  area diff of 0.0
# Kodiak_103456 has a slope of 0.002300745636229125 (0.13182278209115422 deg), stream order of 5, and ds dist to outlet of 28.725900000000003
#  area diff of 0.5699999999999932
# Kodiak_64593 has a slope of 0.03644656429624823 (2.08731041139892 deg), stream order of 5, and ds dist to outlet of 0.0
#  area diff of 0.0
# Kodiak_77794 has a slope of 0.018359547772842648 (1.0518064332587576 deg), stream order of 4, and ds dist to outlet of 0.4731
#  area diff of 0.38700000000000045
# Kodiak_50197 has a slope of 0.005507561972239533 (0.31555686582128434 deg), stream order of 4, and ds dist to outlet of 0.1431
#  area diff of 0.010899999999999466
# Kodiak_106626 has a slope of 0.009413224254701064 (0.5393220922214395 deg), stream order of 5, and ds dist to outlet of 13.3421
#  area diff of 0.29590000000001737
# Kodiak_107816 has a slope of 0.028706435157599883 (1.644306009988758 deg), stream order of 5, and ds dist to outlet of 16.1947
#  area diff of 0.03049999999996089
# Kodiak_129955 has a slope of 0.0030946618214106195 (0.17731049535836896 deg), stream order of 6, and ds dist to outlet of 40.4215
#  area diff of 0.013500000000021828
# Kodiak_103496 has a slope of 0.003790064347025633 (0.21715365139733064 deg), stream order of 4, and ds dist to outlet of 5.026
#  area diff of 0.006999999999997897
# Kodiak_130295 has a slope of 0.008111334802740195 (0.46473505837230716 deg), stream order of 6, and ds dist to outlet of 27.747400000000003
#  area diff of 0.059599999999988995
# Kodiak_128685 has a slope of 0.05489083339577325 (3.141860140236732 deg), stream order of 5, and ds dist to outlet of 1.4778
#  area diff of 0.0315000000000083
# Kodiak_72144 has a slope of 0.09473429828459408 (5.411724698576367 deg), stream order of 3, and ds dist to outlet of 2.7894
#  area diff of 0.0049000000000001265
# Prince_William_Sound_29854 has a slope of 0.003040920791 (0.17423139010841449 deg), stream order of 4, and ds dist to outlet of 1.3582
#  area diff of 0.15380000000000038
# Prince_William_Sound_26464 has a slope of 0.042029061444 (2.406671422706586 deg), stream order of 2, and ds dist to outlet of 0.42210000000000003
#  area diff of 0.19599999999999973
# Prince_William_Sound_36645 has a slope of 0.01277395809 (0.7318540814453655 deg), stream order of 3, and ds dist to outlet of 0.1814
#  area diff of 0.0
# Prince_William_Sound_31865 has a slope of 0.033946415878 (1.9442397679323322 deg), stream order of 2, and ds dist to outlet of 0.0
#  area diff of 0.036700000000000066
# Prince_William_Sound_28086 has a slope of 0.015533008589 (0.8899042695346079 deg), stream order of 2, and ds dist to outlet of 0.25660000000000005
#  area diff of 0.2647000000000004
# Prince_William_Sound_41515 has a slope of 0.013587329482 (0.7784487319573102 deg), stream order of 2, and ds dist to outlet of 0.0
#  area diff of 0.013500000000000512
# Prince_William_Sound_30884 has a slope of 0.00367468682 (0.21054309814459307 deg), stream order of 4, and ds dist to outlet of 0.2449
#  area diff of 0.15419999999999945
# Prince_William_Sound_38993 has a slope of 0.015076576048 (0.8637587359990165 deg), stream order of 2, and ds dist to outlet of 0.0
#  area diff of 0.11719999999999997
# Prince_William_Sound_43055 has a slope of 0.0 (0.0 deg), stream order of 3, and ds dist to outlet of 7.3175
#  area diff of 0.03799999999999848
# Prince_William_Sound_43973 has a slope of 0.013652347802 (0.7821733163726037 deg), stream order of 3, and ds dist to outlet of 0.2214
#  area diff of 0.14409999999999812
# Prince_William_Sound_43383 has a slope of 0.015590375816 (0.8931903737395973 deg), stream order of 4, and ds dist to outlet of 0.2131
#  area diff of 0.0
# Prince_William_Sound_44553 has a slope of 0.000976591401 (0.05595454779754814 deg), stream order of 5, and ds dist to outlet of 0.258
#  area diff of 0.033699999999996066
# Prince_William_Sound_46513 has a slope of 0.0 (0.0 deg), stream order of 6, and ds dist to outlet of 0.0
#  area diff of 0.1955000000000382
# Prince_William_Sound_43933 has a slope of 0.013668350211 (0.7830900158095042 deg), stream order of 4, and ds dist to outlet of 0.0
#  area diff of 0.07290000000000418
# Prince_William_Sound_46055 has a slope of 0.004566315355 (0.26162877934959256 deg), stream order of 3, and ds dist to outlet of 0.028300000000000002
#  area diff of 0.13929999999999998
# Prince_William_Sound_37815 has a slope of 0.009342145587 (0.5352499426592702 deg), stream order of 3, and ds dist to outlet of 0.0
#  area diff of 0.010299999999999976
# Prince_William_Sound_18457 has a slope of 0.007760792884 (0.4446517509606565 deg), stream order of 3, and ds dist to outlet of 0.0
#  area diff of 0.1902999999999988
# Prince_William_Sound_36645 has a slope of 0.01277395809 (0.7318540814453655 deg), stream order of 3, and ds dist to outlet of 0.1814
#  area diff of 0.0
# Prince_William_Sound_37815 has a slope of 0.009342145587 (0.5352499426592702 deg), stream order of 3, and ds dist to outlet of 0.0
#  area diff of 0.010299999999999976
# Prince_William_Sound_42563 has a slope of 0.021710079985 (1.2437005837922386 deg), stream order of 3, and ds dist to outlet of 0.2773
#  area diff of 0.001900000000000901
# Prince_William_Sound_43185 has a slope of 0.058701747171 (3.3595070661257056 deg), stream order of 4, and ds dist to outlet of 21.6573
#  area diff of 0.1883999999999979
# Prince_William_Sound_40285 has a slope of 0.0 (0.0 deg), stream order of 3, and ds dist to outlet of 5.1632
#  area diff of 0.060699999999998866
# Join Fields Complete
# ----------
# <Result 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\all_sites_sj_merge'>

# %%
import arcpy,os
sitesmerge = os.path.join(outgdb,'all_sites_sj_merge')
#Get distance to coastline
coast = r'D:\\Basedata\\AKSSF_Basedata\\AKSSF_Basedata.gdb\\NHD_H_Alaska_Coastline_alb'
arcpy.analysis.Near(sitesmerge, coast, None, "NO_LOCATION", "NO_ANGLE", "GEODESIC", "NEAR_DIST NEAR_DIST")
arcpy.AlterField_management(sitesmerge,'NEAR_DIST','dist_coast_km','dist_coast_km' )
#convert distance in meters to km
arcpy.CalculateField_management(sitesmerge,'dist_coast_km','!dist_coast_km! * .001')
arcpy.DeleteField_management(sitesmerge,'NEAR_FID')
# Out:
# <Result 'D:\\\\GIS\\\\sites_outputs_20230523\\\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\all_sites_sj_merge'>

# %%
import arcpy
import pandas as pd
print(sitesmerge)
sitemerge_df = pd.DataFrame()
fields = ['SiteID', 'cat_ID_con', 'area_diff', 'lat', 'lon', 'site_max_acc', 'site_acc_sqKm', 'Area_km2', 'str_slope','str_slope_dg',
          'str_ord','dist_coast_km', 'ds_dist_outlet']
sitesmerge_arr = arcpy.da.TableToNumPyArray(sitesmerge, fields)
sitemerge_df = pd.DataFrame(sitesmerge_arr)
#sitemerge_df = sitemerge_df.set_index('cat_ID_con')

sitemerge_df
# Out:
# D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\AKSSF_land_met_2023.gdb\all_sites_sj_merge
#                           SiteID                  cat_ID_con  area_diff  \
# 0                           APU1   Cook_Inlet_75004300004192   0.368275
# 1                          APU10   Cook_Inlet_75004300004192   0.368275
# 2                          APU11   Cook_Inlet_75004300004304   0.549225
# 3                          APU12   Cook_Inlet_75004300005245   0.039050
# 4                           APU2   Cook_Inlet_75004300003171   0.028375
# ..                           ...                         ...        ...
# 484               USFS_ERB Creek  Prince_William_Sound_36645   0.000000
# 485  USFS_Solf Lake Outlet Creek  Prince_William_Sound_37815   0.010300
# 486                     15219000  Prince_William_Sound_42563   0.001900
# 487                     15236900  Prince_William_Sound_43185   0.188400
# 488                     15237030  Prince_William_Sound_40285   0.060700
#
#            lat         lon  site_max_acc  site_acc_sqKm    Area_km2  \
# 0    59.772331 -151.836189      23256415     581.410375  581.778650
# 1    59.772246 -151.836298      23256415     581.410375  581.778650
# 2    59.711509 -151.687566      12849755     321.243875  321.793100
# 3    59.778585 -151.818469       7080923     177.023075  177.062125
# 4    59.863859 -151.657504        355448       8.886200    8.914575
# ..         ...         ...           ...            ...         ...
# 484  60.376606 -148.151917         35947       3.594700    3.594700
# 485  60.430692 -147.730911         52568       5.256800    5.267100
# 486  60.761069 -146.174397        122609      12.260900   12.262800
# 487  60.369804 -148.899220        237645      23.764500   23.952900
# 488  60.447986 -148.117277        123168      12.316800   12.377500
#
#      str_slope  str_slope_dg  str_ord  dist_coast_km  ds_dist_outlet
# 0     0.002231      0.127837        6       1.431231        1.750130
# 1     0.002231      0.127837        6       1.429151        1.750130
# 2     0.005771      0.330648        6       4.265209       16.928474
# 3     0.003202      0.183446        5       2.232399        3.621428
# 4     0.003056      0.175102        1       7.659494       35.164017
# ..         ...           ...      ...            ...             ...
# 484   0.012774      0.731854        3       0.035917        0.181400
# 485   0.009342      0.535250        3       0.029536        0.000000
# 486   0.021710      1.243701        3       0.416277        0.277300
# 487   0.058702      3.359507        4      11.920299       21.657300
# 488   0.000000      0.000000        3       1.094722        5.163200
#
# [489 rows x 13 columns]

# %%
import os
#Export CSV to read into R
outdir = r"C:\Users\dwmerrigan\Documents\GitHub\AKSSF\data_preparation\sensitivity_drivers"
sj_outname = 'AKSSF_sites_sj_maxfac_2023.csv'
arcpy.da.NumPyArrayToTable(sitesmerge_arr,os.path.join(outdir,sj_outname))
print('CSV export complete')
print('----------')
# Out:
# CSV export complete
# ----------

# %%
#Delete Clips
arcpy.env.workspace = outgdb
fcs = arcpy.ListFeatureClasses(wild_card='clip_*')
fcs
arcpy.Delete_management(fcs)
# Out:
# ['clip_1',
#  'clip_2',
#  'clip_3',
#  'clip_4',
#  'clip_5',
#  'clip_6',
#  'clip_7',
#  'clip_8',
#  'clip_9',
#  'clip_10',
#  'clip_11',
#  'clip_12',
#  'clip_13',
#  'clip_14',
#  'clip_15',
#  'clip_16',
#  'clip_17',
#  'clip_18',
#  'clip_19',
#  'clip_20',
#  'clip_21',
#  'clip_22',
#  'clip_23',
#  'clip_24',
#  'clip_25',
#  'clip_26',
#  'clip_27',
#  'clip_28',
#  'clip_29',
#  'clip_30',
#  'clip_31',
#  'clip_32',
#  'clip_33',
#  'clip_34',
#  'clip_35',
#  'clip_36',
#  'clip_37',
#  'clip_38',
#  'clip_39',
#  'clip_40',
#  'clip_41',
#  'clip_42',
#  'clip_43',
#  'clip_44',
#  'clip_45',
#  'clip_46',
#  'clip_47',
#  'clip_48',
#  'clip_49',
#  'clip_50',
#  'clip_51',
#  'clip_52',
#  'clip_53',
#  'clip_54',
#  'clip_55',
#  'clip_56',
#  'clip_57',
#  'clip_58',
#  'clip_59',
#  'clip_60',
#  'clip_61',
#  'clip_62',
#  'clip_63',
#  'clip_64',
#  'clip_65',
#  'clip_66',
#  'clip_67',
#  'clip_68',
#  'clip_69',
#  'clip_70',
#  'clip_71',
#  'clip_72',
#  'clip_73',
#  'clip_74',
#  'clip_75',
#  'clip_76',
#  'clip_77',
#  'clip_78',
#  'clip_79',
#  'clip_80',
#  'clip_81',
#  'clip_82',
#  'clip_83',
#  'clip_84',
#  'clip_85',
#  'clip_86',
#  'clip_87',
#  'clip_88',
#  'clip_89',
#  'clip_90',
#  'clip_91',
#  'clip_92',
#  'clip_93',
#  'clip_94',
#  'clip_95',
#  'clip_96',
#  'clip_97',
#  'clip_98',
#  'clip_99',
#  'clip_100',
#  'clip_101',
#  'clip_102',
#  'clip_103',
#  'clip_104',
#  'clip_105',
#  'clip_106',
#  'clip_107',
#  'clip_108',
#  'clip_109',
#  'clip_110',
#  'clip_111',
#  'clip_112',
#  'clip_113',
#  'clip_114',
#  'clip_115',
#  'clip_116',
#  'clip_117',
#  'clip_118',
#  'clip_119',
#  'clip_120',
#  'clip_121',
#  'clip_122',
#  'clip_123',
#  'clip_124',
#  'clip_125',
#  'clip_126',
#  'clip_127',
#  'clip_128',
#  'clip_129',
#  'clip_130',
#  'clip_131',
#  'clip_132',
#  'clip_133',
#  'clip_134',
#  'clip_135',
#  'clip_136',
#  'clip_137',
#  'clip_138',
#  'clip_139',
#  'clip_140',
#  'clip_141',
#  'clip_142',
#  'clip_143',
#  'clip_144',
#  'clip_145',
#  'clip_146',
#  'clip_147',
#  'clip_148',
#  'clip_149',
#  'clip_150',
#  'clip_151',
#  'clip_152',
#  'clip_153',
#  'clip_154',
#  'clip_155',
#  'clip_156',
#  'clip_157',
#  'clip_158',
#  'clip_159',
#  'clip_160',
#  'clip_161',
#  'clip_162',
#  'clip_163',
#  'clip_164',
#  'clip_165',
#  'clip_166',
#  'clip_167',
#  'clip_168',
#  'clip_169',
#  'clip_170',
#  'clip_171',
#  'clip_172',
#  'clip_173',
#  'clip_174',
#  'clip_175',
#  'clip_176',
#  'clip_177',
#  'clip_178',
#  'clip_179',
#  'clip_180',
#  'clip_181',
#  'clip_182',
#  'clip_183',
#  'clip_184',
#  'clip_185',
#  'clip_186',
#  'clip_187',
#  'clip_188',
#  'clip_189',
#  'clip_190',
#  'clip_191',
#  'clip_192',
#  'clip_193',
#  'clip_194',
#  'clip_195',
#  'clip_196',
#  'clip_197',
#  'clip_198',
#  'clip_199',
#  'clip_200',
#  'clip_201',
#  'clip_202',
#  'clip_203',
#  'clip_204',
#  'clip_205',
#  'clip_206',
#  'clip_207',
#  'clip_208',
#  'clip_209',
#  'clip_210',
#  'clip_211',
#  'clip_212',
#  'clip_213',
#  'clip_214',
#  'clip_215',
#  'clip_216',
#  'clip_217',
#  'clip_218',
#  'clip_219',
#  'clip_220',
#  'clip_221',
#  'clip_222',
#  'clip_223',
#  'clip_224',
#  'clip_225',
#  'clip_226',
#  'clip_227',
#  'clip_228',
#  'clip_229',
#  'clip_230',
#  'clip_231',
#  'clip_232',
#  'clip_233',
#  'clip_234',
#  'clip_235',
#  'clip_236',
#  'clip_237',
#  'clip_238',
#  'clip_239',
#  'clip_240',
#  'clip_241',
#  'clip_242',
#  'clip_243',
#  'clip_244',
#  'clip_245',
#  'clip_246',
#  'clip_247',
#  'clip_248',
#  'clip_249',
#  'clip_250',
#  'clip_251',
#  'clip_252',
#  'clip_253',
#  'clip_254',
#  'clip_255',
#  'clip_256',
#  'clip_257',
#  'clip_258',
#  'clip_259',
#  'clip_260',
#  'clip_261',
#  'clip_262',
#  'clip_263',
#  'clip_264',
#  'clip_265',
#  'clip_266',
#  'clip_267',
#  'clip_268',
#  'clip_269',
#  'clip_270',
#  'clip_271',
#  'clip_272',
#  'clip_273',
#  'clip_274',
#  'clip_275',
#  'clip_276',
#  'clip_277',
#  'clip_278',
#  'clip_279',
#  'clip_280',
#  'clip_281',
#  'clip_282',
#  'clip_283',
#  'clip_284',
#  'clip_285',
#  'clip_286',
#  'clip_287',
#  'clip_288',
#  'clip_289',
#  'clip_290',
#  'clip_291',
#  'clip_292',
#  'clip_293',
#  'clip_294',
#  'clip_295',
#  'clip_296',
#  'clip_297',
#  'clip_298',
#  'clip_299',
#  'clip_300',
#  'clip_301',
#  'clip_302',
#  'clip_303',
#  'clip_304',
#  'clip_305',
#  'clip_306',
#  'clip_307',
#  'clip_308',
#  'clip_309',
#  'clip_310',
#  'clip_311',
#  'clip_312',
#  'clip_313',
#  'clip_314',
#  'clip_315',
#  'clip_316',
#  'clip_317',
#  'clip_318',
#  'clip_319',
#  'clip_320',
#  'clip_321',
#  'clip_322',
#  'clip_323',
#  'clip_324',
#  'clip_325',
#  'clip_326',
#  'clip_327',
#  'clip_328',
#  'clip_329',
#  'clip_330',
#  'clip_331',
#  'clip_332',
#  'clip_333',
#  'clip_334',
#  'clip_335',
#  'clip_336',
#  'clip_337',
#  'clip_338',
#  'clip_339',
#  'clip_340',
#  'clip_341',
#  'clip_342',
#  'clip_343',
#  'clip_344',
#  'clip_345',
#  'clip_346',
#  'clip_347',
#  'clip_348',
#  'clip_349',
#  'clip_350',
#  'clip_351',
#  'clip_352',
#  'clip_353',
#  'clip_354',
#  'clip_355',
#  'clip_356',
#  'clip_357',
#  'clip_358',
#  'clip_359',
#  'clip_360',
#  'clip_361',
#  'clip_362',
#  'clip_363',
#  'clip_364',
#  'clip_365',
#  'clip_366',
#  'clip_367',
#  'clip_368',
#  'clip_369',
#  'clip_370',
#  'clip_371',
#  'clip_372',
#  'clip_373',
#  'clip_374',
#  'clip_375',
#  'clip_376',
#  'clip_377',
#  'clip_378',
#  'clip_379',
#  'clip_380',
#  'clip_381',
#  'clip_382',
#  'clip_383',
#  'clip_384',
#  'clip_385',
#  'clip_386',
#  'clip_387',
#  'clip_388',
#  'clip_389',
#  'clip_390',
#  'clip_391',
#  'clip_392',
#  'clip_393',
#  'clip_394',
#  'clip_395',
#  'clip_396',
#  'clip_397',
#  'clip_398',
#  'clip_399',
#  'clip_400',
#  'clip_401',
#  'clip_402',
#  'clip_403',
#  'clip_404',
#  'clip_405',
#  'clip_406',
#  'clip_407',
#  'clip_408',
#  'clip_409',
#  'clip_410',
#  'clip_411',
#  'clip_412',
#  'clip_413',
#  'clip_414',
#  'clip_415',
#  'clip_416',
#  'clip_417',
#  'clip_418',
#  'clip_419',
#  'clip_420',
#  'clip_421',
#  'clip_422',
#  'clip_423',
#  'clip_424',
#  'clip_425',
#  'clip_426',
#  'clip_427',
#  'clip_428',
#  'clip_429',
#  'clip_430',
#  'clip_431',
#  'clip_432',
#  'clip_433',
#  'clip_434',
#  'clip_435',
#  'clip_436',
#  'clip_437',
#  'clip_438',
#  'clip_439',
#  'clip_440',
#  'clip_441',
#  'clip_442',
#  'clip_443',
#  'clip_444',
#  'clip_445',
#  'clip_446',
#  'clip_447',
#  'clip_448',
#  'clip_449',
#  'clip_450',
#  'clip_451',
#  'clip_452',
#  'clip_453',
#  'clip_454',
#  'clip_455',
#  'clip_456',
#  'clip_457',
#  'clip_458',
#  'clip_459',
#  'clip_460',
#  'clip_461',
#  'clip_462',
#  'clip_463',
#  'clip_464',
#  'clip_465',
#  'clip_466',
#  'clip_467',
#  'clip_468',
#  'clip_469',
#  'clip_470',
#  'clip_471',
#  'clip_472',
#  'clip_473',
#  'clip_474',
#  'clip_475',
#  'clip_476',
#  'clip_477',
#  'clip_478',
#  'clip_479',
#  'clip_480',
#  'clip_481',
#  'clip_482',
#  'clip_483',
#  'clip_484',
#  'clip_485',
#  'clip_486',
#  'clip_487',
#  'clip_488',
#  'clip_489']

# %% [markdown]
# ### Compare Differences between old and new tables

# %%
# Specify the path and name of the first table
newTable = r"D:\\GIS\\sites_outputs_20230523\\AKSSF_land_met_2023\\AKSSF_land_met_2023.gdb\\AKSSF_wtd_covariates"

# Specify the path and name of the second table
oldTable = "D:\\GIS\\AKSSF_land_met\\AKSSF_land_met.gdb\\AKSSF_Covariates"

# Specify the common identifier field
common_field = 'cat_ID_con'

# Get the fields common to both tables
fields_table1 = [field.name for field in arcpy.ListFields(newTable)]
fields_table2 = [field.name for field in arcpy.ListFields(oldTable)]
common_fields = list(set(fields_table1) & set(fields_table2))

# Create an empty dictionary to store the differences
cat_Diffs = {}
diff_Details = {}

# Open a search cursor on the first table using the common fields
with arcpy.da.SearchCursor(newTable, [common_field] + common_fields) as cursor1:
    # Iterate through each row in the first table
    for row1 in cursor1:
        cat_ID_con = row1[0]
        field_values1 = row1[1:]

        # Initialize the value list for the dictionary
        value_list = []

        # Open a search cursor on the second table using the common fields
        with arcpy.da.SearchCursor(oldTable, [common_field] + common_fields) as cursor2:
            # Find the corresponding row in the second table based on the common identifier
            for row2 in cursor2:
                if row2[0] == cat_ID_con:
                    field_values2 = row2[1:]

                    # Compare the field values between the two tables
                    for i, (value1, value2) in enumerate(zip(field_values1, field_values2)):
                        field_name = common_fields[i]
                        source_table = 'newTable' if i < len(field_values1) else 'oldTable'

                        # Check if both values are not None
                        if value1 is not None and value2 is not None:
                            # Check if the field is a string
                            if isinstance(value1, str) or isinstance(value2, str):
                                # Store the string values instead of calculating the difference
                                field_dict = {'source_table': source_table, 'field_name': field_name, 'field_value1': value1, 'field_value2': value2}
                            else:
                                # Calculate the difference between the numeric values
                                diff_value = value2 - value1
                                field_dict = {'source_table': source_table, 'field_name': field_name, 'difference': diff_value}
                                # Store the difference details in the diff_Details dictionary
                                if cat_ID_con not in diff_Details:
                                    diff_Details[cat_ID_con] = []
                                diff_Details[cat_ID_con].append((field_name, diff_value))
                        else:
                            # Store the None values as is
                            field_dict = {'source_table': source_table, 'field_name': field_name, 'field_value1': value1, 'field_value2': value2}

                        # Append the field dictionary to the value list
                        value_list.append(field_dict)

        # Store the value list in the dictionary using the common identifier as the key
        if value_list:
            cat_Diffs[cat_ID_con] = value_list

# Print the differences
for key, value in cat_Diffs.items():
    print(f"{key}: {value}")

# Print the differences
for key, value in diff_Details.items():
    print(f"{key}: {value}")
# Out:
# Cook_Inlet_75004300006312: [{'source_table': 'newTable', 'field_name': 'non_wetland_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_STD', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MEAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'cat_ID_con', 'field_value1': 'Cook_Inlet_75004300006312', 'field_value2': 'Cook_Inlet_75004300006312'}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MAX', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_glacier_per', 'field_value1': None, 'field_value2': None}, {'source_table': 'newTable', 'field_name': 'wtd_slope_STD', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_COUNT', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'cat_ID_txt', 'field_value1': '75004300006312', 'field_value2': 75004300006312.0}, {'source_table': 'newTable', 'field_name': 'non_north_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_lake_area_sqm', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MEDIAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_RANGE', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_VARIETY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_PCT90', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_AREA', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_glacier_area_sqm', 'field_value1': None, 'field_value2': None}, {'source_table': 'newTable', 'field_name': 'wtd_wet_per', 'difference': -4.5690917893637106e-07}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MAX', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MIN', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'region', 'field_value1': 'Cook_Inlet', 'field_value2': 'Cook_Inlet'}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MEDIAN', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_SUM', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_SUM', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_PCT90', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_north_per', 'difference': 9.326171834800334e-08}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MEAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MINORITY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_lake_per', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_COUNT', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MIN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MAJORITY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wetland_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'OBJECTID', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_AREA', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'north_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_RANGE', 'difference': 0}]
# Cook_Inlet_75004300001906: [{'source_table': 'newTable', 'field_name': 'non_wetland_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_STD', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MEAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'cat_ID_con', 'field_value1': 'Cook_Inlet_75004300001906', 'field_value2': 'Cook_Inlet_75004300001906'}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MAX', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_glacier_per', 'field_value1': None, 'field_value2': None}, {'source_table': 'newTable', 'field_name': 'wtd_slope_STD', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_COUNT', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'cat_ID_txt', 'field_value1': '75004300001906', 'field_value2': 75004300001906.0}, {'source_table': 'newTable', 'field_name': 'non_north_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_lake_area_sqm', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MEDIAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_RANGE', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_VARIETY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_PCT90', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_AREA', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_glacier_area_sqm', 'field_value1': None, 'field_value2': None}, {'source_table': 'newTable', 'field_name': 'wtd_wet_per', 'difference': 2.3193359410811354e-07}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MAX', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MIN', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'region', 'field_value1': 'Cook_Inlet', 'field_value2': 'Cook_Inlet'}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MEDIAN', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_SUM', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_SUM', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_PCT90', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_north_per', 'difference': 4.527587886826723e-07}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MEAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MINORITY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_lake_per', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_COUNT', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MIN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MAJORITY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wetland_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'OBJECTID', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_AREA', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'north_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_RANGE', 'difference': 0}]
# Cook_Inlet_75004300000100: [{'source_table': 'newTable', 'field_name': 'non_wetland_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_STD', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MEAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'cat_ID_con', 'field_value1': 'Cook_Inlet_75004300000100', 'field_value2': 'Cook_Inlet_75004300000100'}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MAX', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_glacier_per', 'field_value1': None, 'field_value2': None}, {'source_table': 'newTable', 'field_name': 'wtd_slope_STD', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_COUNT', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'cat_ID_txt', 'field_value1': '75004300000100', 'field_value2': 75004300000100.0}, {'source_table': 'newTable', 'field_name': 'non_north_area', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_lake_area_sqm', 'difference': -7.275957614183426e-12}, {'source_table': 'newTable', 'field_name': 'wtd_slope_MEDIAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_RANGE', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_VARIETY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_PCT90', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_AREA', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_glacier_area_sqm', 'field_value1': None, 'field_value2': None}, {'source_table': 'newTable', 'field_name': 'wtd_wet_per', 'difference': 3.7988281320622264e-07}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MAX', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MIN', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'region', 'field_value1': 'Cook_Inlet', 'field_value2': 'Cook_Inlet'}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MEDIAN', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_SUM', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_SUM', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_slope_PCT90', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_north_per', 'difference': -2.1374511760541282e-07}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MEAN', 'difference': 0.0}, {'source_table': 'newTable', 'field_name': 'wtd_elev_MINORITY', 'difference': 0}, {'source_table': 'newTable', 'field_name': 'wtd_lake_per', 
('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', -6.811523434180344e-08), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -4.652099612201255e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', 0.16720221198925422), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_31865: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', 1.3781738275042699e-06), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -2.8198242318921984e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_36645: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', -4.371032702454869e-09), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', 2.8833007803541477e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_37815: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -10580.016495881719), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', 8.26263391040527e-10), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -4.4079589756051973e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.20086986189519251), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_38993: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -4442.195687729458), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', 1.7456054735021098e-07), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -1.3604736359695835e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.14019427153094277), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_40285: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -38094.37792113796), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', 4.454040580803564e-09), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', 4.5227050904372845e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.30777118094233913), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_41515: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', 43561.271630297124), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', -4.6276855414362217e-07), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', 6.323242160988229e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', 0.8199460091911295), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_42563: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -10081.524222338285), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', 9.557342584010087e-09), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -1.4086914035260634e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.082212253501144), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_43055: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -53574.33989511302), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', -5.792236468238343e-09), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -1.8231201259766294e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.35065183031785274), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_43185: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_glacier_per', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -10815.905454899068), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_glacier_area_sqm', 0.0), ('wtd_wet_per', 0.0), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', 4.8455810919278974e-08), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.04515488919879873), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_43383: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -10081.524222338285), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', -6.140136621368697e-09), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -2.0172119086225848e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.039447058634736666), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_43933: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_glacier_per', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', 1549.086306060257), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_glacier_area_sqm', 0.0), ('wtd_wet_per', -2.047271741023593e-09), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', 3.4594726550096766e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', 0.004787410356363209), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_43973: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', 2727.0825887556657), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', -9.872436756985792e-10), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', 3.0419921870361577e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', 0.01633091154959708), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_44553: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_glacier_per', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -12266.678416862229), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_glacier_area_sqm', 0.0), ('wtd_wet_per', 2.2514343278601245e-08), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -4.0527343792007287e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.024390768401648423), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_46055: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', 10302.036828657932), ('wtd_slope_MEDIAN', 0.0), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_wet_per', 2.4645996177241614e-07), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', 0.0), ('wtd_north_per', -3.9184570255201834e-08), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', 0.37280295392118157), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
# Prince_William_Sound_46513: [('non_wetland_area', 0.0), ('wtd_elev_STD', 0.0), ('wtd_slope_MEAN', 0.0), ('wtd_slope_MAX', 0.0), ('wtd_glacier_per', 0.0), ('wtd_slope_STD', 0.0), ('wtd_elev_COUNT', 0.0), ('non_north_area', 0.0), ('wtd_lake_area_sqm', -134988.9462633638), ('wtd_slope_MEDIAN', -1.52587890625e-05), ('wtd_slope_RANGE', 0.0), ('wtd_elev_VARIETY', 0), ('wtd_elev_PCT90', 0), ('wtd_slope_AREA', 0.0), ('wtd_glacier_area_sqm', 0.0), ('wtd_wet_per', -3.9523315287226524e-08), ('wtd_elev_MAX', 0), ('wtd_elev_MIN', 0), ('wtd_elev_MEDIAN', 0), ('wtd_elev_SUM', 0.0), ('wtd_slope_SUM', 0.0), ('wtd_slope_PCT90', -2.6702880859375e-05), ('wtd_north_per', 8.007812510868462e-07), ('wtd_elev_MEAN', 0.0), ('wtd_elev_MINORITY', 0), ('wtd_lake_per', -0.02856615092360105), ('wtd_slope_COUNT', 0.0), ('wtd_slope_MIN', 0.0), ('wtd_elev_MAJORITY', 0), ('wetland_area', 0.0), ('OBJECTID', 0), ('wtd_elev_AREA', 0.0), ('north_area', 0.0), ('wtd_elev_RANGE', 0)]
