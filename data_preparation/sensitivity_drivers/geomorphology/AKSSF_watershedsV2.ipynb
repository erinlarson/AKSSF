# %% [markdown]
# # Create watersheds and catchments
#
# AKSSF project has ~ 500 sites that have been shifted to the flow networks.
# We need to create watersheds for each. This will make extracting spatial
# and climatic covariates for modeling go much faster.
#
# Dustin pointed out that there are fromnodes and tonodes in the NHDPlus that can be used to navigate
# upstream, save all the NHPPlusIDs, select and merge the catchments to create watersheds for each site.
# This works in R so just need to transfer to python. Premise is to use a while loop to keep selecting
# new stream segments that have their tonode match the fromnode of the last segment(s).
# Logic for stopping while loop:
# Stop when summing the ids is not greater than 0. I'm not sure why this works, but it does
# for some watersheds, although I think it may be running infinitely on other watersheds.
# Alternatively, if sum(StartFlag) == count(rec) then all NHDPlusIDs are headwater streams.
#
# NOTE: creating an attribute index on the field that we are selecting on in the cats_merge
# feature class is really important for creating large watersheds. This vastly sped up the time
# for the Cook Inlet watersheds, like the mainstem Susitna. But, you can only run it once, then
# the index is created. This has been added to the Cook Inlet watersheds steps 4-7 code chunk.
# Update 20211122 - Now include eliminate polygon part in watershed creation and limit attribute index to only include
# streams/rivers and artificial paths when building watersheds.
#
# Create a loop and process watersheds for all the points. Start with Cook Inlet first.
# Note that folders, geodbs, and merged catchments are created in the merge_grids script.
# 1. select catchments that intersect points to get NHDPlusID
# 2. create list of IDs
# 3. use loop to create watersheds
# 4. first get list of all upstream NHDPlusIDs
# 5. create temporary layer of catchments
# 6. select catchments that match the upstream IDs
# 7. dissolved on those catchments and save to Cook Inlet gdb and watersheds feature dataset

# %%
#Set paths to gdbs
cr_gdb = r"D:\\GIS\\AKSSF\\Copper_River\\Copper_River.gdb"
ci_gdb = r"D:\\GIS\\AKSSF\\Cook_Inlet\\Cook_Inlet.gdb"
bbay_gdb = r"D:\\GIS\\AKSSF\\Bristol_Bay\\Bristol_Bay.gdb"
pws_gdb = r"D:\\GIS\\AKSSF\\Prince_William_Sound\\Prince_William_Sound.gdb"
kod_gdb = r"D:\\GIS\\AKSSF\\Kodiak\\Kodiak.gdb"
points = r"C:\\Users\\dwmerrigan\\Documents\\GitHub\\AKSSF\\hydrography\\AKSSF_Hydrography.gdb\\AKSSF_Sites_Shifted_2021202"

# %%
# COOK INLET
# steps 1 and 2
# intersect points with catchments and create list of NHDPlusIDs
import arcpy, os
arcpy.env.workspace = ci_gdb
arcpy.env.overwriteOutput = True
#Updated point layer - save to T: and change path once run.
points = r"C:\\Users\\dwmerrigan\\Documents\\GitHub\\AKSSF\\hydrography\\AKSSF_Hydrography.gdb\\AKSSF_Sites_Shifted_2021202"
cats = os.path.join(ci_gdb,'cats_merge')
#List to store catchments to create watersheds from
idList = []
outcats = "cats_intersect"

arcpy.MakeFeatureLayer_management(cats, "tempLayer")
#intersect cats merge with verified points
arcpy.management.SelectLayerByLocation("tempLayer", "INTERSECT", points)
arcpy.CopyFeatures_management("tempLayer", outcats)

fields = arcpy.ListFields("tempLayer")
for field in fields:
    print("{0}".format(field.name))
#Populate idList from cats_intersect
with arcpy.da.SearchCursor("tempLayer", ["NHDPlusID"]) as cursor:
    for row in cursor:
        idList.append(row[0])

print(len(idList))

#check if duplicate catchments in the idList
idset = set(idList)
print(idset)
print(len(idset))
# Out:
# OBJECTID
# Shape
# NHDPlusID
# SourceFC
# GridCode
# AreaSqKm
# VPUID
# Shape_Length
# Shape_Area
# 240
# {75004400010754.0, 75000200013319.0, 75004300001288.0, 75000200004615.0, 75004300002314.0, 75000200000010.0, 75000200000011.0, 75000200015883.0, 75000200015882.0, 75000300025361.0, 75000200000021.0, 75000200003094.0, 75004300002332.0, 75000200015900.0, 75000200008734.0, 75004400001568.0, 75000200003107.0, 75004300006440.0, 75004400009260.0, 75004400009261.0, 75005300022831.0, 75004300002352.0, 75004300000311.0, 75004400010810.0, 75004400011322.0, 75004300005437.0, 75004400000576.0, 75000200014914.0, 75000400014403.0, 75000200013892.0, 75000400014405.0, 75000700036166.0, 75000200011336.0, 75000200005532.0, 75004300008012.0, 75004400010320.0, 75004300003409.0, 75004400003154.0, 75004300000856.0, 75004400009308.0, 75004300004452.0, 75000200010344.0, 75000100003947.0, 75000200015469.0, 75000200017518.0, 75000500010609.0, 75004300001906.0, 75004400000627.0, 75004400009331.0, 75000200002162.0, 75004300004983.0, 75000200010359.0, 75000700032122.0, 75004300006013.0, 75000100001919.0, 75000200011392.0, 75000200013953.0, 75004300003464.0, 75000200007305.0, 75000200015505.0, 75000200018577.0, 75000200003732.0, 75000500009621.0, 75000200018069.0, 75000200010391.0, 75004400008856.0, 75000200018581.0, 75000100002463.0, 75000200007839.0, 75004400010402.0, 75000200007852.0, 75000400000173.0, 75000200007853.0, 75000200014508.0, 75005400001203.0, 75004300006071.0, 75004400006846.0, 75004400009919.0, 75000200007870.0, 75000200002753.0, 75000200012999.0, 75000200013010.0, 75004400006357.0, 75004400008917.0, 75000100000981.0, 75000200000213.0, 75004400007385.0, 75004400007387.0, 75004400007388.0, 75004400004829.0, 75000100002523.0, 75000200016095.0, 75000200013536.0, 75000200015584.0, 75000200016094.0, 75000200015587.0, 75000200013033.0, 75000200014057.0, 75000200018667.0, 75000200003312.0, 75000200002806.0, 75000200008950.0, 75000200007927.0, 75000100000004.0, 75000200008452.0, 75004400007948.0, 75000200012046.0, 75000100003094.0, 75000200007958.0, 75000200000278.0, 75000200011034.0, 75000200018203.0, 75000200005404.0, 75000700030756.0, 75000200010532.0, 75000200005413.0, 75000200015657.0, 75000200010538.0, 75000200010540.0, 75004300005171.0, 75000200010547.0, 75000200011572.0, 75000200019765.0, 75000200003896.0, 75000100000059.0, 75000200018235.0, 75000200008508.0, 75000200019263.0, 75000200015680.0, 75000200005444.0, 75000200005448.0, 75000200008009.0, 75000200015695.0, 75004400001872.0, 75000200018259.0, 75000200018266.0, 75004300004701.0, 75004300002142.0, 75004300006239.0, 75004300004192.0, 75000200008033.0, 75004300003171.0, 75004300000100.0, 75004300000101.0, 75000200008551.0, 75000100004200.0, 75004300000105.0, 75000200002920.0, 75000200011623.0, 75000200002930.0, 75000200008051.0, 75005300011378.0, 75000200002934.0, 75000200018806.0, 75004300004217.0, 75000200013179.0, 75004400003452.0, 75004300005245.0, 75000200005503.0, 75000200005504.0, 75000200013185.0, 75000200014207.0, 75000200013187.0, 75000200013189.0, 75004400002950.0, 75004400002951.0, 75000200011141.0, 75004300001162.0, 75000100000652.0, 75000200018317.0, 75000400009620.0, 75004400006041.0, 75000200000411.0, 75004300007324.0, 75000200018331.0, 75004300004254.0, 75004300002207.0, 75004400001952.0, 75000200000416.0, 75000200010144.0, 75004300007331.0, 75000200018332.0, 75000200010148.0, 75000200015782.0, 75000200000418.0, 75004300006312.0, 75000200002984.0, 75000200008110.0, 75000200006065.0, 75000200013237.0, 75000200000949.0, 75004300005303.0, 75004300001207.0, 75004400009144.0, 75004300001210.0, 75004400011711.0, 75000200013249.0, 75000200018882.0, 75000600030148.0, 75000200005573.0, 75000200003013.0, 75000200005575.0, 75000200013258.0, 75000600010189.0, 75004300004304.0, 75000500011984.0, 75000200013266.0, 75000200005075.0, 75000200000465.0, 75000200005077.0, 75005400029139.0, 75000200007639.0, 75000200010712.0, 75000200015319.0, 75004400001498.0, 75000200015320.0, 75005400013272.0, 75000200007646.0, 75004400003042.0, 75004300004324.0, 75000200008676.0, 75004300002278.0, 750 ...
# 240

# %%
# COOK INLET
# steps 4-7

import arcpy, time, datetime, os
import pandas as pd
from functools import reduce

# steps 4-9 for loop to create watersheds
arcpy.env.workspace = ci_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()

vaa = os.path.join(ci_gdb, "vaa_merge")
cats = os.path.join(ci_gdb, "cats_merge")
streams = os.path.join(ci_gdb,'NHDFlowline_merge')

# Get list of index names for cats merge and add index if not already created
index_names = [i.name for i in arcpy.ListIndexes(cats)]
print(index_names)
if 'NHDPlusID_index' not in index_names:
    print (f'Creating index for {cats}')
    arcpy.AddIndex_management(cats,'NHDPlusID','NHDPlusID_index')
else:
    print(f'{cats} Indexed')

#watersheds feature dataset for storing fcs
fdat = os.path.join(ci_gdb, 'Watersheds')
if not arcpy.Exists(fdat):
    print(f'Creating watershed feature dataset {fdat}')
    arcpy.management.CreateFeatureDataset(ci_gdb, "Watersheds", sr)
else:
    print(f'{fdat} exists for Cook Inlet')

vaa_df1 = pd.DataFrame(arcpy.da.TableToNumPyArray(vaa, ("NHDPlusID", "FromNode", "ToNode", "StartFlag")))
stream_df = pd.DataFrame(arcpy.da.TableToNumPyArray(streams, ("NHDPlusID", "FType")))
dfs = [vaa_df1, stream_df]
vaa_df = reduce(lambda left,right: pd.merge(left,right,on='NHDPlusID',how="outer"), dfs)
# remove pipelines
vaa_df = vaa_df[(vaa_df['FType'] != 428 )]
vaa_df

c=1
for id in idList:
    print(f"{c}. Starting watershed for: " + str(id))
    rec = [id]
    up_ids = []
    up_ids.append(rec)
    rec_len = len(rec)
    hws_sum = 0

    while rec_len != hws_sum:
        fromnode = vaa_df.loc[vaa_df["NHDPlusID"].isin(rec), "FromNode"]
        rec = vaa_df.loc[vaa_df["ToNode"].isin(fromnode), "NHDPlusID"]
        rec_len = len(rec)
        rec_hws = vaa_df.loc[vaa_df["ToNode"].isin(fromnode), "StartFlag"]
        hws_sum = sum(rec_hws)
        up_ids.append(rec)

    newup_ids = []
    for x in up_ids:
        newup_ids.extend(x)
    tempLayer = "catsLyr"
    expression = '"NHDPlusID" IN ({0})'.format(', '.join(map(str, newup_ids)) or 'NULL')
    arcpy.MakeFeatureLayer_management(cats, tempLayer, where_clause=expression)
    outdis = "memory/wtd_" + str(round(id))
    outwtd = "Watersheds\\wtd_" + str(round(id))
    print(outwtd)
    print('----------')
    dis = arcpy.Dissolve_management(tempLayer, outdis)
    watershed = arcpy.EliminatePolygonPart_management(dis, outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
    c=c+1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')
# Out:
# ['FDO_OBJECTID', 'FDO_Shape']
# Creating index for D:\\GIS\\AKSSF\\Cook_Inlet\\Cook_Inlet.gdb\cats_merge
# Creating watershed feature dataset D:\\GIS\\AKSSF\\Cook_Inlet\\Cook_Inlet.gdb\Watersheds
# 1. Starting watershed for: 75004300006312.0
# Watersheds\wtd_75004300006312
# ----------
# 2. Starting watershed for: 75004300001906.0
# Watersheds\wtd_75004300001906
# ----------
# 3. Starting watershed for: 75004300000100.0
# Watersheds\wtd_75004300000100
# ----------
# 4. Starting watershed for: 75004300004983.0
# Watersheds\wtd_75004300004983
# ----------
# 5. Starting watershed for: 75004300004332.0
# Watersheds\wtd_75004300004332
# ----------
# 6. Starting watershed for: 75004300006239.0
# Watersheds\wtd_75004300006239
# ----------
# 7. Starting watershed for: 75004300004304.0
# Watersheds\wtd_75004300004304
# ----------
# 8. Starting watershed for: 75004300002332.0
# Watersheds\wtd_75004300002332
# ----------
# 9. Starting watershed for: 75004300005437.0
# Watersheds\wtd_75004300005437
# ----------
# 10. Starting watershed for: 75004300003464.0
# Watersheds\wtd_75004300003464
# ----------
# 11. Starting watershed for: 75004300005171.0
# Watersheds\wtd_75004300005171
# ----------
# 12. Starting watershed for: 75004300004701.0
# Watersheds\wtd_75004300004701
# ----------
# 13. Starting watershed for: 75004300005303.0
# Watersheds\wtd_75004300005303
# ----------
# 14. Starting watershed for: 75004300006440.0
# Watersheds\wtd_75004300006440
# ----------
# 15. Starting watershed for: 75004300004254.0
# Watersheds\wtd_75004300004254
# ----------
# 16. Starting watershed for: 75004300001207.0
# Watersheds\wtd_75004300001207
# ----------
# 17. Starting watershed for: 75004300005245.0
# Watersheds\wtd_75004300005245
# ----------
# 18. Starting watershed for: 75004300000311.0
# Watersheds\wtd_75004300000311
# ----------
# 19. Starting watershed for: 75004300008012.0
# Watersheds\wtd_75004300008012
# ----------
# 20. Starting watershed for: 75004300004192.0
# Watersheds\wtd_75004300004192
# ----------
# 21. Starting watershed for: 75004300007324.0
# Watersheds\wtd_75004300007324
# ----------
# 22. Starting watershed for: 75004300001162.0
# Watersheds\wtd_75004300001162
# ----------
# 23. Starting watershed for: 75004300004217.0
# Watersheds\wtd_75004300004217
# ----------
# 24. Starting watershed for: 75004300002207.0
# Watersheds\wtd_75004300002207
# ----------
# 25. Starting watershed for: 75004300003409.0
# Watersheds\wtd_75004300003409
# ----------
# 26. Starting watershed for: 75004300002142.0
# Watersheds\wtd_75004300002142
# ----------
# 27. Starting watershed for: 75004300002314.0
# Watersheds\wtd_75004300002314
# ----------
# 28. Starting watershed for: 75004300003171.0
# Watersheds\wtd_75004300003171
# ----------
# 29. Starting watershed for: 75004300000101.0
# Watersheds\wtd_75004300000101
# ----------
# 30. Starting watershed for: 75004300005352.0
# Watersheds\wtd_75004300005352
# ----------
# 31. Starting watershed for: 75004300000856.0
# Watersheds\wtd_75004300000856
# ----------
# 32. Starting watershed for: 75004300004341.0
# Watersheds\wtd_75004300004341
# ----------
# 33. Starting watershed for: 75004300002289.0
# Watersheds\wtd_75004300002289
# ----------
# 34. Starting watershed for: 75004300007331.0
# Watersheds\wtd_75004300007331
# ----------
# 35. Starting watershed for: 75004300006376.0
# Watersheds\wtd_75004300006376
# ----------
# 36. Starting watershed for: 75004300002278.0
# Watersheds\wtd_75004300002278
# ----------
# 37. Starting watershed for: 75004300002352.0
# Watersheds\wtd_75004300002352
# ----------
# 38. Starting watershed for: 75004300001210.0
# Watersheds\wtd_75004300001210
# ----------
# 39. Starting watershed for: 75004300004452.0
# Watersheds\wtd_75004300004452
# ----------
# 40. Starting watershed for: 75004300000105.0
# Watersheds\wtd_75004300000105
# ----------
# 41. Starting watershed for: 75004300006071.0
# Watersheds\wtd_75004300006071
# ----------
# 42. Starting watershed for: 75004300004324.0
# Watersheds\wtd_75004300004324
# ----------
# 43. Starting watershed for: 75004300001288.0
# Watersheds\wtd_75004300001288
# ----------
# 44. Starting watershed for: 75004300006013.0
# Watersheds\wtd_75004300006013
# ----------
# 45. Starting watershed for: 75004400004829.0
# Watersheds\wtd_75004400004829
# ----------
# 46. Starting watershed for: 75004400000576.0
# Watersheds\wtd_75004400000576
# ----------
# 47. Starting watershed for: 75004400006041.0
# Watersheds\wtd_75004400006041
# ----------
# 48. Starting watershed for: 75004400010402.0
# Watersheds\wtd_75004400010402
# ----------
# 49. Starting watershed for: 75004400008856.0
# Watersheds\wtd_75004400008856
# ----------
# 50. Starting watershed for: 75004400010754.0
# Watersheds\wtd_75004400010754
# ----------
# 51. Starting watershed for: 75004400010810.0
# Watersheds\wtd_75004400010810
# ----------
# 52. Starting watershed for: 75004400002950.0
# Watersheds\wtd_75004400002950
# ----------
# 53. Starting watershed for: 75004400009144.0
# Watersheds\wtd_75004400009144
# ----------
# 54. Starting watershed for: 75004400006357.0
# Watersheds\wtd_75004400006357
# ----------
# 55. Starting watershed for: 75004400007385.0
# Watersheds\wtd_75004400007385
# ----------
# 56. Starting watershed for: 75004400007948.0
# Watersheds\wtd_75004400007948
# ----------
# 57. Starting watershed for: 75004400009261.0
# Watersheds\wtd_75004400009261
# ----------
# 58. Starting watershed for: 75004400001510.0
# Watersheds\wtd_75004400001510
# ----------
# 59. Starting watershed for: 75004400007387.0
# Watersheds\wtd_75004400007387
# ----------
# 60. Starting watershed for: 75004400010320.0
# Watersheds\wtd_75004400010320
# ----------
# 61. Starting watershed for: 75004400001568.0
# Watersheds\wtd_75004400001568
# ----------
# 62. Starting watershed for: 75004400008917.0
# Watersheds\wtd_75004400008917
# ----------
# 63. Starting watershed for: 75004400001952.0
# Watersheds\wtd_75004400001952
# ----------
# 64. Starting watershed for: 75004400009919.0
# Watersheds\wtd_75004400009919
# ----------
# 65. Starting watershed for: 75004400001498.0
# Watersheds\wtd_75004400001498
# ----------
# 66. Starting watershed for: 75004400011711.0
# Watersheds\wtd_75004400011711
# ----------
# 67. Starting watershed for: 75004400003452.0
# Watersheds\wtd_75004400003452
# ----------
# 68. Starting watershed for: 75004400007388.0
# Watersheds\wtd_75004400007388
# ----------
# 69. Starting watershed for: 75004400000627.0
# Watersheds\wtd_75004400000627
# ----------
# 70. Starting watershed for: 75004400003042.0
# Watersheds\wtd_75004400003042
# ----------
# 71. Starting watershed for: 75004400002041.0
# Watersheds\wtd_75004400002041
# ----------
# 72. Starting watershed for: 75004400011322.0
# Watersheds\wtd_75004400011322
# ----------
# 73. Starting watershed for: 75004400001872.0
# Watersheds\wtd_75004400001872
# ----------
# 74. Starting watershed for: 75004400009331.0
# Watersheds\wtd_75004400009331
# ----------
# 75. Starting watershed for: 75004400009308.0
# Watersheds\wtd_75004400009308
# ----------
# 76. Starting watershed for: 75004400006846.0
# Watersheds\wtd_75004400006846
# ----------
# 77. Starting watershed for: 75004400003154.0
# Watersheds\wtd_75004400003154
# ----------
# 78. Starting watershed for: 75004400002951.0
# Watersheds\wtd_75004400002951
# ----------
# 79. Starting watershed for: 75004400009260.0
# Watersheds\wtd_75004400009260
# ----------
# 80. Starting watershed for: 75000100000981.0
# Watersheds\wtd_75000100000981
# ----------
# 81. Starting watershed for: 75000100003094.0
# Watersheds\wtd_75000100003094
# ----------
# 82. Starting watershed for: 75000100003947.0
# Watersheds\wtd_75000100003947
# ----------
# 83. Starting watershed for: 75000100002463.0
# Watersheds\wtd_75000100002463
# ----------
# 84. Starting watershed for: 75000100001919.0
# Watersheds\wtd_75000100001919
# ----------
# 85. Starting watershed for: 75000100004336.0
# Watersheds\wtd_75000100004336
# ----------
# 86. Starting watershed for: 75000100000004.0
# Watersheds\wtd_75000100000004
# ----------
# 87. Starting watershed for: 75000100000652.0
# Watersheds\wtd_75000100000652
# ----------
# 88. Starting watershed for: 75000100004200.0
# Watersheds\wtd_75000100004200
# ----------
# 89. Starting watershed for: 75000100002523.0
# Watersheds\wtd_75000100002523
# ----------
# 90. Starting watershed for: 75000100000059.0
# Watersheds\wtd_75000100000059
# ----------
# 91. Starting watershed for: 75000400000173.0
# Watersheds\wtd_75000400000173
# ----------
# 92. Starting watershed for: 75000400009620.0
# Watersheds\wtd_75000400009620
# ----------
# 93. Starting watershed for: 75000400014405.0
# Watersheds\wtd_75000400014405
# ----------
# 94. Starting watershed for: 75000400014403.0
# Watersheds\wtd_75000400014403
# ----------
# 95. Starting watershed for: 75000700036166.0
# Watersheds\wtd_75000700036166
# ----------
# 96. Starting watershed for: 75000700030756.0
# Watersheds\wtd_75000700030756
# ----------
# 97. Starting watershed for: 75000700032122.0
# Watersheds\wtd_75000700032122
# ----------
# 98. Starting watershed for: 75000500009621.0
# Watersheds\wtd_75000500009621
# ----------
# 99. Starting watershed for: 75000500011984.0
# Watersheds\wtd_75000500011984
# ----------
# 100. Starting watershed for: 75000500009975.0
# Watersheds\wtd_75000500009975
# ----------
# 101. Starting watershed for: 75000500010609.0
# Watersheds\wtd_75000500010609
# ----------
# 102. Starting watershed for: 75000300025361.0
# Watersheds\wtd_75000300025361
# ----------
# 103. Starting watershed for: 75000600010189.0
# Watersheds\wtd_75000600010189
# ----------
# 104. Starting watershed for: 75000600030148.0
# Watersheds\wtd_75000600030148
# ----------
# 105. Starting watershed for: 75000200008033.0
# Watersheds\wtd_75000200008033
# ----------
# 106. Starting watershed for: 75000200002920.0
# Watersheds\wtd_75000200002920
# ----------
# 107. Starting watershed for: 75000200000411.0
# Watersheds\wtd_75000200000411
# ----------
# 108. Starting watershed for: 75000200008551.0
# Watersheds\wtd_75000200008551
# ----------
# 109. Starting watershed for: 75000200007305.0
# Watersheds\wtd_75000200007305
# ----------
# 110. Starting watershed for: 75000200015657.0
# Watersheds\wtd_75000200015657
# ----------
# 111. Starting watershed for: 75000200003107.0
# Watersheds\wtd_75000200003107
# ----------
# 112. Starting watershed for: 75000200008009.0
# Watersheds\wtd_75000200008009
# ----------
# 113. Starting watershed for: 75000200013536.0
# Watersheds\wtd_75000200013536
# ----------
# 114. Starting watershed for: 75000200015867.0
# Watersheds\wtd_75000200015867
# ----------
# 115. Starting watershed for: 75000200010712.0
# Watersheds\wtd_75000200010712
# ----------
# 116. Starting watershed for: 75000200003070.0
# Watersheds\wtd_75000200003070
# ----------
# 117. Starting watershed for: 75000200006065.0
# Watersheds\wtd_75000200006065
# ----------
# 118. Starting watershed for: 75000200010532.0
# Watersheds\wtd_75000200010532
# ----------
# 119. Starting watershed for: 75000200005573.0
# Watersheds\wtd_75000200005573
# ----------
# 120. Starting watershed for: 75000200005575.0
# Watersheds\wtd_75000200005575
# ----------
# 121. Starting watershed for: 75000200018331.0
# Watersheds\wtd_75000200018331
# ----------
# 122. Starting watershed for: 75000200005504.0
# Watersheds\wtd_75000200005504
# ----------
# 123. Starting watershed for: 75000200003013.0
# Watersheds\wtd_75000200003013
# ----------
# 124. Starting watershed for: 75000200015680.0
# Watersheds\wtd_75000200015680
# ----------
# 125. Starting watershed for: 75000200000416.0
# Watersheds\wtd_75000200000416
# ----------
# 126. Starting watershed for: 75000200005413.0
# Watersheds\wtd_75000200005413
# ----------
# 127. Starting watershed for: 75000200002930.0
# Watersheds\wtd_75000200002930
# ----------
# 128. Starting watershed for: 75000200010359.0
# Watersheds\wtd_75000200010359
# ----------
# 129. Starting watershed for: 75000200010144.0
# Watersheds\wtd_75000200010144
# ----------
# 130. Starting watershed for: 75000200018266.0
# Watersheds\wtd_75000200018266
# ----------
# 131. Starting watershed for: 75000200002753.0
# Watersheds\wtd_75000200002753
# ----------
# 132. Starting watershed for: 75000200015505.0
# Watersheds\wtd_75000200015505
# ----------
# 133. Starting watershed for: 75000200015584.0
# Watersheds\wtd_75000200015584
# ----------
# 134. Starting watershed for: 75000200002806.0
# Watersheds\wtd_75000200002806
# ----------
# 135. Starting watershed for: 75000200007853.0
# Watersheds\wtd_75000200007853
# ----------
# 136. Starting watershed for: 75000200018577.0
# Watersheds\wtd_75000200018577
# ----------
# 137. Starting watershed for: 75000200015695.0
# Watersheds\wtd_75000200015695
# ----------
# 138. Starting watershed for: 75000200013033.0
# Watersheds\wtd_75000200013033
# ----------
# 139. Starting watershed for: 75000200005075.0
# Watersheds\wtd_75000200005075
# ----------
# 140. Starting watershed for: 75000200007839.0
# Watersheds\wtd_75000200007839
# ----------
# 141. Starting watershed for: 75000200007958.0
# Watersheds\wtd_75000200007958
# ----------
# 142. Starting watershed for: 75000200013189.0
# Watersheds\wtd_75000200013189
# ----------
# 143. Starting watershed for: 75000200002934.0
# Watersheds\wtd_75000200002934
# ----------
# 144. Starting watershed for: 75000200018235.0
# Watersheds\wtd_75000200018235
# ----------
# 145. Starting watershed for: 75000200013258.0
# Watersheds\wtd_75000200013258
# ----------
# 146. Starting watershed for: 75000200018069.0
# Watersheds\wtd_75000200018069
# ----------
# 147. Starting watershed for: 75000200013187.0
# Watersheds\wtd_75000200013187
# ----------
# 148. Starting watershed for: 75000200007646.0
# Watersheds\wtd_75000200007646
# ----------
# 149. Starting watershed for: 75000200000010.0
# Watersheds\wtd_75000200000010
# ----------
# 150. Starting watershed for: 75000200013185.0
# Watersheds\wtd_75000200013185
# ----------
# 151. Starting watershed for: 75000200010344.0
# Watersheds\wtd_75000200010344
# ----------
# 152. Starting watershed for: 75000200010538.0
# Watersheds\wtd_75000200010538
# ----------
# 153. Starting watershed for: 75000200010547.0
# Watersheds\wtd_75000200010547
# ----------
# 154. Starting watershed for: 75000200005606.0
# Watersheds\wtd_75000200005606
# ----------
# 155. Starting watershed for: 75000200002554.0
# Watersheds\wtd_75000200002554
# ----------
# 156. Starting watershed for: 75000200017518.0
# Watersheds\wtd_75000200017518
# ----------
# 157. Starting watershed for: 75000200018332.0
# Watersheds\wtd_75000200018332
# ----------
# 158. Starting watershed for: 75000200015469.0
# Watersheds\wtd_75000200015469
# ----------
# 159. Starting watershed for: 75000200010540.0
# Watersheds\wtd_75000200010540
# ----------
# 160. Starting watershed for: 75000200018806.0
# Watersheds\wtd_75000200018806
# ----------
# 161. Starting watershed for: 75000200003094.0
# Watersheds\wtd_75000200003094
# ----------
# 162. Starting watershed for: 75000200014914.0
# Watersheds\wtd_75000200014914
# ----------
# 163. Starting watershed for: 75000200007639.0
# Watersheds\wtd_75000200007639
# ----------
# 164. Starting watershed for: 75000200013266.0
# Watersheds\wtd_75000200013266
# ----------
# 165. Starting watershed for: 75000200010391.0
# Watersheds\wtd_75000200010391
# ----------
# 166. Starting watershed for: 75000200015860.0
# Watersheds\wtd_75000200015860
# ----------
# 167. Starting watershed for: 75000200005503.0
# Watersheds\wtd_75000200005503
# ----------
# 168. Starting watershed for: 75000200000213.0
# Watersheds\wtd_75000200000213
# ----------
# 169. Starting watershed for: 75000200015782.0
# Watersheds\wtd_75000200015782
# ----------
# 170. Starting watershed for: 75000200011141.0
# Watersheds\wtd_75000200011141
# ----------
# 171. Starting watershed for: 75000200008051.0
# Watersheds\wtd_75000200008051
# ----------
# 172. Starting watershed for: 75000200013319.0
# Watersheds\wtd_75000200013319
# ----------
# 173. Starting watershed for: 75000200007852.0
# Watersheds\wtd_75000200007852
# ----------
# 174. Starting watershed for: 75000200000465.0
# Watersheds\wtd_75000200000465
# ----------
# 175. Starting watershed for: 75000200013237.0
# Watersheds\wtd_75000200013237
# ----------
# 176. Starting watershed for: 75000200007870.0
# Watersheds\wtd_75000200007870
# ----------
# 177. Starting watershed for: 75000200000011.0
# Watersheds\wtd_75000200000011
# ----------
# 178. Starting watershed for: 75000200013953.0
# Watersheds\wtd_75000200013953
# ----------
# 179. Starting watershed for: 75000200004615.0
# Watersheds\wtd_75000200004615
# ----------
# 180. Starting watershed for: 75000200010148.0
# Watersheds\wtd_75000200010148
# ----------
# 181. Starting watershed for: 75000200013892.0
# Watersheds\wtd_75000200013892
# ----------
# 182. Starting watershed for: 75000200013179.0
# Watersheds\wtd_75000200013179
# ----------
# 183. Starting watershed for: 75000200002984.0
# Watersheds\wtd_75000200002984
# ----------
# 184. Starting watershed for: 75000200007660.0
# Watersheds\wtd_75000200007660
# ----------
# 185. Starting watershed for: 75000200005448.0
# Watersheds\wtd_75000200005448
# ----------
# 186. Starting watershed for: 75000200018581.0
# Watersheds\wtd_75000200018581
# ----------
# 187. Starting watershed for: 75000200011336.0
# Watersheds\wtd_75000200011336
# ----------
# 188. Starting watershed for: 75000200012999.0
# Watersheds\wtd_75000200012999
# ----------
# 189. Starting watershed for: 75000200003732.0
# Watersheds\wtd_75000200003732
# ----------
# 190. Starting watershed for: 75000200008734.0
# Watersheds\wtd_75000200008734
# ----------
# 191. Starting watershed for: 75000200000021.0
# Watersheds\wtd_75000200000021
# ----------
# 192. Starting watershed for: 75000200005532.0
# Watersheds\wtd_75000200005532
# ----------
# 193. Starting watershed for: 75000200018882.0
# Watersheds\wtd_75000200018882
# ----------
# 194. Starting watershed for: 75000200005404.0
# Watersheds\wtd_75000200005404
# ----------
# 195. Starting watershed for: 75000200015587.0
# Watersheds\wtd_75000200015587
# ----------
# 196. Starting watershed for: 75000200015319.0
# Watersheds\wtd_75000200015319
# ----------
# 197. Starting watershed for: 75000200015900.0
# Watersheds\wtd_75000200015900
# ----------
# 198. Starting watershed for: 75000200005077.0
# Watersheds\wtd_75000200005077
# ----------
# 199. Starting watershed for: 75000200008950.0
# Watersheds\wtd_75000200008950
# ----------
# 200. Starting watershed for: 75000200015320.0
# Watersheds\wtd_75000200015320
# ----------
# 201. Starting watershed for: 75000200012046.0
# Watersheds\wtd_75000200012046
# ----------
# 202. Starting watershed for: 75000200002162.0
# Watersheds\wtd_75000200002162
# ----------
# 203. Starting watershed for: 75000200011392.0
# Watersheds\wtd_75000200011392
# ----------
# 204. Starting watershed for: 75000200000278.0
# Watersheds\wtd_75000200000278
# ----------
# 205. Starting watershed for: 75000200018259.0
# Watersheds\wtd_75000200018259
# ----------
# 206. Starting watershed for: 75000200005444.0
# Watersheds\wtd_75000200005444
# ----------
# 207. Starting watershed for: 75000200018203.0
# Watersheds\wtd_75000200018203
# ----------
# 208. Starting watershed for: 75000200008110.0
# Watersheds\wtd_75000200008110
# ----------
# 209. Starting watershed for: 75000200018317.0
# Watersheds\wtd_75000200018317
# ----------
# 210. Starting watershed for: 75000200000949.0
# Watersheds\wtd_75000200000949
# ----------
# 211. Starting watershed for: 75000200013249.0
# Watersheds\wtd_75000200013249
# ----------
# 212. Starting watershed for: 75000200013010.0
# Watersheds\wtd_75000200013010
# ----------
# 213. Starting watershed for: 75000200000418.0
# Watersheds\wtd_75000200000418
# ----------
# 214. Starting watershed for: 75000200002552.0
# Watersheds\wtd_75000200002552
# ----------
# 215. Starting watershed for: 75000200008508.0
# Watersheds\wtd_75000200008508
# ----------
# 216. Starting watershed for: 75000200007670.0
# Watersheds\wtd_75000200007670
# ----------
# 217. Starting watershed for: 75000200008676.0
# Watersheds\wtd_75000200008676
# ----------
# 218. Starting watershed for: 75000200018667.0
# Watersheds\wtd_75000200018667
# ----------
# 219. Starting watershed for: 75000200011572.0
# Watersheds\wtd_75000200011572
# ----------
# 220. Starting watershed for: 75000200011623.0
# Watersheds\wtd_75000200011623
# ----------
# 221. Starting watershed for: 75000200019765.0
# Watersheds\wtd_75000200019765
# ----------
# 222. Starting watershed for: 75000200016095.0
# Watersheds\wtd_75000200016095
# ----------
# 223. Starting watershed for: 75000200014508.0
# Watersheds\wtd_75000200014508
# ----------
# 224. Starting watershed for: 75000200015883.0
# Watersheds\wtd_75000200015883
# ----------
# 225. Starting watershed for: 75000200014057.0
# Watersheds\wtd_75000200014057
# ----------
# 226. Starting watershed for: 75000200019263.0
# Watersheds\wtd_75000200019263
# ----------
# 227. Starting watershed for: 75000200003896.0
# Watersheds\wtd_75000200003896
# ----------
# 228. Starting watershed for: 75000200005619.0
# Watersheds\wtd_75000200005619
# ----------
# 229. Starting watershed for: 75000200003312.0
# Watersheds\wtd_75000200003312
# ----------
# 230. Starting watershed for: 75000200014207.0
# Watersheds\wtd_75000200014207
# ----------
# 231. Starting watershed for: 75000200007927.0
# Watersheds\wtd_75000200007927
# ----------
# 232. Starting watershed for: 75000200011034.0
# Watersheds\wtd_75000200011034
# ----------
# 233. Starting watershed for: 75000200015882.0
# Watersheds\wtd_75000200015882
# ----------
# 234. Starting watershed for: 75000200016094.0
# Watersheds\wtd_75000200016094
# ----------
# 235. Starting watershed for: 75000200008452.0
# Watersheds\wtd_75000200008452
# ----------
# 236. Starting watershed for: 75005300022831.0
# Watersheds\wtd_75005300022831
# ----------
# 237. Starting watershed for: 75005300011378.0
# Watersheds\wtd_75005300011378
# ----------
# 238. Starting watershed for: 75005400001203.0
# Watersheds\wtd_75005400001203
# ----------
# 239. Starting watershed for: 75005400029139.0
# Watersheds\wtd_75005400029139
# ----------
# 240. Starting watershed for: 75005400013272.0
# Watersheds\wtd_75005400013272
# ----------
# Process completed at 2021-12-03 02:03 (Elapsed time: 0:34:57)
# ----------

# %%
# COPPER RIVER
# steps 1 and 2
# intersect points with catchments and create list of NHDPlusIDs
import arcpy, os
arcpy.env.workspace = cr_gdb
arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr


cats = os.path.join(cr_gdb,'cats_merge')
idList = []
outcats = "cats_intersect"

arcpy.MakeFeatureLayer_management(cats, "tempLayer")
arcpy.management.SelectLayerByLocation("tempLayer", "INTERSECT", points)
arcpy.CopyFeatures_management("tempLayer", outcats)

fields = arcpy.ListFields("tempLayer")
for field in fields:
    print("{0}".format(field.name))
with arcpy.da.SearchCursor("tempLayer", ["NHDPlusID"]) as cursor:
    for row in cursor:
        idList.append(row[0])

print(len(idList))
# Out:
# OBJECTID
# Shape
# NHDPlusID
# SourceFC
# GridCode
# AreaSqKm
# VPUID
# Shape_Length
# Shape_Area
# 28

# %%
# COPPER RIVER
# steps 4-7

import arcpy, time, datetime, os
import pandas as pd
from functools import reduce

# steps 4-9 for loop to create watersheds
arcpy.env.workspace = cr_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()

vaa = os.path.join(cr_gdb, "vaa_merge")
cats = os.path.join(cr_gdb, "cats_merge")
streams = os.path.join(cr_gdb, "NHDFlowline_merge")

# Get list of index names for cats merge and add index if not already created
index_names = [i.name for i in arcpy.ListIndexes(cats)]
print(index_names)
if 'NHDPlusID_index' not in index_names:
    print (f'Creating index for {cats}')
    arcpy.AddIndex_management(cats,'NHDPlusID','NHDPlusID_index')
else:
    print(f'{cats} Indexed')

#watersheds feature dataset for storing fcs
fdat = os.path.join(cr_gdb, 'Watersheds')
if not arcpy.Exists(fdat):
    arcpy.management.CreateFeatureDataset(cr_gdb, "Watersheds", sr)
else:
    print(f'{fdat} exists for copper- river')

vaa_df1 = pd.DataFrame(arcpy.da.TableToNumPyArray(vaa, ("NHDPlusID", "FromNode", "ToNode", "StartFlag")))
stream_df = pd.DataFrame(arcpy.da.TableToNumPyArray(streams, ("NHDPlusID", "FType")))
dfs = [vaa_df1, stream_df]
vaa_df = reduce(lambda left,right: pd.merge(left,right,on='NHDPlusID',how="outer"), dfs)
# remove pipelines
vaa_df = vaa_df[(vaa_df['FType'] != 428 )]
vaa_df

c=1
for id in idList:
    print(f"{c}. Starting watershed for: " + str(id))
    rec = [id]
    up_ids = []
    up_ids.append(rec)
    rec_len = len(rec)
    hws_sum = 0

    while rec_len != hws_sum:
        fromnode = vaa_df.loc[vaa_df["NHDPlusID"].isin(rec), "FromNode"]
        rec = vaa_df.loc[vaa_df["ToNode"].isin(fromnode), "NHDPlusID"]
        rec_len = len(rec)
        rec_hws = vaa_df.loc[vaa_df["ToNode"].isin(fromnode), "StartFlag"]
        hws_sum = sum(rec_hws)
        up_ids.append(rec)
    #up_ids is a list with more than numbers, use extend to only keep numeric nhdplusids
    newup_ids = []
    for x in up_ids:
        newup_ids.extend(x)

    tempLayer = "catsLyr"
    expression = '"NHDPlusID" IN ({0})'.format(', '.join(map(str, newup_ids)) or 'NULL')
    arcpy.MakeFeatureLayer_management(cats, tempLayer, where_clause=expression)
    outdis = "memory/wtd_" + str(round(id))
    outwtd = "Watersheds\\wtd_" + str(round(id))
    print(outwtd)
    print('----------')
    dis = arcpy.Dissolve_management(tempLayer, outdis)
    watershed = arcpy.EliminatePolygonPart_management(dis, outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
    c=c+1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
print('----------')

# %% [markdown]
# ## If operation hangs then suspend and run following chunk to check what watersheds were missed

# %%
arcpy.env.workspace = cr_gdb
wtd_lst = []
for ds in arcpy.ListDatasets():
        arcpy.env.workspace = ds
        for dfc in arcpy.ListFeatureClasses():
            print (dfc)
            wtd_lst.append(float(dfc[4:]+'.0'))
cr_missed = (set(idList).difference(wtd_lst))
print (f'{len(cr_missed)} Watersheds not created')
print(f'Missing values in first list: {cr_missed}')

list1_as_set = set(idList)
intersection = list1_as_set.intersection(wtd_lst)
intersection_as_list = list(intersection)
print(f'List intersection {intersection_as_list}')
print (f'Length of list inter {len(intersection_as_list)}')
# Out:
# wtd_75019800000406
# wtd_75019800010313
# wtd_75019800014348
# wtd_75019800001957
# wtd_75019800019692
# wtd_75019600118138
# wtd_75019700004190
# wtd_75019700004084
# wtd_75019700017692
# wtd_75019700001794
# wtd_75019700003889
# wtd_75003900062338
# wtd_75003900033524
# wtd_75003900054316
# wtd_75003900055039
# wtd_75003900023942
# wtd_75003900058380
# wtd_75003900028507
# wtd_75003900027489
# wtd_75003900044936
# wtd_75003900023855
# wtd_75003900044738
# wtd_75003900055694
# wtd_75003900023674
# wtd_75003900062264
# wtd_75003900055316
# wtd_75003900039073
# wtd_75003900027771
# 0 Watersheds not created
# Missing values in first list: set()
# List intersection [75019700001794.0, 75003900062338.0, 75003900023942.0, 75003900044936.0, 75019800014348.0, 75003900058380.0, 75003900055694.0, 75003900055316.0, 75019800000406.0, 75019700017692.0, 75003900039073.0, 75019800001957.0, 75003900054316.0, 75003900023855.0, 75019700003889.0, 75003900062264.0, 75003900044738.0, 75019800010313.0, 75003900028507.0, 75019700004190.0, 75003900027489.0, 75019800019692.0, 75019700004084.0, 75003900033524.0, 75019600118138.0, 75003900027771.0, 75003900023674.0, 75003900055039.0]
# Length of list inter 28

# %%
# BRISTOL BAY WATERSHEDS

import arcpy, os
import pandas as pd

arcpy.env.workspace = bbay_gdb
arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

cats = os.path.join(bbay_gdb, 'cats_merge')
idList = []
outcats = "cats_intersect"

arcpy.MakeFeatureLayer_management(cats, "tempLayer")
arcpy.management.SelectLayerByLocation("tempLayer", "INTERSECT", points)
arcpy.CopyFeatures_management("tempLayer", outcats)

fields = arcpy.ListFields("tempLayer")
for field in fields:
    print("{0}".format(field.name))
with arcpy.da.SearchCursor("tempLayer", ["catID"]) as cursor:
    for row in cursor:
        idList.append(row[0])

print(len(idList))
# Out:
# OBJECTID
# Shape
# gridcode
# catID
# Shape_Length
# Shape_Area
# 114

# %%
# BRISTOL BAY
# steps 4-7

import arcpy
import pandas as pd
import time

# steps 4-9 for loop to create watersheds
arcpy.env.workspace = bbay_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
streams = "streams_merge"
cats = "cats_merge"

# Get list of index names for cats merge and add index if not already created
index_names = [i.name for i in arcpy.ListIndexes(cats)]
print(index_names)
if 'catid_index' not in index_names:
    print (f'Creating index for {cats}')
    arcpy.AddIndex_management(cats, "catID", "catid_index")
else:
    print(f'{cats} Indexed')

#watersheds feature dataset for storing fcs
fdat = os.path.join(bbay_gdb, 'Watersheds')
if not arcpy.Exists(fdat):
    arcpy.management.CreateFeatureDataset(bbay_gdb, "Watersheds", sr)
else:
    print(f'{fdat} exists for Bristol Bay')

str_df = pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(streams, ("catID", "upCatID1", "upCatID2")))
hws_codes = [999999, 1999999, 2999999, 3999999, 4999999]

#idList if doing ALL watersheds.
c=1
for id in idList:
    print(f"{c}. Starting watershed for: " + str(id))
    rec = [id]
    up_ids = []
    sum_rec = sum(rec)
    timeout = time.time() + 60*15 # 15 minutes from this point

    while(sum_rec > 0):
        if time.time() > timeout:
            break
        up_ids.append(rec)
        rec = str_df.loc[str_df["catID"].isin(rec), ("upCatID1", "upCatID2")]
        rec = rec.replace(hws_codes, 0)
        rec = pd.concat([rec['upCatID1'], rec['upCatID2']])

        sum_rec = sum(rec)
    newup_ids = []
    for x in up_ids:
        newup_ids.extend(x)
    tempLayer = "catsLyr"
    expression = '"catID" IN ({0})'.format(', '.join(map(str, newup_ids)) or 'NULL')
    arcpy.MakeFeatureLayer_management(cats, tempLayer)
    arcpy.management.SelectLayerByAttribute(tempLayer, "NEW_SELECTION", expression, None)
    print("Starting dissolve")
    outdis = "memory/wtd_" + str(round(id))
    outwtd = "Watersheds\\wtd_" + str(round(id))
    dis = arcpy.Dissolve_management(tempLayer, outdis)
    watershed = arcpy.EliminatePolygonPart_management(dis, outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
    print("Watershed created at:" + outwtd)
    c=c+1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
# Out:
# ['FDO_OBJECTID', 'FDO_Shape']
# Creating index for cats_merge
# 1. Starting watershed for: 1023044
# Starting dissolve
# Watershed created at:Watersheds\wtd_1023044
# 2. Starting watershed for: 2041471
# Starting dissolve
# Watershed created at:Watersheds\wtd_2041471
# 3. Starting watershed for: 2065755
# Starting dissolve
# Watershed created at:Watersheds\wtd_2065755
# 4. Starting watershed for: 2065914
# Starting dissolve
# Watershed created at:Watersheds\wtd_2065914
# 5. Starting watershed for: 2066924
# Starting dissolve
# Watershed created at:Watersheds\wtd_2066924
# 6. Starting watershed for: 2066955
# Starting dissolve
# Watershed created at:Watersheds\wtd_2066955
# 7. Starting watershed for: 2067494
# Starting dissolve
# Watershed created at:Watersheds\wtd_2067494
# 8. Starting watershed for: 2068072
# Starting dissolve
# Watershed created at:Watersheds\wtd_2068072
# 9. Starting watershed for: 2068584
# Starting dissolve
# Watershed created at:Watersheds\wtd_2068584
# 10. Starting watershed for: 2070402
# Starting dissolve
# Watershed created at:Watersheds\wtd_2070402
# 11. Starting watershed for: 2071934
# Starting dissolve
# Watershed created at:Watersheds\wtd_2071934
# 12. Starting watershed for: 2072993
# Starting dissolve
# Watershed created at:Watersheds\wtd_2072993
# 13. Starting watershed for: 2073464
# Starting dissolve
# Watershed created at:Watersheds\wtd_2073464
# 14. Starting watershed for: 2074424
# Starting dissolve
# Watershed created at:Watersheds\wtd_2074424
# 15. Starting watershed for: 2078232
# Starting dissolve
# Watershed created at:Watersheds\wtd_2078232
# 16. Starting watershed for: 2078282
# Starting dissolve
# Watershed created at:Watersheds\wtd_2078282
# 17. Starting watershed for: 2082373
# Starting dissolve
# Watershed created at:Watersheds\wtd_2082373
# 18. Starting watershed for: 2082393
# Starting dissolve
# Watershed created at:Watersheds\wtd_2082393
# 19. Starting watershed for: 2084713
# Starting dissolve
# Watershed created at:Watersheds\wtd_2084713
# 20. Starting watershed for: 2085642
# Starting dissolve
# Watershed created at:Watersheds\wtd_2085642
# 21. Starting watershed for: 2085962
# Starting dissolve
# Watershed created at:Watersheds\wtd_2085962
# 22. Starting watershed for: 2087913
# Starting dissolve
# Watershed created at:Watersheds\wtd_2087913
# 23. Starting watershed for: 2088163
# Starting dissolve
# Watershed created at:Watersheds\wtd_2088163
# 24. Starting watershed for: 2088253
# Starting dissolve
# Watershed created at:Watersheds\wtd_2088253
# 25. Starting watershed for: 2088326
# Starting dissolve
# Watershed created at:Watersheds\wtd_2088326
# 26. Starting watershed for: 2088586
# Starting dissolve
# Watershed created at:Watersheds\wtd_2088586
# 27. Starting watershed for: 3023044
# Starting dissolve
# Watershed created at:Watersheds\wtd_3023044
# 28. Starting watershed for: 3024343
# Starting dissolve
# Watershed created at:Watersheds\wtd_3024343
# 29. Starting watershed for: 3030955
# Starting dissolve
# Watershed created at:Watersheds\wtd_3030955
# 30. Starting watershed for: 3033666
# Starting dissolve
# Watershed created at:Watersheds\wtd_3033666
# 31. Starting watershed for: 3033956
# Starting dissolve
# Watershed created at:Watersheds\wtd_3033956
# 32. Starting watershed for: 3034126
# Starting dissolve
# Watershed created at:Watersheds\wtd_3034126
# 33. Starting watershed for: 4046617
# Starting dissolve
# Watershed created at:Watersheds\wtd_4046617
# 34. Starting watershed for: 4048046
# Starting dissolve
# Watershed created at:Watersheds\wtd_4048046
# 35. Starting watershed for: 4051055
# Starting dissolve
# Watershed created at:Watersheds\wtd_4051055
# 36. Starting watershed for: 4051056
# Starting dissolve
# Watershed created at:Watersheds\wtd_4051056
# 37. Starting watershed for: 4051616
# Starting dissolve
# Watershed created at:Watersheds\wtd_4051616
# 38. Starting watershed for: 4052076
# Starting dissolve
# Watershed created at:Watersheds\wtd_4052076
# 39. Starting watershed for: 4054120
# Starting dissolve
# Watershed created at:Watersheds\wtd_4054120
# 40. Starting watershed for: 4054200
# Starting dissolve
# Watershed created at:Watersheds\wtd_4054200
# 41. Starting watershed for: 4055337
# Starting dissolve
# Watershed created at:Watersheds\wtd_4055337
# 42. Starting watershed for: 4059016
# Starting dissolve
# Watershed created at:Watersheds\wtd_4059016
# 43. Starting watershed for: 4059736
# Starting dissolve
# Watershed created at:Watersheds\wtd_4059736
# 44. Starting watershed for: 4060036
# Starting dissolve
# Watershed created at:Watersheds\wtd_4060036
# 45. Starting watershed for: 4061136
# Starting dissolve
# Watershed created at:Watersheds\wtd_4061136
# 46. Starting watershed for: 4063606
# Starting dissolve
# Watershed created at:Watersheds\wtd_4063606
# 47. Starting watershed for: 4063775
# Starting dissolve
# Watershed created at:Watersheds\wtd_4063775
# 48. Starting watershed for: 4064055
# Starting dissolve
# Watershed created at:Watersheds\wtd_4064055
# 49. Starting watershed for: 4064845
# Starting dissolve
# Watershed created at:Watersheds\wtd_4064845
# 50. Starting watershed for: 4068584
# Starting dissolve
# Watershed created at:Watersheds\wtd_4068584
# 51. Starting watershed for: 4069455
# Starting dissolve
# Watershed created at:Watersheds\wtd_4069455
# 52. Starting watershed for: 4069495
# Starting dissolve
# Watershed created at:Watersheds\wtd_4069495
# 53. Starting watershed for: 4069586
# Starting dissolve
# Watershed created at:Watersheds\wtd_4069586
# 54. Starting watershed for: 4071036
# Starting dissolve
# Watershed created at:Watersheds\wtd_4071036
# 55. Starting watershed for: 4071256
# Starting dissolve
# Watershed created at:Watersheds\wtd_4071256
# 56. Starting watershed for: 4071625
# Starting dissolve
# Watershed created at:Watersheds\wtd_4071625
# 57. Starting watershed for: 4073375
# Starting dissolve
# Watershed created at:Watersheds\wtd_4073375
# 58. Starting watershed for: 4074184
# Starting dissolve
# Watershed created at:Watersheds\wtd_4074184
# 59. Starting watershed for: 4074505
# Starting dissolve
# Watershed created at:Watersheds\wtd_4074505
# 60. Starting watershed for: 4074726
# Starting dissolve
# Watershed created at:Watersheds\wtd_4074726
# 61. Starting watershed for: 4075225
# Starting dissolve
# Watershed created at:Watersheds\wtd_4075225
# 62. Starting watershed for: 4075474
# Starting dissolve
# Watershed created at:Watersheds\wtd_4075474
# 63. Starting watershed for: 4075715
# Starting dissolve
# Watershed created at:Watersheds\wtd_4075715
# 64. Starting watershed for: 4076505
# Starting dissolve
# Watershed created at:Watersheds\wtd_4076505
# 65. Starting watershed for: 4076575
# Starting dissolve
# Watershed created at:Watersheds\wtd_4076575
# 66. Starting watershed for: 4076675
# Starting dissolve
# Watershed created at:Watersheds\wtd_4076675
# 67. Starting watershed for: 4078235
# Starting dissolve
# Watershed created at:Watersheds\wtd_4078235
# 68. Starting watershed for: 4079234
# Starting dissolve
# Watershed created at:Watersheds\wtd_4079234
# 69. Starting watershed for: 4080045
# Starting dissolve
# Watershed created at:Watersheds\wtd_4080045
# 70. Starting watershed for: 4080875
# Starting dissolve
# Watershed created at:Watersheds\wtd_4080875
# 71. Starting watershed for: 4082225
# Starting dissolve
# Watershed created at:Watersheds\wtd_4082225
# 72. Starting watershed for: 4084145
# Starting dissolve
# Watershed created at:Watersheds\wtd_4084145
# 73. Starting watershed for: 4084351
# Starting dissolve
# Watershed created at:Watersheds\wtd_4084351
# 74. Starting watershed for: 4084915
# Starting dissolve
# Watershed created at:Watersheds\wtd_4084915
# 75. Starting watershed for: 4086815
# Starting dissolve
# Watershed created at:Watersheds\wtd_4086815
# 76. Starting watershed for: 4087015
# Starting dissolve
# Watershed created at:Watersheds\wtd_4087015
# 77. Starting watershed for: 4087224
# Starting dissolve
# Watershed created at:Watersheds\wtd_4087224
# 78. Starting watershed for: 4088675
# Starting dissolve
# Watershed created at:Watersheds\wtd_4088675
# 79. Starting watershed for: 4088904
# Starting dissolve
# Watershed created at:Watersheds\wtd_4088904
# 80. Starting watershed for: 4089074
# Starting dissolve
# Watershed created at:Watersheds\wtd_4089074
# 81. Starting watershed for: 4089384
# Starting dissolve
# Watershed created at:Watersheds\wtd_4089384
# 82. Starting watershed for: 4089394
# Starting dissolve
# Watershed created at:Watersheds\wtd_4089394
# 83. Starting watershed for: 4089574
# Starting dissolve
# Watershed created at:Watersheds\wtd_4089574
# 84. Starting watershed for: 4091164
# Starting dissolve
# Watershed created at:Watersheds\wtd_4091164
# 85. Starting watershed for: 4091424
# Starting dissolve
# Watershed created at:Watersheds\wtd_4091424
# 86. Starting watershed for: 4092244
# Starting dissolve
# Watershed created at:Watersheds\wtd_4092244
# 87. Starting watershed for: 4093084
# Starting dissolve
# Watershed created at:Watersheds\wtd_4093084
# 88. Starting watershed for: 4095301
# Starting dissolve
# Watershed created at:Watersheds\wtd_4095301
# 89. Starting watershed for: 4095374
# Starting dissolve
# Watershed created at:Watersheds\wtd_4095374
# 90. Starting watershed for: 4096064
# Starting dissolve
# Watershed created at:Watersheds\wtd_4096064
# 91. Starting watershed for: 4096454
# Starting dissolve
# Watershed created at:Watersheds\wtd_4096454
# 92. Starting watershed for: 4098114
# Starting dissolve
# Watershed created at:Watersheds\wtd_4098114
# 93. Starting watershed for: 4098704
# Starting dissolve
# Watershed created at:Watersheds\wtd_4098704
# 94. Starting watershed for: 4099594
# Starting dissolve
# Watershed created at:Watersheds\wtd_4099594
# 95. Starting watershed for: 4099694
# Starting dissolve
# Watershed created at:Watersheds\wtd_4099694
# 96. Starting watershed for: 4101123
# Starting dissolve
# Watershed created at:Watersheds\wtd_4101123
# 97. Starting watershed for: 4101274
# Starting dissolve
# Watershed created at:Watersheds\wtd_4101274
# 98. Starting watershed for: 4102124
# Starting dissolve
# Watershed created at:Watersheds\wtd_4102124
# 99. Starting watershed for: 4104574
# Starting dissolve
# Watershed created at:Watersheds\wtd_4104574
# 100. Starting watershed for: 4105204
# Starting dissolve
# Watershed created at:Watersheds\wtd_4105204
# 101. Starting watershed for: 4105594
# Starting dissolve
# Watershed created at:Watersheds\wtd_4105594
# 102. Starting watershed for: 4105844
# Starting dissolve
# Watershed created at:Watersheds\wtd_4105844
# 103. Starting watershed for: 4106904
# Starting dissolve
# Watershed created at:Watersheds\wtd_4106904
# 104. Starting watershed for: 4107464
# Starting dissolve
# Watershed created at:Watersheds\wtd_4107464
# 105. Starting watershed for: 4115672
# Starting dissolve
# Watershed created at:Watersheds\wtd_4115672
# 106. Starting watershed for: 5008707
# Starting dissolve
# Watershed created at:Watersheds\wtd_5008707
# 107. Starting watershed for: 5020796
# Starting dissolve
# Watershed created at:Watersheds\wtd_5020796
# 108. Starting watershed for: 5021476
# Starting dissolve
# Watershed created at:Watersheds\wtd_5021476
# 109. Starting watershed for: 5030363
# Starting dissolve
# Watershed created at:Watersheds\wtd_5030363
# 110. Starting watershed for: 5030704
# Starting dissolve
# Watershed created at:Watersheds\wtd_5030704
# 111. Starting watershed for: 5032474
# Starting dissolve
# Watershed created at:Watersheds\wtd_5032474
# 112. Starting watershed for: 5033094
# Starting dissolve
# Watershed created at:Watersheds\wtd_5033094
# 113. Starting watershed for: 5034893
# Starting dissolve
# Watershed created at:Watersheds\wtd_5034893
# 114. Starting watershed for: 5038375
# Starting dissolve
# Watershed created at:Watersheds\wtd_5038375
# Process completed at 2021-12-03 02:13 (Elapsed time: 0:05:16)

# %%
# code when trouble-shooting bb above.
import arcpy

# Got through 95 watersheds and all other programs froze, restarted and finding which watersheds remain.
arcpy.env.workspace = os.path.join(bbay_gdb,'Watersheds')
wtds = arcpy.ListFeatureClasses()
#just get numeric part
wtds = [x[4:20] for x in wtds]
#convert to numeric
wtds = [int(i) for i in wtds]
print(wtds)
print(len(wtds))
print(len(idList))
#
# idFilter = [x for x in idList if x not in wtds]
# print(idFilter)
# print("Original list of sites in BB: " + str(len(idList)))
# print("Watersheds completed: " + str(len(wtds)))
# print("Watersheds remaining: " + str(len(idFilter)))
# Out:
# [1023044, 2041471, 2065755, 2065914, 2066924, 2066955, 2067494, 2068072, 2068584, 2070402, 2071934, 2072993, 2073464, 2074424, 2078232, 2078282, 2082373, 2082393, 2084713, 2085642, 2085962, 2087913, 2088163, 2088253, 2088326, 2088586, 3023044, 3024343, 3030955, 3033666, 3033956, 3034126, 4046617, 4048046, 4051055, 4051056, 4051616, 4052076, 4054120, 4054200, 4055337, 4059016, 4059736, 4060036, 4061136, 4063606, 4063775, 4064055, 4064845, 4068584, 4069455, 4069495, 4069586, 4071036, 4071256, 4071625, 4073375, 4074184, 4074505, 4074726, 4075225, 4075474, 4075715, 4076505, 4076575, 4076675, 4078235, 4079234, 4080045, 4080875, 4082225, 4084145, 4084351, 4084915, 4086815, 4087015, 4087224, 4088675, 4088904, 4089074, 4089384, 4089394, 4089574, 4091164, 4091424, 4092244, 4093084, 4095301, 4095374, 4096064, 4096454, 4098114, 4098704, 4099594, 4099694, 4101123, 4101274, 4102124, 4104574, 4105204, 4105594, 4105844, 4106904, 4107464, 4115672, 5008707, 5020796, 5021476, 5030363, 5030704, 5032474, 5033094, 5034893, 5038375]
# 114
# 114

# %%
# PRINCE WILLIAM SOUND WATERSHEDS

import arcpy,os
arcpy.env.overwriteOutput = True
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr
arcpy.env.workspace = pws_gdb
arcpy.env.overwriteOutput = True

idList = []
cats = os.path.join(pws_gdb,'cats_merge')
outcats = os.path.join(pws_gdb, "cats_intersect")
arcpy.MakeFeatureLayer_management(cats, "tempLayer")
arcpy.management.SelectLayerByLocation("templayer", "INTERSECT", points)
arcpy.CopyFeatures_management("templayer", outcats)

fields = arcpy.ListFields("tempLayer")
for field in fields:
    print("{0}".format(field.name))
with arcpy.da.SearchCursor("tempLayer", ["gridcode"]) as cursor:
    for row in cursor:
        idList.append(row[0])

print(len(idList))
# Out:
# OBJECTID
# Shape
# gridcode
# Shape_Length
# Shape_Area
# catID
# 20

# %%
# Prince_William_Sound
# steps 4-7

import arcpy,os
import pandas as pd
arcpy.env.workspace = pws_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
streams = "streams_merge"
cats = "cats_merge"

# Get list of index names for cats merge and add index if not already created
index_names = [i.name for i in arcpy.ListIndexes(cats)]
print(index_names)
if 'catid_index' not in index_names:
    print (f'Creating index for {cats}')
    arcpy.AddIndex_management(cats, "catID", "catid_index")
else:
    print(f'{cats} Indexed')

#watersheds feature dataset for storing fcs
fdat = os.path.join(pws_gdb, 'Watersheds')
if not arcpy.Exists(fdat):
    arcpy.management.CreateFeatureDataset(pws_gdb, "Watersheds", sr)
else:
    print(f'{fdat} exists for PWS')

fields = arcpy.ListFields(streams)
for field in fields:
    print("{0}".format(field.name))

str_df = pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(streams, ("LINKNO", "USLINKNO1", "USLINKNO2")))
hws_codes = [-1]

# idList = [46055]

#idList if doing ALL watersheds.
c=1
for id in idList:
    print(f"{c}. Starting watershed for: " + str(id))
    rec = [id]
    up_ids = []
    sum_rec = sum(rec)

    while(sum_rec > 0):
        up_ids.append(rec)
        rec = str_df.loc[str_df["LINKNO"].isin(rec), ("USLINKNO1", "USLINKNO2")]
        rec = pd.concat([rec['USLINKNO1'], rec['USLINKNO2']])
        sum_rec = sum(rec)
        print(sum_rec)

    # up_ids is a list with more than numbers, use extend to only keep numeric nhdplusids
    newup_ids = []
    for x in up_ids:
        newup_ids.extend(x)

    tempLayer = "catsLyr"
    expression = '"gridcode" IN ({0})'.format(', '.join(map(str, newup_ids)) or 'NULL')
    arcpy.MakeFeatureLayer_management(cats, tempLayer)
    arcpy.management.SelectLayerByAttribute(tempLayer, "NEW_SELECTION", expression, None)
    print("Starting dissolve")
    outdis = "memory/wtd_" + str(round(id))
    outwtd = "Watersheds\\wtd_" + str(round(id))
    dis = arcpy.Dissolve_management(tempLayer, outdis)
    watershed = arcpy.EliminatePolygonPart_management(dis, outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
    print("Watershed created at:" + outwtd)
    c=c+1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
# Out:
# ['FDO_OBJECTID', 'FDO_Shape', 'catid_index']
# cats_merge Indexed
# OBJECTID
# Shape
# LINKNO
# DSLINKNO
# USLINKNO1
# USLINKNO2
# DSNODEID
# strmOrder
# Length
# Magnitude
# DSContArea
# strmDrop
# Slope
# StraightL
# USContArea
# WSNO
# DOUTEND
# DOUTSTART
# DOUTMID
# Shape_Length
# 1. Starting watershed for: 18457
# 27744
# 28132
# 28222
# 28392
# 31982
# 55458
# 70970
# 51980
# 46384
# 32378
# 49918
# 46944
# 27748
# 27942
# 30852
# 45518
# 23998
# 25882
# 41028
# 19208
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_18457
# 2. Starting watershed for: 26464
# 31298
# 29766
# 29746
# 27746
# 26276
# 25536
# 11766
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_26464
# 3. Starting watershed for: 28086
# 33752
# 31730
# 30390
# 28450
# 11820
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_28086
# 4. Starting watershed for: 29854
# 57928
# 92356
# 136652
# 140448
# 114430
# 116608
# 71984
# 36578
# 50646
# 66676
# 74932
# 72752
# 47198
# 26782
# 27316
# 15926
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_29854
# 5. Starting watershed for: 30884
# 49888
# 78696
# 58952
# 100026
# 123672
# 90698
# 94972
# 124242
# 89638
# 90142
# 122522
# 86948
# 85182
# 49012
# 49116
# 18847
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_30884
# 6. Starting watershed for: 31865
# 46050
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_31865
# 7. Starting watershed for: 36645
# 50980
# 50068
# 48998
# 45948
# 55168
# 67240
# -8
# Starting dissolve
# Watershed created at:Watersheds\wtd_36645
# 8. Starting watershed for: 37815
# 40660
# 65128
# 74770
# 52966
# 14884
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_37815
# 9. Starting watershed for: 38993
# 49836
# 38264
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_38993
# 10. Starting watershed for: 40285
# 73260
# 77320
# 81276
# 55666
# 41484
# 38868
# 39538
# 11208
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_40285
# 11. Starting watershed for: 41515
# 60710
# 61398
# 59808
# 59188
# 58238
# 58328
# 58628
# 57078
# 54908
# 52788
# 40228
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_41515
# 12. Starting watershed for: 42563
# 51476
# 53264
# 52324
# 51524
# 51024
# 50134
# 76244
# 90092
# 63508
# 44810
# 41034
# 40954
# 37794
# 35994
# 13454
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_42563
# 13. Starting watershed for: 43055
# 53760
# 52728
# 51348
# 52428
# 51968
# 72538
# 86460
# 68776
# 49864
# 49988
# 48748
# 47028
# 45348
# 44248
# 43228
# 43038
# 40348
# 36998
# 36518
# 7848
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_43055
# 14. Starting watershed for: 43185
# 84300
# 121030
# 158086
# 243440
# 274386
# 151264
# 42076
# 24558
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_43185
# 15. Starting watershed for: 43383
# 85846
# 105772
# 107528
# 107118
# 104318
# 102648
# 100438
# 125878
# 157806
# 144770
# 105008
# 83424
# 81568
# 76158
# 47158
# 13450
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_43383
# 16. Starting watershed for: 43933
# 59916
# 74964
# 90602
# 84760
# 127342
# 153256
# 137032
# 129854
# 152716
# 136482
# 123074
# 115206
# 81106
# 123682
# 120116
# 116494
# 82526
# 68136
# 84462
# 33628
# -8
# Starting dissolve
# Watershed created at:Watersheds\wtd_43933
# 17. Starting watershed for: 43973
# 61286
# 60314
# 60624
# 60874
# 60904
# 59884
# 60214
# 57874
# 57924
# 57064
# 55414
# 68154
# 82112
# 46150
# 42554
# 22544
# -4
# Starting dissolve
# Watershed created at:Watersheds\wtd_43973
# 18. Starting watershed for: 44553
# 58286
# 75944
# 108582
# 123058
# 156886
# 178412
# 197600
# 197186
# 210166
# 179414
# 132286
# 208276
# 249446
# 194416
# 124422
# 93030
# 143438
# 151234
# 170758
# 179690
# 228566
# 269852
# 251272
# 120320
# 30142
# -8
# Starting dissolve
# Watershed created at:Watersheds\wtd_44553
# 19. Starting watershed for: 46055
# 68689
# 85158
# 126374
# 107464
# 19055
# -8
# Starting dissolve
# Watershed created at:Watersheds\wtd_46055
# 20. Starting watershed for: 46513
# 79036
# 130222
# 172638
# 260104
# 286524
# 270272
# 301764
# 314340
# 344468
# 349224
# 405112
# 411546
# 338926
# 365554
# 405620
# 316164
# 292192
# 297348
# 321916
# 409236
# 467836
# 566828
# 599616
# 600298
# 556816
# 652426
# 643714
# 597202
# 506306
# 512816
# 466504
# 442554
# 389178
# 422596
# 512078
# 518215
# 738290
# 802595
# 863776
# 1036351
# 1048647
# 854326
# 661761
# 548516
# 570612
# 579431
# 400704
# 437272
# 578552
# 681022
# 831074
# 847666
# 954516
# 1291186
# 1308586
# 1411898
# 1290938
# 1464548
# 1579596
# 1478252
# 1237774
# 1267706
# 1111988
# 997456
# 1100058
# 1046988
# 1037109
# 833358
# 429652
# 278170
# 128246
# -8
# Starting dissolve
# Watershed created at:Watersheds\wtd_46513
# Process completed at 2021-12-03 09:23 (Elapsed time: 0:00:31)

# %%
# KODIAK WATERSHEDS

import arcpy
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr
arcpy.env.workspace = kod_gdb
arcpy.env.overwriteOutput = True

idList = []
cats = os.path.join(kod_gdb,'cats_merge')
outcats = "cats_intersect"
arcpy.MakeFeatureLayer_management(cats, "tempLayer")
arcpy.management.SelectLayerByLocation("tempLayer", "INTERSECT", points)
arcpy.CopyFeatures_management("tempLayer", outcats)
fields = arcpy.ListFields("tempLayer")
for field in fields:
    print("{0}".format(field.name))
with arcpy.da.SearchCursor("tempLayer", ["gridcode"]) as cursor:
    for row in cursor:
        idList.append(row[0])

print(len(idList))
# Out:
# OBJECTID
# Shape
# gridcode
# Shape_Length
# Shape_Area
# catID
# 28

# %%
# Kodiak
# steps 4-7

import arcpy
import pandas as pd
arcpy.env.workspace = kod_gdb
arcpy.env.overwriteOutput = True
arcpy.env.qualifiedFieldNames = False
sr = arcpy.SpatialReference(3338)  #'NAD_1983_Alaska_Albers'
arcpy.env.outputCoordinateSystem = sr

# Start timing function
processStart = time.time()
processStartdt = datetime.datetime.now()
streams = "streams_merge"
cats = "cats_merge"

# Get list of index names for cats merge and add index if not already created
index_names = [i.name for i in arcpy.ListIndexes(cats)]
print(index_names)
if 'catid_index' not in index_names:
    print (f'Creating index for {cats}')
    arcpy.AddIndex_management(cats, "catID", "catid_index")
else:
    print(f'{cats} Indexed')

#watersheds feature dataset for storing fcs
fdat = os.path.join(kod_gdb, 'Watersheds')
if not arcpy.Exists(fdat):
    arcpy.management.CreateFeatureDataset(kod_gdb, "Watersheds", sr)
else:
    print(f'{fdat} exists for Kodiak')


fields = arcpy.ListFields(streams)
for field in fields:
    print("{0}".format(field.name))

str_df = pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(streams, ("LINKNO", "USLINKNO1", "USLINKNO2")))
hws_codes = [-1]

#idList if doing ALL watersheds.
c = 1
for id in idList:
    print(f"{c}. Starting watershed for: " + str(id))
    rec = [id]
    up_ids = []
    sum_rec = sum(rec)

    while(sum_rec > 0):
        up_ids.append(rec)
        rec = str_df.loc[str_df["LINKNO"].isin(rec), ("USLINKNO1", "USLINKNO2")]
        rec = pd.concat([rec['USLINKNO1'], rec['USLINKNO2']])
        sum_rec = sum(rec)
 
    #up_ids is a list with more than numbers, use extend to only keep numeric nhdplusids
    newup_ids = []
    for x in up_ids:
        newup_ids.extend(x)

    tempLayer = "catsLyr"
    expression = '"gridcode" IN ({0})'.format(', '.join(map(str, newup_ids)) or 'NULL')
    arcpy.MakeFeatureLayer_management(cats, tempLayer)
    arcpy.management.SelectLayerByAttribute(tempLayer, "NEW_SELECTION", expression, None)
    print("Starting dissolve")
    outdis = "memory/wtd_" + str(round(id))
    outwtd = "Watersheds\\wtd_" + str(round(id))
    dis = arcpy.Dissolve_management(tempLayer, outdis)
    watershed = arcpy.EliminatePolygonPart_management(dis, outwtd,"PERCENT", "0 SquareKilometers", 90, "CONTAINED_ONLY")
    print("Watershed created at:" + outwtd)
    c=c+1

# End timing
processEnd = time.time()
processElapsed = int(processEnd - processStart)
processSuccess_time = datetime.datetime.now()

# Report success
print(f'Process completed at {processSuccess_time.strftime("%Y-%m-%d %H:%M")} '
      f'(Elapsed time: {datetime.timedelta(seconds=processElapsed)})')
# Out:
# ['FDO_OBJECTID', 'FDO_Shape', 'catid_index']
# cats_merge Indexed
# OBJECTID
# Shape
# LINKNO
# DSLINKNO
# USLINKNO1
# USLINKNO2
# DSNODEID
# strmOrder
# Length
# Magnitude
# DSContArea
# strmDrop
# Slope
# StraightL
# USContArea
# WSNO
# DOUTEND
# DOUTSTART
# DOUTMID
# proc_reg
# Shape_Length
# 1. Starting watershed for: 48267
# Starting dissolve
# Watershed created at:Watersheds\wtd_48267
# 2. Starting watershed for: 49617
# Starting dissolve
# Watershed created at:Watersheds\wtd_49617
# 3. Starting watershed for: 50197
# Starting dissolve
# Watershed created at:Watersheds\wtd_50197
# 4. Starting watershed for: 64593
# Starting dissolve
# Watershed created at:Watersheds\wtd_64593
# 5. Starting watershed for: 72144
# Starting dissolve
# Watershed created at:Watersheds\wtd_72144
# 6. Starting watershed for: 76954
# Starting dissolve
# Watershed created at:Watersheds\wtd_76954
# 7. Starting watershed for: 77794
# Starting dissolve
# Watershed created at:Watersheds\wtd_77794
# 8. Starting watershed for: 90346
# Starting dissolve
# Watershed created at:Watersheds\wtd_90346
# 9. Starting watershed for: 93176
# Starting dissolve
# Watershed created at:Watersheds\wtd_93176
# 10. Starting watershed for: 94216
# Starting dissolve
# Watershed created at:Watersheds\wtd_94216
# 11. Starting watershed for: 97276
# Starting dissolve
# Watershed created at:Watersheds\wtd_97276
# 12. Starting watershed for: 99516
# Starting dissolve
# Watershed created at:Watersheds\wtd_99516
# 13. Starting watershed for: 100826
# Starting dissolve
# Watershed created at:Watersheds\wtd_100826
# 14. Starting watershed for: 101556
# Starting dissolve
# Watershed created at:Watersheds\wtd_101556
# 15. Starting watershed for: 103096
# Starting dissolve
# Watershed created at:Watersheds\wtd_103096
# 16. Starting watershed for: 103196
# Starting dissolve
# Watershed created at:Watersheds\wtd_103196
# 17. Starting watershed for: 103296
# Starting dissolve
# Watershed created at:Watersheds\wtd_103296
# 18. Starting watershed for: 103456
# Starting dissolve
# Watershed created at:Watersheds\wtd_103456
# 19. Starting watershed for: 103496
# Starting dissolve
# Watershed created at:Watersheds\wtd_103496
# 20. Starting watershed for: 106626
# Starting dissolve
# Watershed created at:Watersheds\wtd_106626
# 21. Starting watershed for: 106676
# Starting dissolve
# Watershed created at:Watersheds\wtd_106676
# 22. Starting watershed for: 107796
# Starting dissolve
# Watershed created at:Watersheds\wtd_107796
# 23. Starting watershed for: 107816
# Starting dissolve
# Watershed created at:Watersheds\wtd_107816
# 24. Starting watershed for: 108356
# Starting dissolve
# Watershed created at:Watersheds\wtd_108356
# 25. Starting watershed for: 128685
# Starting dissolve
# Watershed created at:Watersheds\wtd_128685
# 26. Starting watershed for: 129955
# Starting dissolve
# Watershed created at:Watersheds\wtd_129955
# 27. Starting watershed for: 130295
# Starting dissolve
# Watershed created at:Watersheds\wtd_130295
# 28. Starting watershed for: 130735
# Starting dissolve
# Watershed created at:Watersheds\wtd_130735
# Process completed at 2021-12-03 09:24 (Elapsed time: 0:00:56)
